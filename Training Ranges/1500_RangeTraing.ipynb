# %% [markdown]
# # Preamble

# %% [markdown]
# This notebook shows the results of training with different data ranges. Due to past findings the prediction of the ai can be signifcantly better when trained on specific parts of the dataset. Here the ai has been trained on data within the range (distance) of 1500 to the midpoint.

# %% [markdown]
# # Preparation of data

# %% [markdown]
# ## Setting up dataframe

# %%
import pandas as pd
import numpy as np
import glob
import os
from typing import List
import os 
import sklearn.preprocessing

# %%
HEIGHT_CONSTANT = False
directory_path = '/Users/benedictkunzmann/Desktop/Bachelorarbeit/Verlauf/Modelle/20230902_version_3.1/01_measurement_data'

# %%
### function definition section:
def sort_key(file_path): # define a custom sorting key function to sort filenames alphabetically
    """ notes here """
    
    file_name = os.path.basename(file_path)
    
    return file_name

def get_csv_paths_list(directory_path: str):
    """ notes:
        this function is meant to list all A4T-, A5T-, A6T- and A7T-measurement files
         for different coil-coil-distances in form of her absolute filepathes."""

    csv_files = []

    parPath = os.getcwd()
    dataFolder = directory_path
    dataPath = os.path.join(parPath, dataFolder)

    subfolders = [f.path for f in os.scandir(dataPath) if f.is_dir()]

    for folder in subfolders:
        files_in_dir = glob.glob(os.path.join(folder, "*.csv"))
        sorted_files = sorted(files_in_dir, key=sort_key)
        csv_files.append(sorted_files)

    csv_files = csv_files[0:-1]

    return csv_files

def process_csv_files(csv_block: List[str]) -> pd.DataFrame:
    """ notes:
        parameter csv_block needs to be a list of 4 filepath strings.
        those strings refer to 4 different measurement files of sensors
         A4T, A5T, A6T and A7T.
        for a different height (coil-coil-distance) another csv_block
         has to be passed in.
        this function returns a combined/merged pd.dataframe in which
         the structure is ["A4T","A5T","A6T","A7T","x","y","z"], 
         thus all XxY-grids within each individual measurment file
         are flattened."""

    tmp_dfs = []
    columns = ["A4T","A5T","A6T","A7T","x","y","z"]
    merged_df = pd.DataFrame(columns=columns)

    curr_dz = float(csv_block[0].split("_dz")[1].split("/")[0]) # extract current z-height of dataset
    for _, sensor_file in enumerate(csv_block):
        data_list = [] # create a list to store the data

        curr_sensor = sensor_file.split("_")[-1].split(".")[0]  # extract current sensor's name in dataset

        df = pd.read_csv(sensor_file,skiprows=28,sep=",",index_col=0)
        df.index = pd.to_numeric(df.index)
        df.columns = pd.to_numeric(df.columns)

        for row_label, row in df.iterrows():
            for col_label, value in row.items():
                data_list.append((value, col_label, row_label, curr_dz, curr_sensor))

        tmp_dfs.append(pd.DataFrame(data_list, columns=["data","x","y","z","sensor"]))

        for _, tmp_df in enumerate(tmp_dfs):
            sensor_name = tmp_df["sensor"][0]
            merged_df[sensor_name] = tmp_df["data"]
        merged_df["x"] = tmp_df["x"]
        merged_df["y"] = tmp_df["y"]
        merged_df["z"] = tmp_df["z"]
        
    return merged_df

# %%
def extend_array(arr: np.ndarray, n: int):
    if arr.ndim == 1:
        result = []
        result.extend([arr[0]])
        for i in range(1, len(arr)):
            diff = (arr[i] - arr[i-1]) / (n+1)
            new_elements = [arr[i-1] + j*diff for j in range(1, (n+1))]
            result.extend(new_elements)
            result.extend([arr[i]])
        return np.array(result)

    result = []
    for row in arr:
        new_row = [row[0]]
        for i in range(1, len(row)):
            diff = (row[i] - row[i-1]) / (n+1)
            new_elements = [row[i-1] + j*diff for j in range(1, (n+1))]
            new_row.extend(new_elements)
            new_row.append(row[i])
        result.append(new_row)
    return np.array(result)

# %%
csv_files = []
merged_df_list = []

csv_files = get_csv_paths_list(directory_path) # function call to get the filepathes of all measurement files
csv_files # jupyter print

for idx, z_height_group in enumerate(csv_files): # loop through each group of files (A4T, A5T, A6T, A7T)
    merged_df_list.append(process_csv_files(z_height_group))

final_combined_df = pd.concat(merged_df_list, ignore_index=True)
final_combined_df
# Out:
#          A4T    A5T    A6T    A7T      x       y      z
# 0      0.122  0.159  0.161  0.148  620.0 -1120.0  190.0
# 1      0.160  0.194  0.192  0.173  600.0 -1120.0  190.0
# 2      0.145  0.186  0.189  0.178  580.0 -1120.0  190.0
# 3      0.132  0.167  0.168  0.154  560.0 -1120.0  190.0
# 4      0.132  0.167  0.172  0.161  540.0 -1120.0  190.0
# ...      ...    ...    ...    ...    ...     ...    ...
# 49828  0.143  0.179  0.176  0.156 -540.0  1120.0  180.0
# 49829  0.110  0.151  0.143  0.128 -560.0  1120.0  180.0
# 49830  0.114  0.159  0.156  0.143 -580.0  1120.0  180.0
# 49831  0.157  0.192  0.187  0.167 -600.0  1120.0  180.0
# 49832  0.000  0.000  0.000  0.000 -620.0  1120.0  180.0
#
# [49833 rows x 7 columns]

# %%
final_combined_df["A4T"].max()
# Out:
# 3.934

# %% [markdown]
# ### Cuttting the Frame

# %%
distance_threshold = 1500

# Calculate Euclidean distance
final_combined_df['distance'] = np.sqrt(final_combined_df['x']**2 + final_combined_df['y']**2)

# Filter the DataFrame based on the distance threshold
filtered_df = final_combined_df[final_combined_df['distance'] <= distance_threshold]

# Drop the 'distance' column if you don't need it anymore
filtered_df = filtered_df.drop(columns=['distance'])

# Display the filtered DataFrame
filtered_df
# Out:
#          A4T    A5T    A6T    A7T      x       y      z
# 0      0.122  0.159  0.161  0.148  620.0 -1120.0  190.0
# 1      0.160  0.194  0.192  0.173  600.0 -1120.0  190.0
# 2      0.145  0.186  0.189  0.178  580.0 -1120.0  190.0
# 3      0.132  0.167  0.168  0.154  560.0 -1120.0  190.0
# 4      0.132  0.167  0.172  0.161  540.0 -1120.0  190.0
# ...      ...    ...    ...    ...    ...     ...    ...
# 49828  0.143  0.179  0.176  0.156 -540.0  1120.0  180.0
# 49829  0.110  0.151  0.143  0.128 -560.0  1120.0  180.0
# 49830  0.114  0.159  0.156  0.143 -580.0  1120.0  180.0
# 49831  0.157  0.192  0.187  0.167 -600.0  1120.0  180.0
# 49832  0.000  0.000  0.000  0.000 -620.0  1120.0  180.0
#
# [49833 rows x 7 columns]

# %%
# input_data = final_combined_df[["A4T", "A5T", "A6T", "A7T"]]
input_data = filtered_df[["A4T", "A5T", "A6T", "A7T"]]
input_data
# Out:
#          A4T    A5T    A6T    A7T
# 0      0.122  0.159  0.161  0.148
# 1      0.160  0.194  0.192  0.173
# 2      0.145  0.186  0.189  0.178
# 3      0.132  0.167  0.168  0.154
# 4      0.132  0.167  0.172  0.161
# ...      ...    ...    ...    ...
# 49828  0.143  0.179  0.176  0.156
# 49829  0.110  0.151  0.143  0.128
# 49830  0.114  0.159  0.156  0.143
# 49831  0.157  0.192  0.187  0.167
# 49832  0.000  0.000  0.000  0.000
#
# [49833 rows x 4 columns]

# %%
# target_data = final_combined_df[["x", "y"]]
target_data = filtered_df[["x", "y"]]
target_data
# Out:
#            x       y
# 0      620.0 -1120.0
# 1      600.0 -1120.0
# 2      580.0 -1120.0
# 3      560.0 -1120.0
# 4      540.0 -1120.0
# ...      ...     ...
# 49828 -540.0  1120.0
# 49829 -560.0  1120.0
# 49830 -580.0  1120.0
# 49831 -600.0  1120.0
# 49832 -620.0  1120.0
#
# [49833 rows x 2 columns]

# %% [markdown]
# ## Scale the dataframe

# %%
scaler_input = sklearn.preprocessing.MinMaxScaler()
scaled_input_data = scaler_input.fit_transform(input_data)
scaled_input_data.max(axis=0)
# Out:
# array([1., 1., 1., 1.])

# %%
scaler_target = sklearn.preprocessing.MinMaxScaler()
scaled_target_data = scaler_target.fit_transform(target_data)
scaled_target_data.max(axis=0)
# Out:
# array([1., 1.])

# %% [markdown]
# ## Get distribution of the datapoints

# %%
import matplotlib.pyplot as plt

percentages = []
thresholds = []

for threshold in np.arange(0.05, 1, 0.05):
    thresholds.append(threshold)
    filtered_arr = scaled_input_data[scaled_input_data >= threshold]
    percentage = len(filtered_arr) / scaled_input_data.size * 100
    percentages.append(percentage)
    # print(f"Threshold: {threshold:.2f}, Percentage: {percentage:.2f}%")

plt.bar(thresholds, percentages, width= 0.025)
plt.show()

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dropout, Input, Activation, Dense
from keras.initializers import HeUniform
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.losses import MeanSquaredError

# %%
import metrics
import time

# %% [markdown]
# ## Generating training and testing data

# %%
input_tensor = tf.convert_to_tensor(scaled_input_data)
target_tensor = tf.convert_to_tensor(scaled_target_data)
n_features = 4

# %%
# Create a dataset with the input and target tensors
dataset = tf.data.Dataset.from_tensor_slices((input_tensor, target_tensor))

# Shuffle the dataset with a buffer size of the number of samples
buffer_size = input_tensor.shape[0]
shuffled_dataset = dataset.shuffle(buffer_size)

# Extract the shuffled input and target tensors from the shuffled dataset
input_tensor, target_tensor = next(iter(shuffled_dataset.batch(buffer_size)))

input_dataset = tf.data.Dataset.from_tensor_slices(input_data)
target_dataset = tf.data.Dataset.from_tensor_slices(target_tensor)

print(input_tensor.shape)
# Out:
# (49833, 4)

# %%
# # split the data and labels into training and testing sets
# train_size = int(0.7 * len(input_tensor)) # 80% of data for training
# train_data, test_data = tf.split(input_tensor, [train_size, len(input_tensor)-train_size], axis=0)
# train_labels, test_labels = tf.split(target_tensor, [train_size, len(target_tensor)-train_size], axis=0)
# print(train_data.shape, train_labels.shape)

buffer_size = input_tensor.shape[0]
indices = np.arange(buffer_size)
np.random.shuffle(indices)

# Define the sizes for training, validation, and test sets
train_size = int(0.7 * buffer_size)  # 70% of data for training
val_size = int(0.15 * buffer_size)   # 15% of data for validation
test_size = buffer_size - train_size - val_size  # Rest for testing

# Split the shuffled indices into training, validation, and test sets
train_indices = indices[:train_size]
val_indices = indices[train_size:train_size + val_size]
test_indices = indices[train_size + val_size:]

# Convert the indices to TensorFlow tensors
train_indices = tf.convert_to_tensor(train_indices, dtype=tf.int32)
val_indices = tf.convert_to_tensor(val_indices, dtype=tf.int32)
test_indices = tf.convert_to_tensor(test_indices, dtype=tf.int32)

# Use the indices to create tensors for training, validation, and test sets
train_data = tf.gather(input_tensor, train_indices)
train_labels = tf.gather(target_tensor, train_indices)

val_data = tf.gather(input_tensor, val_indices)
val_labels = tf.gather(target_tensor, val_indices)

test_data = tf.gather(input_tensor, test_indices)
test_labels = tf.gather(target_tensor, test_indices)

# %% [markdown]
# ## Building the model

# %%
n_hidden = 1024

model = Sequential()
model.add(Input(shape= (n_features), name='Dense_Input'))
model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_1'))
model.add(Activation('relu', name='relu_1'))
model.add(Dropout(rate=0.2, name='dropout_1'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_2'))
model.add(Activation('relu', name='relu_2'))
model.add(Dropout(rate=0.2, name='dropout_2'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_3'))
model.add(Activation('relu', name='relu_3'))
model.add(Dropout(rate=0.2, name='dropout_3'))
model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_4'))
model.add(Activation('relu', name='relu_4'))
model.add(Dense(2, name='Dense_Out'))
model.add(Activation('sigmoid', name='sigmoid_Out'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_1 (Dense)             (None, 512)               2560
#
#  relu_1 (Activation)         (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  Dense_2 (Dense)             (None, 1024)              525312
#
#  relu_2 (Activation)         (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  Dense_3 (Dense)             (None, 1024)              1049600
#
#  relu_3 (Activation)         (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  Dense_4 (Dense)             (None, 512)               524800
#
#  relu_4 (Activation)         (None, 512)               0
#
#  Dense_Out (Dense)           (None, 2)                 1026
#
#  sigmoid_Out (Activation)    (None, 2)                 0
#
# =================================================================
# Total params: 2,103,298
# Trainable params: 2,103,298
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
import math
# Define configuration parameters
start_lr = 0.0001
rampup_epochs = 20
exp_decay = 0.1

# Define the scheduling function
def scheduler(epoch):
  def lr(epoch, start_lr, rampup_epochs, exp_decay):
    if epoch < rampup_epochs:
      return start_lr
    else:
      return start_lr * math.exp(-exp_decay * epoch)
  return lr(epoch, start_lr, rampup_epochs, exp_decay)

# %%
optimizer = Adam()
loss = MeanSquaredError()

mcp_save = ModelCheckpoint(f'MLP-NewData-ZInput_mse_{int(time.time())}.h5', 
                           save_best_only=True,
                           monitor='val_mse', 
                           mode='min')

learning_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
model.compile(optimizer=optimizer, 
                loss="mse",
                metrics=["mse", metrics.CenterMeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYSquarredErrorRealWorld(scaler=scaler_target),  
                                metrics.MeanXYAbsoluteErrorRealWorld(scaler=scaler_target),
                                metrics.MeanXYRootSquarredErrorRealWorld(scaler=scaler_target)]
)

# %%
history = model.fit(
    x = train_data,
    y = train_labels, 
    epochs = 40,
    validation_data = [val_data, val_labels],
    callbacks = [learning_callback]
)
# Out:
# Epoch 1/40
# 2023-09-24 16:44:19.039864: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1091/1091 [==============================] - ETA: 0s - loss: 0.0467 - mse: 0.0467 - centernormXYReal: 1009.4772 - normXYReal: 452.0846 - mseXYReal: 151374.4219 - maeXYReal: 287.3226 - rmseXYReal: 389.0687
# 2023-09-24 16:44:35.212491: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0467 - mse: 0.0467 - centernormXYReal: 1009.4772 - normXYReal: 452.0846 - mseXYReal: 151374.4219 - maeXYReal: 287.3226 - rmseXYReal: 389.0687 - val_loss: 0.0265 - val_mse: 0.0265 - val_centernormXYReal: 443.8656 - val_normXYReal: 303.9110 - val_mseXYReal: 72556.2109 - val_maeXYReal: 193.6008 - val_rmseXYReal: 269.3626 - lr: 1.0000e-04
# Epoch 2/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0247 - mse: 0.0247 - centernormXYReal: 329.1853 - normXYReal: 278.7589 - mseXYReal: 64820.3047 - maeXYReal: 177.3249 - rmseXYReal: 254.5983 - val_loss: 0.0215 - val_mse: 0.0215 - val_centernormXYReal: 219.5247 - val_normXYReal: 255.4882 - val_mseXYReal: 54474.8789 - val_maeXYReal: 162.5419 - val_rmseXYReal: 233.3985 - lr: 1.0000e-04
# Epoch 3/40
# 1091/1091 [==============================] - 18s 16ms/step - loss: 0.0217 - mse: 0.0217 - centernormXYReal: 310.0549 - normXYReal: 254.0656 - mseXYReal: 55624.5312 - maeXYReal: 161.1412 - rmseXYReal: 235.8485 - val_loss: 0.0197 - val_mse: 0.0197 - val_centernormXYReal: 162.1429 - val_normXYReal: 234.5158 - val_mseXYReal: 50349.0078 - val_maeXYReal: 148.1668 - val_rmseXYReal: 224.3858 - lr: 1.0000e-04
# Epoch 4/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0201 - mse: 0.0201 - centernormXYReal: 258.1524 - normXYReal: 238.0814 - mseXYReal: 50956.0586 - maeXYReal: 149.9462 - rmseXYReal: 225.7345 - val_loss: 0.0196 - val_mse: 0.0196 - val_centernormXYReal: 236.4443 - val_normXYReal: 228.8419 - val_mseXYReal: 52287.4688 - val_maeXYReal: 143.6701 - val_rmseXYReal: 228.6645 - lr: 1.0000e-04
# Epoch 5/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0189 - mse: 0.0189 - centernormXYReal: 241.2073 - normXYReal: 225.6563 - mseXYReal: 47542.2617 - maeXYReal: 141.4060 - rmseXYReal: 218.0419 - val_loss: 0.0169 - val_mse: 0.0169 - val_centernormXYReal: 153.8397 - val_normXYReal: 210.7382 - val_mseXYReal: 41606.5469 - val_maeXYReal: 132.0835 - val_rmseXYReal: 203.9768 - lr: 1.0000e-04
# Epoch 6/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0179 - mse: 0.0179 - centernormXYReal: 229.7155 - normXYReal: 216.1221 - mseXYReal: 44796.9375 - maeXYReal: 134.9978 - rmseXYReal: 211.6529 - val_loss: 0.0166 - val_mse: 0.0166 - val_centernormXYReal: 215.1516 - val_normXYReal: 212.1999 - val_mseXYReal: 41080.5742 - val_maeXYReal: 132.1556 - val_rmseXYReal: 202.6834 - lr: 1.0000e-04
# Epoch 7/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0172 - mse: 0.0172 - centernormXYReal: 189.3512 - normXYReal: 207.6070 - mseXYReal: 42726.1289 - maeXYReal: 129.1663 - rmseXYReal: 206.7030 - val_loss: 0.0157 - val_mse: 0.0157 - val_centernormXYReal: 188.2756 - val_normXYReal: 195.5143 - val_mseXYReal: 37642.5234 - val_maeXYReal: 121.1133 - val_rmseXYReal: 194.0168 - lr: 1.0000e-04
# Epoch 8/40
# 1091/1091 [==============================] - 18s 16ms/step - loss: 0.0164 - mse: 0.0164 - centernormXYReal: 209.0018 - normXYReal: 199.6214 - mseXYReal: 40447.3203 - maeXYReal: 123.7745 - rmseXYReal: 201.1152 - val_loss: 0.0151 - val_mse: 0.0151 - val_centernormXYReal: 162.3558 - val_normXYReal: 187.4249 - val_mseXYReal: 36235.8203 - val_maeXYReal: 115.4762 - val_rmseXYReal: 190.3571 - lr: 1.0000e-04
# Epoch 9/40
# 1091/1091 [==============================] - 18s 16ms/step - loss: 0.0158 - mse: 0.0158 - centernormXYReal: 173.8178 - normXYReal: 193.6648 - mseXYReal: 38819.4453 - maeXYReal: 119.7684 - rmseXYReal: 197.0265 - val_loss: 0.0150 - val_mse: 0.0150 - val_centernormXYReal: 148.4350 - val_normXYReal: 189.6916 - val_mseXYReal: 35124.0078 - val_maeXYReal: 117.3133 - val_rmseXYReal: 187.4140 - lr: 1.0000e-04
# Epoch 10/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0154 - mse: 0.0154 - centernormXYReal: 172.1251 - normXYReal: 188.5125 - mseXYReal: 37866.5039 - maeXYReal: 116.2529 - rmseXYReal: 194.5932 - val_loss: 0.0139 - val_mse: 0.0139 - val_centernormXYReal: 154.5110 - val_normXYReal: 177.5124 - val_mseXYReal: 32774.0781 - val_maeXYReal: 109.2978 - val_rmseXYReal: 181.0361 - lr: 1.0000e-04
# Epoch 11/40
# 1091/1091 [==============================] - 18s 16ms/step - loss: 0.0150 - mse: 0.0150 - centernormXYReal: 214.5648 - normXYReal: 183.6534 - mseXYReal: 36570.6914 - maeXYReal: 113.1163 - rmseXYReal: 191.2346 - val_loss: 0.0139 - val_mse: 0.0139 - val_centernormXYReal: 193.6985 - val_normXYReal: 176.9833 - val_mseXYReal: 32488.0410 - val_maeXYReal: 108.5376 - val_rmseXYReal: 180.2444 - lr: 1.0000e-04
# Epoch 12/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0147 - mse: 0.0147 - centernormXYReal: 191.1922 - normXYReal: 179.9516 - mseXYReal: 35833.9883 - maeXYReal: 110.6746 - rmseXYReal: 189.2987 - val_loss: 0.0135 - val_mse: 0.0135 - val_centernormXYReal: 180.9066 - val_normXYReal: 176.4613 - val_mseXYReal: 32334.2051 - val_maeXYReal: 108.5510 - val_rmseXYReal: 179.8171 - lr: 1.0000e-04
# Epoch 13/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0142 - mse: 0.0142 - centernormXYReal: 165.3068 - normXYReal: 175.3884 - mseXYReal: 34480.9531 - maeXYReal: 107.6354 - rmseXYReal: 185.6905 - val_loss: 0.0133 - val_mse: 0.0133 - val_centernormXYReal: 180.8814 - val_normXYReal: 171.2849 - val_mseXYReal: 31099.1621 - val_maeXYReal: 105.6855 - val_rmseXYReal: 176.3495 - lr: 1.0000e-04
# Epoch 14/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0138 - mse: 0.0138 - centernormXYReal: 176.1647 - normXYReal: 172.1139 - mseXYReal: 33422.3047 - maeXYReal: 105.4927 - rmseXYReal: 182.8177 - val_loss: 0.0130 - val_mse: 0.0130 - val_centernormXYReal: 176.8839 - val_normXYReal: 167.6217 - val_mseXYReal: 30910.5859 - val_maeXYReal: 103.3920 - val_rmseXYReal: 175.8141 - lr: 1.0000e-04
# Epoch 15/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0138 - mse: 0.0138 - centernormXYReal: 156.0204 - normXYReal: 169.6270 - mseXYReal: 33671.9336 - maeXYReal: 103.8701 - rmseXYReal: 183.4991 - val_loss: 0.0128 - val_mse: 0.0128 - val_centernormXYReal: 98.1359 - val_normXYReal: 158.2125 - val_mseXYReal: 30424.0723 - val_maeXYReal: 96.3351 - val_rmseXYReal: 174.4250 - lr: 1.0000e-04
# Epoch 16/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0134 - mse: 0.0134 - centernormXYReal: 192.3056 - normXYReal: 166.3830 - mseXYReal: 32394.8281 - maeXYReal: 101.9060 - rmseXYReal: 179.9856 - val_loss: 0.0131 - val_mse: 0.0131 - val_centernormXYReal: 149.3344 - val_normXYReal: 159.4455 - val_mseXYReal: 31113.7305 - val_maeXYReal: 96.8621 - val_rmseXYReal: 176.3908 - lr: 1.0000e-04
# Epoch 17/40
# 1091/1091 [==============================] - 19s 18ms/step - loss: 0.0132 - mse: 0.0132 - centernormXYReal: 198.4858 - normXYReal: 162.9155 - mseXYReal: 31604.3418 - maeXYReal: 99.6167 - rmseXYReal: 177.7761 - val_loss: 0.0122 - val_mse: 0.0122 - val_centernormXYReal: 132.0992 - val_normXYReal: 153.7984 - val_mseXYReal: 27647.2617 - val_maeXYReal: 93.7305 - val_rmseXYReal: 166.2747 - lr: 1.0000e-04
# Epoch 18/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0130 - mse: 0.0130 - centernormXYReal: 168.2638 - normXYReal: 160.3980 - mseXYReal: 30967.9492 - maeXYReal: 97.9775 - rmseXYReal: 175.9771 - val_loss: 0.0118 - val_mse: 0.0118 - val_centernormXYReal: 123.3932 - val_normXYReal: 147.8960 - val_mseXYReal: 27135.3164 - val_maeXYReal: 90.0630 - val_rmseXYReal: 164.7280 - lr: 1.0000e-04
# Epoch 19/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0127 - mse: 0.0127 - centernormXYReal: 168.3819 - normXYReal: 158.5510 - mseXYReal: 30329.0449 - maeXYReal: 96.8588 - rmseXYReal: 174.1524 - val_loss: 0.0120 - val_mse: 0.0120 - val_centernormXYReal: 164.5687 - val_normXYReal: 152.3815 - val_mseXYReal: 27257.6738 - val_maeXYReal: 93.2896 - val_rmseXYReal: 165.0990 - lr: 1.0000e-04
# Epoch 20/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0126 - mse: 0.0126 - centernormXYReal: 127.3574 - normXYReal: 156.9833 - mseXYReal: 29945.2012 - maeXYReal: 95.8527 - rmseXYReal: 173.0468 - val_loss: 0.0120 - val_mse: 0.0120 - val_centernormXYReal: 148.9992 - val_normXYReal: 153.2769 - val_mseXYReal: 27557.5547 - val_maeXYReal: 93.7196 - val_rmseXYReal: 166.0047 - lr: 1.0000e-04
# Epoch 21/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0117 - mse: 0.0117 - centernormXYReal: 162.7770 - normXYReal: 145.5828 - mseXYReal: 27319.3438 - maeXYReal: 88.7414 - rmseXYReal: 165.2856 - val_loss: 0.0115 - val_mse: 0.0115 - val_centernormXYReal: 150.5741 - val_normXYReal: 145.3586 - val_mseXYReal: 25865.8887 - val_maeXYReal: 88.4753 - val_rmseXYReal: 160.8288 - lr: 1.3534e-05
# Epoch 22/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0114 - mse: 0.0114 - centernormXYReal: 187.2190 - normXYReal: 142.5290 - mseXYReal: 26444.6426 - maeXYReal: 86.7889 - rmseXYReal: 162.6181 - val_loss: 0.0113 - val_mse: 0.0113 - val_centernormXYReal: 105.9111 - val_normXYReal: 144.4871 - val_mseXYReal: 25295.5254 - val_maeXYReal: 87.8803 - val_rmseXYReal: 159.0457 - lr: 1.2246e-05
# Epoch 23/40
# 1091/1091 [==============================] - 18s 17ms/step - loss: 0.0113 - mse: 0.0113 - centernormXYReal: 159.3074 - normXYReal: 141.0161 - mseXYReal: 26133.6719 - maeXYReal: 85.8368 - rmseXYReal: 161.6591 - val_loss: 0.0112 - val_mse: 0.0112 - val_centernormXYReal: 119.6850 - val_normXYReal: 142.6537 - val_mseXYReal: 25083.1367 - val_maeXYReal: 86.8152 - val_rmseXYReal: 158.3766 - lr: 1.1080e-05
# Epoch 24/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0113 - mse: 0.0113 - centernormXYReal: 146.8902 - normXYReal: 140.5294 - mseXYReal: 26127.4922 - maeXYReal: 85.4855 - rmseXYReal: 161.6400 - val_loss: 0.0114 - val_mse: 0.0114 - val_centernormXYReal: 126.0763 - val_normXYReal: 144.0250 - val_mseXYReal: 25730.3398 - val_maeXYReal: 87.7501 - val_rmseXYReal: 160.4068 - lr: 1.0026e-05
# Epoch 25/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0112 - mse: 0.0112 - centernormXYReal: 126.5713 - normXYReal: 139.2696 - mseXYReal: 25668.1523 - maeXYReal: 84.7702 - rmseXYReal: 160.2128 - val_loss: 0.0113 - val_mse: 0.0113 - val_centernormXYReal: 114.9571 - val_normXYReal: 143.5608 - val_mseXYReal: 25354.0918 - val_maeXYReal: 87.3446 - val_rmseXYReal: 159.2297 - lr: 9.0718e-06
# Epoch 26/40
# 1091/1091 [==============================] - 19s 18ms/step - loss: 0.0111 - mse: 0.0111 - centernormXYReal: 188.4859 - normXYReal: 138.6987 - mseXYReal: 25584.9492 - maeXYReal: 84.3542 - rmseXYReal: 159.9530 - val_loss: 0.0113 - val_mse: 0.0113 - val_centernormXYReal: 150.8788 - val_normXYReal: 143.2510 - val_mseXYReal: 25299.7363 - val_maeXYReal: 87.1317 - val_rmseXYReal: 159.0589 - lr: 8.2085e-06
# Epoch 27/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0111 - mse: 0.0111 - centernormXYReal: 153.3974 - normXYReal: 138.3507 - mseXYReal: 25446.4551 - maeXYReal: 84.1096 - rmseXYReal: 159.5195 - val_loss: 0.0113 - val_mse: 0.0113 - val_centernormXYReal: 128.1221 - val_normXYReal: 143.5240 - val_mseXYReal: 25234.9375 - val_maeXYReal: 87.3350 - val_rmseXYReal: 158.8551 - lr: 7.4274e-06
# Epoch 28/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0111 - mse: 0.0111 - centernormXYReal: 158.5419 - normXYReal: 138.3945 - mseXYReal: 25602.8027 - maeXYReal: 84.1687 - rmseXYReal: 160.0088 - val_loss: 0.0112 - val_mse: 0.0112 - val_centernormXYReal: 132.4876 - val_normXYReal: 142.9518 - val_mseXYReal: 24973.3477 - val_maeXYReal: 86.7860 - val_rmseXYReal: 158.0296 - lr: 6.7206e-06
# Epoch 29/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0111 - mse: 0.0111 - centernormXYReal: 170.4270 - normXYReal: 137.8933 - mseXYReal: 25469.7285 - maeXYReal: 83.8147 - rmseXYReal: 159.5924 - val_loss: 0.0112 - val_mse: 0.0112 - val_centernormXYReal: 134.2088 - val_normXYReal: 142.0481 - val_mseXYReal: 24963.7305 - val_maeXYReal: 86.3402 - val_rmseXYReal: 157.9991 - lr: 6.0810e-06
# Epoch 30/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0110 - mse: 0.0110 - centernormXYReal: 134.5638 - normXYReal: 137.1407 - mseXYReal: 25210.5078 - maeXYReal: 83.3389 - rmseXYReal: 158.7782 - val_loss: 0.0112 - val_mse: 0.0112 - val_centernormXYReal: 115.7013 - val_normXYReal: 142.0941 - val_mseXYReal: 24747.8418 - val_maeXYReal: 86.3398 - val_rmseXYReal: 157.3145 - lr: 5.5023e-06
# Epoch 31/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0110 - mse: 0.0110 - centernormXYReal: 173.8560 - normXYReal: 137.2934 - mseXYReal: 25373.3633 - maeXYReal: 83.4204 - rmseXYReal: 159.2902 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 139.4624 - val_normXYReal: 140.9263 - val_mseXYReal: 24635.3223 - val_maeXYReal: 85.5689 - val_rmseXYReal: 156.9564 - lr: 4.9787e-06
# Epoch 32/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0110 - mse: 0.0110 - centernormXYReal: 159.0110 - normXYReal: 136.7370 - mseXYReal: 25240.7520 - maeXYReal: 83.0737 - rmseXYReal: 158.8734 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 138.2452 - val_normXYReal: 141.5424 - val_mseXYReal: 24773.7988 - val_maeXYReal: 86.0658 - val_rmseXYReal: 157.3969 - lr: 4.5049e-06
# Epoch 33/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0110 - mse: 0.0110 - centernormXYReal: 150.2109 - normXYReal: 136.8718 - mseXYReal: 25278.1836 - maeXYReal: 83.1465 - rmseXYReal: 158.9911 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 135.5332 - val_normXYReal: 141.1747 - val_mseXYReal: 24623.9238 - val_maeXYReal: 85.8000 - val_rmseXYReal: 156.9201 - lr: 4.0762e-06
# Epoch 34/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0109 - mse: 0.0109 - centernormXYReal: 165.9521 - normXYReal: 136.5831 - mseXYReal: 25056.4395 - maeXYReal: 82.9652 - rmseXYReal: 158.2923 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 122.3926 - val_normXYReal: 141.5055 - val_mseXYReal: 24722.0059 - val_maeXYReal: 86.0825 - val_rmseXYReal: 157.2323 - lr: 3.6883e-06
# Epoch 35/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0109 - mse: 0.0109 - centernormXYReal: 149.9707 - normXYReal: 136.1384 - mseXYReal: 25007.1797 - maeXYReal: 82.7085 - rmseXYReal: 158.1366 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 123.6573 - val_normXYReal: 141.3096 - val_mseXYReal: 24602.8594 - val_maeXYReal: 85.9031 - val_rmseXYReal: 156.8530 - lr: 3.3373e-06
# Epoch 36/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0109 - mse: 0.0109 - centernormXYReal: 167.3913 - normXYReal: 136.1591 - mseXYReal: 24961.7090 - maeXYReal: 82.7454 - rmseXYReal: 157.9928 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 116.6573 - val_normXYReal: 141.6145 - val_mseXYReal: 24704.7793 - val_maeXYReal: 86.0662 - val_rmseXYReal: 157.1775 - lr: 3.0197e-06
# Epoch 37/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0109 - mse: 0.0109 - centernormXYReal: 183.5786 - normXYReal: 136.0268 - mseXYReal: 25009.6992 - maeXYReal: 82.6337 - rmseXYReal: 158.1445 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 122.8322 - val_normXYReal: 141.2521 - val_mseXYReal: 24641.6543 - val_maeXYReal: 85.8474 - val_rmseXYReal: 156.9766 - lr: 2.7324e-06
# Epoch 38/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0109 - mse: 0.0109 - centernormXYReal: 158.1213 - normXYReal: 135.9210 - mseXYReal: 24987.8145 - maeXYReal: 82.5505 - rmseXYReal: 158.0753 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 116.4290 - val_normXYReal: 141.0686 - val_mseXYReal: 24712.6094 - val_maeXYReal: 85.7756 - val_rmseXYReal: 157.2025 - lr: 2.4724e-06
# Epoch 39/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0109 - mse: 0.0109 - centernormXYReal: 150.0996 - normXYReal: 135.5692 - mseXYReal: 24895.2188 - maeXYReal: 82.3541 - rmseXYReal: 157.7822 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 136.1076 - val_normXYReal: 141.2217 - val_mseXYReal: 24656.9668 - val_maeXYReal: 85.8680 - val_rmseXYReal: 157.0254 - lr: 2.2371e-06
# Epoch 40/40
# 1091/1091 [==============================] - 19s 17ms/step - loss: 0.0109 - mse: 0.0109 - centernormXYReal: 180.0371 - normXYReal: 135.7059 - mseXYReal: 24932.0254 - maeXYReal: 82.4209 - rmseXYReal: 157.8988 - val_loss: 0.0111 - val_mse: 0.0111 - val_centernormXYReal: 137.8540 - val_normXYReal: 140.7259 - val_mseXYReal: 24563.3398 - val_maeXYReal: 85.5762 - val_rmseXYReal: 156.7270 - lr: 2.0242e-06

# %% [markdown]
# ## Analysis of the model

# %%
plt.plot(history.history["mse"], 'b', label="mse")
plt.plot(history.history["val_mse"], 'r', label="val_mse")
plt.ylabel("mse")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["loss"], 'b', label="loss")
plt.plot(history.history["val_loss"], 'r', label="val_loss")
plt.ylabel("losses")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["centernormXYReal"], 'b', label="centernormXYReal")
plt.plot(history.history["val_centernormXYReal"], 'r', label="val_centernormXYReal")
plt.ylabel("centernormXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["normXYReal"], 'b', label="normXYReal")
plt.plot(history.history["val_normXYReal"], 'r', label="val_normXYReal")
plt.ylabel("normXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
results = model.evaluate(test_data, test_labels)
dict(zip(model.metrics_names, results))
# Out:
# 234/234 [==============================] - 3s 13ms/step - loss: 0.0121 - mse: 0.0121 - centernormXYReal: 178.1336 - normXYReal: 144.4362 - mseXYReal: 27653.6719 - maeXYReal: 87.8865 - rmseXYReal: 166.2939
# {'loss': 0.012123133055865765,
#  'mse': 0.012123133055865765,
#  'centernormXYReal': 178.13363647460938,
#  'normXYReal': 144.4362335205078,
#  'mseXYReal': 27653.671875,
#  'maeXYReal': 87.88653564453125,
#  'rmseXYReal': 166.29393005371094}
