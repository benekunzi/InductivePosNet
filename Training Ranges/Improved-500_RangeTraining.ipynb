# %% [markdown]
# # Preamble

# %% [markdown]
# This notebook shows the results of training with different data ranges. Due to past findings the prediction of the ai can be signifcantly better when trained on specific parts of the dataset. Here the ai has been trained on data within the range (distance) of 500 to the midpoint.

# %% [markdown]
# # Preparation of data

# %% [markdown]
# ## Setting up dataframe

# %%
import pandas as pd
import numpy as np
import glob
import os
from typing import List
import os 
import sklearn.preprocessing

# %%
distance_threshold = 250
HEIGHT_CONSTANT = False
directory_path = '/Users/benedictkunzmann/Desktop/Bachelorarbeit/Verlauf/Modelle/20230902_version_3.1/01_measurement_data'

# %%
### function definition section:
def sort_key(file_path): # define a custom sorting key function to sort filenames alphabetically
    """ notes here """
    
    file_name = os.path.basename(file_path)
    
    return file_name

def get_csv_paths_list(directory_path: str):
    """ notes:
        this function is meant to list all A4T-, A5T-, A6T- and A7T-measurement files
         for different coil-coil-distances in form of her absolute filepathes."""

    csv_files = []

    parPath = os.getcwd()
    dataFolder = directory_path
    dataPath = os.path.join(parPath, dataFolder)

    subfolders = [f.path for f in os.scandir(dataPath) if f.is_dir()]

    for folder in subfolders:
        files_in_dir = glob.glob(os.path.join(folder, "*.csv"))
        sorted_files = sorted(files_in_dir, key=sort_key)
        csv_files.append(sorted_files)

    csv_files = csv_files[0:-1]

    return csv_files

def process_csv_files(csv_block: List[str]) -> pd.DataFrame:
    """ notes:
        parameter csv_block needs to be a list of 4 filepath strings.
        those strings refer to 4 different measurement files of sensors
         A4T, A5T, A6T and A7T.
        for a different height (coil-coil-distance) another csv_block
         has to be passed in.
        this function returns a combined/merged pd.dataframe in which
         the structure is ["A4T","A5T","A6T","A7T","x","y","z"], 
         thus all XxY-grids within each individual measurment file
         are flattened."""

    tmp_dfs = []
    columns = ["A4T","A5T","A6T","A7T","x","y","z"]
    merged_df = pd.DataFrame(columns=columns)

    curr_dz = float(csv_block[0].split("_dz")[1].split("/")[0]) # extract current z-height of dataset
    for _, sensor_file in enumerate(csv_block):
        data_list = [] # create a list to store the data

        curr_sensor = sensor_file.split("_")[-1].split(".")[0]  # extract current sensor's name in dataset

        df = pd.read_csv(sensor_file,skiprows=28,sep=",",index_col=0)
        df.index = pd.to_numeric(df.index)
        df.columns = pd.to_numeric(df.columns)

        for row_label, row in df.iterrows():
            for col_label, value in row.items():
                data_list.append((value, col_label, row_label, curr_dz, curr_sensor))

        tmp_dfs.append(pd.DataFrame(data_list, columns=["data","x","y","z","sensor"]))

        for _, tmp_df in enumerate(tmp_dfs):
            sensor_name = tmp_df["sensor"][0]
            merged_df[sensor_name] = tmp_df["data"]
        merged_df["x"] = tmp_df["x"]
        merged_df["y"] = tmp_df["y"]
        merged_df["z"] = tmp_df["z"]
        
    return merged_df

# %%
def extend_array(arr: np.ndarray, n: int):
    if arr.ndim == 1:
        result = []
        result.extend([arr[0]])
        for i in range(1, len(arr)):
            diff = (arr[i] - arr[i-1]) / (n+1)
            new_elements = [arr[i-1] + j*diff for j in range(1, (n+1))]
            result.extend(new_elements)
            result.extend([arr[i]])
        return np.array(result)

    result = []
    for row in arr:
        new_row = [row[0]]
        for i in range(1, len(row)):
            diff = (row[i] - row[i-1]) / (n+1)
            new_elements = [row[i-1] + j*diff for j in range(1, (n+1))]
            new_row.extend(new_elements)
            new_row.append(row[i])
        result.append(new_row)
    return np.array(result)

# %%
csv_files = []
merged_df_list = []

csv_files = get_csv_paths_list(directory_path) # function call to get the filepathes of all measurement files
csv_files # jupyter print

for idx, z_height_group in enumerate(csv_files): # loop through each group of files (A4T, A5T, A6T, A7T)
    merged_df_list.append(process_csv_files(z_height_group))

final_combined_df = pd.concat(merged_df_list, ignore_index=True)
final_combined_df
# Out:
#          A4T    A5T    A6T    A7T      x       y      z
# 0      0.122  0.159  0.161  0.148  620.0 -1120.0  190.0
# 1      0.160  0.194  0.192  0.173  600.0 -1120.0  190.0
# 2      0.145  0.186  0.189  0.178  580.0 -1120.0  190.0
# 3      0.132  0.167  0.168  0.154  560.0 -1120.0  190.0
# 4      0.132  0.167  0.172  0.161  540.0 -1120.0  190.0
# ...      ...    ...    ...    ...    ...     ...    ...
# 49828  0.143  0.179  0.176  0.156 -540.0  1120.0  180.0
# 49829  0.110  0.151  0.143  0.128 -560.0  1120.0  180.0
# 49830  0.114  0.159  0.156  0.143 -580.0  1120.0  180.0
# 49831  0.157  0.192  0.187  0.167 -600.0  1120.0  180.0
# 49832  0.000  0.000  0.000  0.000 -620.0  1120.0  180.0
#
# [49833 rows x 7 columns]

# %%
final_combined_df["A4T"].max()
# Out:
# 3.934

# %% [markdown]
# ### Cuttting the Frame

# %%
# Calculate Euclidean distance
final_combined_df['distance'] = np.sqrt(final_combined_df['x']**2 + final_combined_df['y']**2)

# Filter the DataFrame based on the distance threshold
filtered_df = final_combined_df[final_combined_df['distance'] <= distance_threshold]

# Drop the 'distance' column if you don't need it anymore
filtered_df = filtered_df.drop(columns=['distance'])

# Display the filtered DataFrame
filtered_df
# Out:
#          A4T    A5T    A6T    A7T     x      y      z
# 2800   1.981  1.104  1.171  1.190  60.0 -240.0  190.0
# 2801   2.104  1.110  1.172  1.122  40.0 -240.0  190.0
# 2802   2.173  1.113  1.165  1.067  20.0 -240.0  190.0
# 2803   2.207  1.100  1.152  1.024   0.0 -240.0  190.0
# 2804   2.227  1.077  1.124  1.002 -20.0 -240.0  190.0
# ...      ...    ...    ...    ...   ...    ...    ...
# 47028  1.212  1.067  2.157  1.317  20.0  240.0  180.0
# 47029  1.226  1.093  2.141  1.326   0.0  240.0  180.0
# 47030  1.226  1.133  2.092  1.338 -20.0  240.0  180.0
# 47031  1.210  1.176  2.007  1.337 -40.0  240.0  180.0
# 47032  1.199  1.243  1.892  1.309 -60.0  240.0  180.0
#
# [3423 rows x 7 columns]

# %%
# input_data = final_combined_df[["A4T", "A5T", "A6T", "A7T"]]
input_data = filtered_df[["A4T", "A5T", "A6T", "A7T"]]
input_data
# Out:
#          A4T    A5T    A6T    A7T
# 2800   1.981  1.104  1.171  1.190
# 2801   2.104  1.110  1.172  1.122
# 2802   2.173  1.113  1.165  1.067
# 2803   2.207  1.100  1.152  1.024
# 2804   2.227  1.077  1.124  1.002
# ...      ...    ...    ...    ...
# 47028  1.212  1.067  2.157  1.317
# 47029  1.226  1.093  2.141  1.326
# 47030  1.226  1.133  2.092  1.338
# 47031  1.210  1.176  2.007  1.337
# 47032  1.199  1.243  1.892  1.309
#
# [3423 rows x 4 columns]

# %%
# target_data = final_combined_df[["x", "y"]]
target_data = filtered_df[["x", "y"]]
target_data
# Out:
#           x      y
# 2800   60.0 -240.0
# 2801   40.0 -240.0
# 2802   20.0 -240.0
# 2803    0.0 -240.0
# 2804  -20.0 -240.0
# ...     ...    ...
# 47028  20.0  240.0
# 47029   0.0  240.0
# 47030 -20.0  240.0
# 47031 -40.0  240.0
# 47032 -60.0  240.0
#
# [3423 rows x 2 columns]

# %% [markdown]
# ## Scale the dataframe

# %%
scaler_input = sklearn.preprocessing.MinMaxScaler()
scaled_input_data = scaler_input.fit_transform(input_data)
scaled_input_data.max(axis=0)
# Out:
# array([1., 1., 1., 1.])

# %%
scaler_target = sklearn.preprocessing.MinMaxScaler()
scaled_target_data = scaler_target.fit_transform(target_data)
scaled_target_data.max(axis=0)
# Out:
# array([1., 1.])

# %% [markdown]
# ## Get distribution of the datapoints

# %%
import matplotlib.pyplot as plt

percentages = []
thresholds = []

for threshold in np.arange(0.05, 1, 0.05):
    thresholds.append(threshold)
    filtered_arr = scaled_input_data[scaled_input_data >= threshold]
    percentage = len(filtered_arr) / scaled_input_data.size * 100
    percentages.append(percentage)
    # print(f"Threshold: {threshold:.2f}, Percentage: {percentage:.2f}%")

plt.bar(thresholds, percentages, width= 0.025)
plt.show()

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dropout, Input, Activation, Dense
from keras.initializers import HeUniform
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.losses import MeanSquaredError

# %%
import metrics
import datetime
import time

# %% [markdown]
# ## Generating training and testing data

# %%
input_tensor = tf.convert_to_tensor(scaled_input_data)
target_tensor = tf.convert_to_tensor(scaled_target_data)
n_features = 4

# %%
# Create a dataset with the input and target tensors
dataset = tf.data.Dataset.from_tensor_slices((input_tensor, target_tensor))

# Shuffle the dataset with a buffer size of the number of samples
buffer_size = input_tensor.shape[0]
shuffled_dataset = dataset.shuffle(buffer_size)

# Extract the shuffled input and target tensors from the shuffled dataset
input_tensor, target_tensor = next(iter(shuffled_dataset.batch(buffer_size)))

input_dataset = tf.data.Dataset.from_tensor_slices(input_data)
target_dataset = tf.data.Dataset.from_tensor_slices(target_tensor)

print(input_tensor.shape)
# Out:
# (3423, 4)

# %%
# # split the data and labels into training and testing sets
# train_size = int(0.7 * len(input_tensor)) # 80% of data for training
# train_data, test_data = tf.split(input_tensor, [train_size, len(input_tensor)-train_size], axis=0)
# train_labels, test_labels = tf.split(target_tensor, [train_size, len(target_tensor)-train_size], axis=0)
# print(train_data.shape, train_labels.shape)

buffer_size = input_tensor.shape[0]
indices = np.arange(buffer_size)
np.random.shuffle(indices)

# Define the sizes for training, validation, and test sets
train_size = int(0.7 * buffer_size)  # 70% of data for training
val_size = int(0.15 * buffer_size)   # 15% of data for validation
test_size = buffer_size - train_size - val_size  # Rest for testing

# Split the shuffled indices into training, validation, and test sets
train_indices = indices[:train_size]
val_indices = indices[train_size:train_size + val_size]
test_indices = indices[train_size + val_size:]

# Convert the indices to TensorFlow tensors
train_indices = tf.convert_to_tensor(train_indices, dtype=tf.int32)
val_indices = tf.convert_to_tensor(val_indices, dtype=tf.int32)
test_indices = tf.convert_to_tensor(test_indices, dtype=tf.int32)

# Use the indices to create tensors for training, validation, and test sets
train_data = tf.gather(input_tensor, train_indices)
train_labels = tf.gather(target_tensor, train_indices)

val_data = tf.gather(input_tensor, val_indices)
val_labels = tf.gather(target_tensor, val_indices)

test_data = tf.gather(input_tensor, test_indices)
test_labels = tf.gather(target_tensor, test_indices)

# %% [markdown]
# ## Building the model

# %%
n_hidden = 1500

model = Sequential()
model.add(Input(shape= (n_features), name='Dense_Input'))
# model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_1'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_1'))
model.add(Activation('relu', name='relu_1'))
model.add(Dropout(rate=0.2, name='dropout_1'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_2'))
model.add(Activation('relu', name='relu_2'))
model.add(Dropout(rate=0.2, name='dropout_2'))
# model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_3'))
# model.add(Activation('relu', name='relu_3'))
# model.add(Dropout(rate=0.2, name='dropout_3'))
# model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_4'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_4'))
model.add(Activation('relu', name='relu_4'))
model.add(Dense(2, name='Dense_Out'))
model.add(Activation('sigmoid', name='sigmoid_Out'))

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_1 (Dense)             (None, 1500)              7500
#
#  relu_1 (Activation)         (None, 1500)              0
#
#  dropout_1 (Dropout)         (None, 1500)              0
#
#  Dense_2 (Dense)             (None, 1500)              2251500
#
#  relu_2 (Activation)         (None, 1500)              0
#
#  dropout_2 (Dropout)         (None, 1500)              0
#
#  Dense_4 (Dense)             (None, 1500)              2251500
#
#  relu_4 (Activation)         (None, 1500)              0
#
#  Dense_Out (Dense)           (None, 2)                 3002
#
#  sigmoid_Out (Activation)    (None, 2)                 0
#
# =================================================================
# Total params: 4,513,502
# Trainable params: 4,513,502
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
import math
# Define configuration parameters
start_lr = 0.0001
rampup_epochs = 40
exp_decay = 0.05

# Define the scheduling function
def scheduler(epoch):
  def lr(epoch, start_lr, rampup_epochs, exp_decay):
    if epoch < rampup_epochs:
      return start_lr
    else:
      return start_lr * math.exp(-exp_decay * epoch)
  return lr(epoch, start_lr, rampup_epochs, exp_decay)

# %%
optimizer = Adam()
loss = MeanSquaredError()

timestamp = time.time()
datetime_obj = datetime.datetime.fromtimestamp(timestamp)
# Format the datetime object as a string in your desired format
readable_time = datetime_obj.strftime('%Y-%m-%d %H:%M:%S')

mcp_save = ModelCheckpoint(f'MLP-DataRange_{distance_threshold}_mse_{readable_time}.h5', 
                           save_best_only=True,
                           monitor='val_mse', 
                           mode='min')

learning_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
model.compile(optimizer=optimizer, 
                loss="mse",
                metrics=["mse", metrics.CenterMeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYSquarredErrorRealWorld(scaler=scaler_target),  
                                metrics.MeanXYAbsoluteErrorRealWorld(scaler=scaler_target),
                                metrics.MeanXYRootSquarredErrorRealWorld(scaler=scaler_target)]
)

# %%
history = model.fit(
    x = train_data,
    y = train_labels, 
    epochs = 200,
    validation_data = [val_data, val_labels],
    callbacks = [learning_callback, mcp_save]
)
# Out:
# Epoch 1/200
# 2023-09-25 19:39:55.118366: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 75/75 [==============================] - ETA: 0s - loss: 0.0252 - mse: 0.0252 - centernormXYReal: 82.8991 - normXYReal: 89.6190 - mseXYReal: 5816.3545 - maeXYReal: 56.6894 - rmseXYReal: 76.2650
# 2023-09-25 19:39:58.432177: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 75/75 [==============================] - 4s 48ms/step - loss: 0.0252 - mse: 0.0252 - centernormXYReal: 82.8991 - normXYReal: 89.6190 - mseXYReal: 5816.3545 - maeXYReal: 56.6894 - rmseXYReal: 76.2650 - val_loss: 0.0100 - val_mse: 0.0100 - val_centernormXYReal: 42.5779 - val_normXYReal: 58.5686 - val_mseXYReal: 2310.9614 - val_maeXYReal: 36.8397 - val_rmseXYReal: 48.0725 - lr: 1.0000e-04
# Epoch 2/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0145 - mse: 0.0145 - centernormXYReal: 58.5641 - normXYReal: 69.4696 - mseXYReal: 3341.7888 - maeXYReal: 43.4950 - rmseXYReal: 57.8082 - val_loss: 0.0084 - val_mse: 0.0084 - val_centernormXYReal: 34.8022 - val_normXYReal: 53.8126 - val_mseXYReal: 1941.3448 - val_maeXYReal: 34.0334 - val_rmseXYReal: 44.0607 - lr: 1.0000e-04
# Epoch 3/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0113 - mse: 0.0113 - centernormXYReal: 46.4082 - normXYReal: 61.3169 - mseXYReal: 2607.7327 - maeXYReal: 38.2347 - rmseXYReal: 51.0660 - val_loss: 0.0078 - val_mse: 0.0078 - val_centernormXYReal: 32.5705 - val_normXYReal: 51.3660 - val_mseXYReal: 1802.5510 - val_maeXYReal: 32.2221 - val_rmseXYReal: 42.4565 - lr: 1.0000e-04
# Epoch 4/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0105 - mse: 0.0105 - centernormXYReal: 43.2445 - normXYReal: 58.8904 - mseXYReal: 2430.2937 - maeXYReal: 36.5945 - rmseXYReal: 49.2980 - val_loss: 0.0082 - val_mse: 0.0082 - val_centernormXYReal: 48.3423 - val_normXYReal: 52.1385 - val_mseXYReal: 1885.1257 - val_maeXYReal: 32.5933 - val_rmseXYReal: 43.4180 - lr: 1.0000e-04
# Epoch 5/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0102 - mse: 0.0102 - centernormXYReal: 47.9168 - normXYReal: 57.3912 - mseXYReal: 2355.9548 - maeXYReal: 35.4990 - rmseXYReal: 48.5382 - val_loss: 0.0080 - val_mse: 0.0080 - val_centernormXYReal: 38.4542 - val_normXYReal: 50.7545 - val_mseXYReal: 1834.7037 - val_maeXYReal: 31.2610 - val_rmseXYReal: 42.8334 - lr: 1.0000e-04
# Epoch 6/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0098 - mse: 0.0098 - centernormXYReal: 45.8481 - normXYReal: 56.2546 - mseXYReal: 2249.6335 - maeXYReal: 34.9521 - rmseXYReal: 47.4303 - val_loss: 0.0064 - val_mse: 0.0064 - val_centernormXYReal: 29.7465 - val_normXYReal: 46.2176 - val_mseXYReal: 1473.8311 - val_maeXYReal: 28.9563 - val_rmseXYReal: 38.3905 - lr: 1.0000e-04
# Epoch 7/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0093 - mse: 0.0093 - centernormXYReal: 46.9028 - normXYReal: 54.5448 - mseXYReal: 2136.0256 - maeXYReal: 33.6429 - rmseXYReal: 46.2172 - val_loss: 0.0064 - val_mse: 0.0064 - val_centernormXYReal: 29.0766 - val_normXYReal: 46.1348 - val_mseXYReal: 1485.0895 - val_maeXYReal: 28.6095 - val_rmseXYReal: 38.5369 - lr: 1.0000e-04
# Epoch 8/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0089 - mse: 0.0089 - centernormXYReal: 43.6224 - normXYReal: 53.3126 - mseXYReal: 2058.6169 - maeXYReal: 32.9220 - rmseXYReal: 45.3720 - val_loss: 0.0067 - val_mse: 0.0067 - val_centernormXYReal: 42.0696 - val_normXYReal: 47.1561 - val_mseXYReal: 1547.9751 - val_maeXYReal: 29.0955 - val_rmseXYReal: 39.3443 - lr: 1.0000e-04
# Epoch 9/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0088 - mse: 0.0088 - centernormXYReal: 41.5535 - normXYReal: 52.5150 - mseXYReal: 2021.9359 - maeXYReal: 32.4498 - rmseXYReal: 44.9659 - val_loss: 0.0075 - val_mse: 0.0075 - val_centernormXYReal: 35.2490 - val_normXYReal: 49.6567 - val_mseXYReal: 1731.6937 - val_maeXYReal: 30.3802 - val_rmseXYReal: 41.6136 - lr: 1.0000e-04
# Epoch 10/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0083 - mse: 0.0083 - centernormXYReal: 40.8512 - normXYReal: 51.0589 - mseXYReal: 1905.0140 - maeXYReal: 31.5319 - rmseXYReal: 43.6465 - val_loss: 0.0060 - val_mse: 0.0060 - val_centernormXYReal: 30.0049 - val_normXYReal: 44.1538 - val_mseXYReal: 1372.1066 - val_maeXYReal: 27.2887 - val_rmseXYReal: 37.0420 - lr: 1.0000e-04
# Epoch 11/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0082 - mse: 0.0082 - centernormXYReal: 42.0437 - normXYReal: 50.6282 - mseXYReal: 1879.1298 - maeXYReal: 31.3048 - rmseXYReal: 43.3489 - val_loss: 0.0066 - val_mse: 0.0066 - val_centernormXYReal: 31.0879 - val_normXYReal: 46.6318 - val_mseXYReal: 1509.2484 - val_maeXYReal: 28.7349 - val_rmseXYReal: 38.8490 - lr: 1.0000e-04
# Epoch 12/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0081 - mse: 0.0081 - centernormXYReal: 36.9234 - normXYReal: 50.7255 - mseXYReal: 1874.9098 - maeXYReal: 31.2615 - rmseXYReal: 43.3002 - val_loss: 0.0063 - val_mse: 0.0063 - val_centernormXYReal: 28.9361 - val_normXYReal: 45.3354 - val_mseXYReal: 1449.4296 - val_maeXYReal: 28.1586 - val_rmseXYReal: 38.0714 - lr: 1.0000e-04
# Epoch 13/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0077 - mse: 0.0077 - centernormXYReal: 37.8979 - normXYReal: 49.1304 - mseXYReal: 1780.0018 - maeXYReal: 30.3342 - rmseXYReal: 42.1901 - val_loss: 0.0063 - val_mse: 0.0063 - val_centernormXYReal: 33.2440 - val_normXYReal: 45.2589 - val_mseXYReal: 1448.9924 - val_maeXYReal: 27.7191 - val_rmseXYReal: 38.0656 - lr: 1.0000e-04
# Epoch 14/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0078 - mse: 0.0078 - centernormXYReal: 38.4688 - normXYReal: 49.2336 - mseXYReal: 1794.2173 - maeXYReal: 30.2304 - rmseXYReal: 42.3582 - val_loss: 0.0058 - val_mse: 0.0058 - val_centernormXYReal: 29.3805 - val_normXYReal: 43.7240 - val_mseXYReal: 1331.6946 - val_maeXYReal: 27.1377 - val_rmseXYReal: 36.4924 - lr: 1.0000e-04
# Epoch 15/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0076 - mse: 0.0076 - centernormXYReal: 43.7881 - normXYReal: 49.1302 - mseXYReal: 1749.8013 - maeXYReal: 30.4861 - rmseXYReal: 41.8306 - val_loss: 0.0062 - val_mse: 0.0062 - val_centernormXYReal: 33.7416 - val_normXYReal: 44.2884 - val_mseXYReal: 1417.6207 - val_maeXYReal: 27.0269 - val_rmseXYReal: 37.6513 - lr: 1.0000e-04
# Epoch 16/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0072 - mse: 0.0072 - centernormXYReal: 35.8452 - normXYReal: 47.6762 - mseXYReal: 1666.2736 - maeXYReal: 29.4508 - rmseXYReal: 40.8200 - val_loss: 0.0057 - val_mse: 0.0057 - val_centernormXYReal: 31.2744 - val_normXYReal: 43.8428 - val_mseXYReal: 1323.5165 - val_maeXYReal: 27.0009 - val_rmseXYReal: 36.3802 - lr: 1.0000e-04
# Epoch 17/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0081 - mse: 0.0081 - centernormXYReal: 39.7790 - normXYReal: 50.7606 - mseXYReal: 1862.4092 - maeXYReal: 31.3222 - rmseXYReal: 43.1556 - val_loss: 0.0057 - val_mse: 0.0057 - val_centernormXYReal: 28.9151 - val_normXYReal: 43.5534 - val_mseXYReal: 1314.2714 - val_maeXYReal: 26.9023 - val_rmseXYReal: 36.2529 - lr: 1.0000e-04
# Epoch 18/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0073 - mse: 0.0073 - centernormXYReal: 34.0660 - normXYReal: 47.4712 - mseXYReal: 1677.7611 - maeXYReal: 29.2183 - rmseXYReal: 40.9605 - val_loss: 0.0059 - val_mse: 0.0059 - val_centernormXYReal: 31.1506 - val_normXYReal: 43.4637 - val_mseXYReal: 1352.9955 - val_maeXYReal: 26.5163 - val_rmseXYReal: 36.7831 - lr: 1.0000e-04
# Epoch 19/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0072 - mse: 0.0072 - centernormXYReal: 38.0484 - normXYReal: 47.1953 - mseXYReal: 1661.7919 - maeXYReal: 29.1107 - rmseXYReal: 40.7651 - val_loss: 0.0058 - val_mse: 0.0058 - val_centernormXYReal: 37.3145 - val_normXYReal: 44.6901 - val_mseXYReal: 1343.2856 - val_maeXYReal: 27.2955 - val_rmseXYReal: 36.6509 - lr: 1.0000e-04
# Epoch 20/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0069 - mse: 0.0069 - centernormXYReal: 36.1142 - normXYReal: 46.0754 - mseXYReal: 1580.6998 - maeXYReal: 28.4256 - rmseXYReal: 39.7580 - val_loss: 0.0058 - val_mse: 0.0058 - val_centernormXYReal: 29.0994 - val_normXYReal: 43.1114 - val_mseXYReal: 1346.6562 - val_maeXYReal: 26.5202 - val_rmseXYReal: 36.6968 - lr: 1.0000e-04
# Epoch 21/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0069 - mse: 0.0069 - centernormXYReal: 36.6151 - normXYReal: 46.2297 - mseXYReal: 1587.2837 - maeXYReal: 28.5068 - rmseXYReal: 39.8407 - val_loss: 0.0058 - val_mse: 0.0058 - val_centernormXYReal: 31.9425 - val_normXYReal: 44.0012 - val_mseXYReal: 1332.6355 - val_maeXYReal: 27.0959 - val_rmseXYReal: 36.5053 - lr: 1.0000e-04
# Epoch 22/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0067 - mse: 0.0067 - centernormXYReal: 34.5739 - normXYReal: 45.5196 - mseXYReal: 1538.4827 - maeXYReal: 28.1559 - rmseXYReal: 39.2235 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 30.1835 - val_normXYReal: 41.4703 - val_mseXYReal: 1224.2125 - val_maeXYReal: 25.4060 - val_rmseXYReal: 34.9887 - lr: 1.0000e-04
# Epoch 23/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0067 - mse: 0.0067 - centernormXYReal: 36.0176 - normXYReal: 45.6133 - mseXYReal: 1534.5878 - maeXYReal: 28.1328 - rmseXYReal: 39.1738 - val_loss: 0.0058 - val_mse: 0.0058 - val_centernormXYReal: 28.6383 - val_normXYReal: 42.5825 - val_mseXYReal: 1324.8179 - val_maeXYReal: 26.0409 - val_rmseXYReal: 36.3980 - lr: 1.0000e-04
# Epoch 24/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0067 - mse: 0.0067 - centernormXYReal: 34.3869 - normXYReal: 45.6762 - mseXYReal: 1552.4987 - maeXYReal: 28.1666 - rmseXYReal: 39.4018 - val_loss: 0.0051 - val_mse: 0.0051 - val_centernormXYReal: 28.2187 - val_normXYReal: 40.8624 - val_mseXYReal: 1172.9469 - val_maeXYReal: 25.2206 - val_rmseXYReal: 34.2483 - lr: 1.0000e-04
# Epoch 25/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0067 - mse: 0.0067 - centernormXYReal: 35.9006 - normXYReal: 45.8842 - mseXYReal: 1551.5232 - maeXYReal: 28.3756 - rmseXYReal: 39.3894 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 31.5071 - val_normXYReal: 41.6794 - val_mseXYReal: 1222.7114 - val_maeXYReal: 25.8302 - val_rmseXYReal: 34.9673 - lr: 1.0000e-04
# Epoch 26/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0064 - mse: 0.0064 - centernormXYReal: 32.2425 - normXYReal: 44.2951 - mseXYReal: 1483.1692 - maeXYReal: 27.3949 - rmseXYReal: 38.5119 - val_loss: 0.0055 - val_mse: 0.0055 - val_centernormXYReal: 33.8412 - val_normXYReal: 41.9099 - val_mseXYReal: 1257.1843 - val_maeXYReal: 25.9787 - val_rmseXYReal: 35.4568 - lr: 1.0000e-04
# Epoch 27/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0063 - mse: 0.0063 - centernormXYReal: 34.1290 - normXYReal: 43.8677 - mseXYReal: 1457.2047 - maeXYReal: 27.0372 - rmseXYReal: 38.1734 - val_loss: 0.0049 - val_mse: 0.0049 - val_centernormXYReal: 27.8014 - val_normXYReal: 39.7711 - val_mseXYReal: 1132.3016 - val_maeXYReal: 24.5173 - val_rmseXYReal: 33.6497 - lr: 1.0000e-04
# Epoch 28/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0061 - mse: 0.0061 - centernormXYReal: 32.7282 - normXYReal: 43.5107 - mseXYReal: 1413.6841 - maeXYReal: 26.8835 - rmseXYReal: 37.5990 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 28.6059 - val_normXYReal: 41.0368 - val_mseXYReal: 1224.3964 - val_maeXYReal: 25.0643 - val_rmseXYReal: 34.9914 - lr: 1.0000e-04
# Epoch 29/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0062 - mse: 0.0062 - centernormXYReal: 33.2656 - normXYReal: 44.0843 - mseXYReal: 1438.6368 - maeXYReal: 27.1137 - rmseXYReal: 37.9294 - val_loss: 0.0048 - val_mse: 0.0048 - val_centernormXYReal: 26.1119 - val_normXYReal: 39.5580 - val_mseXYReal: 1111.8556 - val_maeXYReal: 24.4649 - val_rmseXYReal: 33.3445 - lr: 1.0000e-04
# Epoch 30/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0061 - mse: 0.0061 - centernormXYReal: 30.7941 - normXYReal: 43.1285 - mseXYReal: 1401.8180 - maeXYReal: 26.6409 - rmseXYReal: 37.4409 - val_loss: 0.0050 - val_mse: 0.0050 - val_centernormXYReal: 29.1571 - val_normXYReal: 39.8588 - val_mseXYReal: 1143.1096 - val_maeXYReal: 24.7257 - val_rmseXYReal: 33.8099 - lr: 1.0000e-04
# Epoch 31/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0060 - mse: 0.0060 - centernormXYReal: 34.0794 - normXYReal: 42.8290 - mseXYReal: 1380.5380 - maeXYReal: 26.4851 - rmseXYReal: 37.1556 - val_loss: 0.0047 - val_mse: 0.0047 - val_centernormXYReal: 26.5915 - val_normXYReal: 38.4586 - val_mseXYReal: 1075.3330 - val_maeXYReal: 23.6914 - val_rmseXYReal: 32.7923 - lr: 1.0000e-04
# Epoch 32/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0061 - mse: 0.0061 - centernormXYReal: 32.8576 - normXYReal: 43.0026 - mseXYReal: 1401.2761 - maeXYReal: 26.5684 - rmseXYReal: 37.4336 - val_loss: 0.0046 - val_mse: 0.0046 - val_centernormXYReal: 26.8792 - val_normXYReal: 38.0068 - val_mseXYReal: 1056.3297 - val_maeXYReal: 23.4888 - val_rmseXYReal: 32.5012 - lr: 1.0000e-04
# Epoch 33/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0059 - mse: 0.0059 - centernormXYReal: 32.4687 - normXYReal: 42.5146 - mseXYReal: 1357.6349 - maeXYReal: 26.2278 - rmseXYReal: 36.8461 - val_loss: 0.0045 - val_mse: 0.0045 - val_centernormXYReal: 25.2564 - val_normXYReal: 37.6074 - val_mseXYReal: 1039.6394 - val_maeXYReal: 23.2311 - val_rmseXYReal: 32.2434 - lr: 1.0000e-04
# Epoch 34/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0059 - mse: 0.0059 - centernormXYReal: 32.7785 - normXYReal: 42.1857 - mseXYReal: 1353.8813 - maeXYReal: 26.1014 - rmseXYReal: 36.7951 - val_loss: 0.0046 - val_mse: 0.0046 - val_centernormXYReal: 27.0367 - val_normXYReal: 38.3261 - val_mseXYReal: 1063.3746 - val_maeXYReal: 23.6518 - val_rmseXYReal: 32.6094 - lr: 1.0000e-04
# Epoch 35/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0058 - mse: 0.0058 - centernormXYReal: 33.3115 - normXYReal: 42.1047 - mseXYReal: 1341.5525 - maeXYReal: 26.0534 - rmseXYReal: 36.6272 - val_loss: 0.0049 - val_mse: 0.0049 - val_centernormXYReal: 29.1133 - val_normXYReal: 39.5198 - val_mseXYReal: 1118.0771 - val_maeXYReal: 24.6108 - val_rmseXYReal: 33.4377 - lr: 1.0000e-04
# Epoch 36/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0056 - mse: 0.0056 - centernormXYReal: 32.0284 - normXYReal: 41.4796 - mseXYReal: 1301.3196 - maeXYReal: 25.6396 - rmseXYReal: 36.0738 - val_loss: 0.0044 - val_mse: 0.0044 - val_centernormXYReal: 28.9925 - val_normXYReal: 37.5871 - val_mseXYReal: 1017.5767 - val_maeXYReal: 23.2647 - val_rmseXYReal: 31.8995 - lr: 1.0000e-04
# Epoch 37/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0056 - mse: 0.0056 - centernormXYReal: 29.7254 - normXYReal: 41.3493 - mseXYReal: 1289.8223 - maeXYReal: 25.4952 - rmseXYReal: 35.9141 - val_loss: 0.0046 - val_mse: 0.0046 - val_centernormXYReal: 28.2015 - val_normXYReal: 38.2195 - val_mseXYReal: 1056.1593 - val_maeXYReal: 23.6797 - val_rmseXYReal: 32.4986 - lr: 1.0000e-04
# Epoch 38/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0057 - mse: 0.0057 - centernormXYReal: 30.5489 - normXYReal: 41.5097 - mseXYReal: 1302.4951 - maeXYReal: 25.6096 - rmseXYReal: 36.0901 - val_loss: 0.0043 - val_mse: 0.0043 - val_centernormXYReal: 25.8152 - val_normXYReal: 37.1116 - val_mseXYReal: 995.3352 - val_maeXYReal: 22.8205 - val_rmseXYReal: 31.5489 - lr: 1.0000e-04
# Epoch 39/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0057 - mse: 0.0057 - centernormXYReal: 34.8832 - normXYReal: 41.5149 - mseXYReal: 1302.9954 - maeXYReal: 25.8035 - rmseXYReal: 36.0970 - val_loss: 0.0045 - val_mse: 0.0045 - val_centernormXYReal: 31.3626 - val_normXYReal: 37.5573 - val_mseXYReal: 1039.4861 - val_maeXYReal: 23.2474 - val_rmseXYReal: 32.2411 - lr: 1.0000e-04
# Epoch 40/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0054 - mse: 0.0054 - centernormXYReal: 30.5454 - normXYReal: 40.5652 - mseXYReal: 1247.4354 - maeXYReal: 25.1194 - rmseXYReal: 35.3191 - val_loss: 0.0043 - val_mse: 0.0043 - val_centernormXYReal: 27.6396 - val_normXYReal: 37.4691 - val_mseXYReal: 999.3672 - val_maeXYReal: 23.1086 - val_rmseXYReal: 31.6128 - lr: 1.0000e-04
# Epoch 41/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0051 - mse: 0.0051 - centernormXYReal: 28.6657 - normXYReal: 39.1881 - mseXYReal: 1182.2979 - maeXYReal: 24.2730 - rmseXYReal: 34.3846 - val_loss: 0.0041 - val_mse: 0.0041 - val_centernormXYReal: 26.1862 - val_normXYReal: 35.7081 - val_mseXYReal: 937.6862 - val_maeXYReal: 22.0811 - val_rmseXYReal: 30.6217 - lr: 1.3534e-05
# Epoch 42/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 28.0280 - normXYReal: 38.2469 - mseXYReal: 1134.6649 - maeXYReal: 23.7354 - rmseXYReal: 33.6848 - val_loss: 0.0041 - val_mse: 0.0041 - val_centernormXYReal: 23.8030 - val_normXYReal: 35.8976 - val_mseXYReal: 944.0376 - val_maeXYReal: 22.1153 - val_rmseXYReal: 30.7252 - lr: 1.2873e-05
# Epoch 43/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 25.1881 - normXYReal: 38.1534 - mseXYReal: 1116.6711 - maeXYReal: 23.6890 - rmseXYReal: 33.4166 - val_loss: 0.0041 - val_mse: 0.0041 - val_centernormXYReal: 25.8352 - val_normXYReal: 35.9239 - val_mseXYReal: 940.9450 - val_maeXYReal: 22.2630 - val_rmseXYReal: 30.6748 - lr: 1.2246e-05
# Epoch 44/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 25.7893 - normXYReal: 37.8487 - mseXYReal: 1114.2051 - maeXYReal: 23.4943 - rmseXYReal: 33.3797 - val_loss: 0.0040 - val_mse: 0.0040 - val_centernormXYReal: 25.2780 - val_normXYReal: 35.6918 - val_mseXYReal: 931.8044 - val_maeXYReal: 22.0953 - val_rmseXYReal: 30.5255 - lr: 1.1648e-05
# Epoch 45/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 26.9611 - normXYReal: 37.6092 - mseXYReal: 1095.3140 - maeXYReal: 23.3512 - rmseXYReal: 33.0955 - val_loss: 0.0040 - val_mse: 0.0040 - val_centernormXYReal: 25.3132 - val_normXYReal: 35.6042 - val_mseXYReal: 928.3346 - val_maeXYReal: 22.0449 - val_rmseXYReal: 30.4686 - lr: 1.1080e-05
# Epoch 46/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0047 - mse: 0.0047 - centernormXYReal: 24.3374 - normXYReal: 37.5296 - mseXYReal: 1085.7274 - maeXYReal: 23.2646 - rmseXYReal: 32.9504 - val_loss: 0.0040 - val_mse: 0.0040 - val_centernormXYReal: 26.3130 - val_normXYReal: 35.5023 - val_mseXYReal: 920.0556 - val_maeXYReal: 22.0381 - val_rmseXYReal: 30.3324 - lr: 1.0540e-05
# Epoch 47/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0047 - mse: 0.0047 - centernormXYReal: 25.3053 - normXYReal: 37.5422 - mseXYReal: 1091.5184 - maeXYReal: 23.3281 - rmseXYReal: 33.0381 - val_loss: 0.0040 - val_mse: 0.0040 - val_centernormXYReal: 25.4757 - val_normXYReal: 35.3171 - val_mseXYReal: 912.9343 - val_maeXYReal: 21.8393 - val_rmseXYReal: 30.2148 - lr: 1.0026e-05
# Epoch 48/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0047 - mse: 0.0047 - centernormXYReal: 24.5258 - normXYReal: 37.2374 - mseXYReal: 1074.7468 - maeXYReal: 23.1415 - rmseXYReal: 32.7833 - val_loss: 0.0040 - val_mse: 0.0040 - val_centernormXYReal: 25.9472 - val_normXYReal: 35.4363 - val_mseXYReal: 915.6689 - val_maeXYReal: 21.9377 - val_rmseXYReal: 30.2600 - lr: 9.5369e-06
# Epoch 49/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0047 - mse: 0.0047 - centernormXYReal: 23.2739 - normXYReal: 37.2833 - mseXYReal: 1080.3849 - maeXYReal: 23.1445 - rmseXYReal: 32.8692 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 25.9420 - val_normXYReal: 35.2741 - val_mseXYReal: 907.3548 - val_maeXYReal: 21.8887 - val_rmseXYReal: 30.1223 - lr: 9.0718e-06
# Epoch 50/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0047 - mse: 0.0047 - centernormXYReal: 24.6363 - normXYReal: 37.3044 - mseXYReal: 1078.6490 - maeXYReal: 23.1424 - rmseXYReal: 32.8428 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 26.2838 - val_normXYReal: 35.0535 - val_mseXYReal: 903.3099 - val_maeXYReal: 21.7549 - val_rmseXYReal: 30.0551 - lr: 8.6294e-06
# Epoch 51/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 24.4045 - normXYReal: 37.1763 - mseXYReal: 1070.4795 - maeXYReal: 23.0700 - rmseXYReal: 32.7182 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 24.8225 - val_normXYReal: 35.2163 - val_mseXYReal: 905.5392 - val_maeXYReal: 21.8389 - val_rmseXYReal: 30.0922 - lr: 8.2085e-06
# Epoch 52/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 23.5779 - normXYReal: 36.9433 - mseXYReal: 1058.0607 - maeXYReal: 22.9256 - rmseXYReal: 32.5278 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 26.0905 - val_normXYReal: 34.9470 - val_mseXYReal: 894.6530 - val_maeXYReal: 21.6890 - val_rmseXYReal: 29.9107 - lr: 7.8082e-06
# Epoch 53/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 25.6174 - normXYReal: 36.8679 - mseXYReal: 1061.2252 - maeXYReal: 22.9093 - rmseXYReal: 32.5765 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 26.4704 - val_normXYReal: 35.0336 - val_mseXYReal: 898.5939 - val_maeXYReal: 21.7049 - val_rmseXYReal: 29.9766 - lr: 7.4274e-06
# Epoch 54/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 24.5832 - normXYReal: 36.9222 - mseXYReal: 1062.8171 - maeXYReal: 22.9612 - rmseXYReal: 32.6009 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 25.7425 - val_normXYReal: 35.0930 - val_mseXYReal: 900.6799 - val_maeXYReal: 21.8083 - val_rmseXYReal: 30.0113 - lr: 7.0651e-06
# Epoch 55/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 24.3596 - normXYReal: 36.8479 - mseXYReal: 1054.7958 - maeXYReal: 22.8793 - rmseXYReal: 32.4776 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 23.7028 - val_normXYReal: 35.1846 - val_mseXYReal: 902.8370 - val_maeXYReal: 21.7567 - val_rmseXYReal: 30.0472 - lr: 6.7206e-06
# Epoch 56/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 24.3509 - normXYReal: 36.9891 - mseXYReal: 1060.9958 - maeXYReal: 22.9583 - rmseXYReal: 32.5729 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 24.9082 - val_normXYReal: 34.8572 - val_mseXYReal: 887.6861 - val_maeXYReal: 21.6360 - val_rmseXYReal: 29.7941 - lr: 6.3928e-06
# Epoch 57/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 23.9048 - normXYReal: 36.9387 - mseXYReal: 1059.3534 - maeXYReal: 22.9449 - rmseXYReal: 32.5477 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 24.8768 - val_normXYReal: 34.9715 - val_mseXYReal: 895.5370 - val_maeXYReal: 21.6820 - val_rmseXYReal: 29.9255 - lr: 6.0810e-06
# Epoch 58/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 23.6966 - normXYReal: 36.9418 - mseXYReal: 1062.4163 - maeXYReal: 22.9497 - rmseXYReal: 32.5947 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.5969 - val_normXYReal: 34.6503 - val_mseXYReal: 884.7955 - val_maeXYReal: 21.4737 - val_rmseXYReal: 29.7455 - lr: 5.7844e-06
# Epoch 59/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 24.1305 - normXYReal: 36.5151 - mseXYReal: 1034.3738 - maeXYReal: 22.6697 - rmseXYReal: 32.1617 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 25.1749 - val_normXYReal: 34.8181 - val_mseXYReal: 886.6049 - val_maeXYReal: 21.6323 - val_rmseXYReal: 29.7759 - lr: 5.5023e-06
# Epoch 60/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 24.1252 - normXYReal: 36.6313 - mseXYReal: 1047.3433 - maeXYReal: 22.7733 - rmseXYReal: 32.3627 - val_loss: 0.0039 - val_mse: 0.0039 - val_centernormXYReal: 24.9944 - val_normXYReal: 34.8138 - val_mseXYReal: 887.5561 - val_maeXYReal: 21.5869 - val_rmseXYReal: 29.7919 - lr: 5.2340e-06
# Epoch 61/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 22.6840 - normXYReal: 36.7673 - mseXYReal: 1053.3411 - maeXYReal: 22.8023 - rmseXYReal: 32.4552 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 23.7456 - val_normXYReal: 34.7341 - val_mseXYReal: 880.9969 - val_maeXYReal: 21.5505 - val_rmseXYReal: 29.6816 - lr: 4.9787e-06
# Epoch 62/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 23.8892 - normXYReal: 36.6493 - mseXYReal: 1042.7290 - maeXYReal: 22.7822 - rmseXYReal: 32.2913 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.0443 - val_normXYReal: 34.6944 - val_mseXYReal: 878.7924 - val_maeXYReal: 21.5388 - val_rmseXYReal: 29.6444 - lr: 4.7359e-06
# Epoch 63/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 23.5933 - normXYReal: 36.6293 - mseXYReal: 1043.4298 - maeXYReal: 22.7433 - rmseXYReal: 32.3022 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.8812 - val_normXYReal: 34.5229 - val_mseXYReal: 876.6472 - val_maeXYReal: 21.4313 - val_rmseXYReal: 29.6082 - lr: 4.5049e-06
# Epoch 64/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 24.8985 - normXYReal: 36.3705 - mseXYReal: 1036.1532 - maeXYReal: 22.5767 - rmseXYReal: 32.1893 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.1869 - val_normXYReal: 34.5958 - val_mseXYReal: 879.2478 - val_maeXYReal: 21.4911 - val_rmseXYReal: 29.6521 - lr: 4.2852e-06
# Epoch 65/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 24.5236 - normXYReal: 36.7059 - mseXYReal: 1048.0339 - maeXYReal: 22.8158 - rmseXYReal: 32.3734 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 23.5966 - val_normXYReal: 34.5982 - val_mseXYReal: 877.6749 - val_maeXYReal: 21.4599 - val_rmseXYReal: 29.6256 - lr: 4.0762e-06
# Epoch 66/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 24.0516 - normXYReal: 36.4589 - mseXYReal: 1036.7073 - maeXYReal: 22.6535 - rmseXYReal: 32.1979 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.6922 - val_normXYReal: 34.3609 - val_mseXYReal: 872.7106 - val_maeXYReal: 21.3235 - val_rmseXYReal: 29.5417 - lr: 3.8774e-06
# Epoch 67/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.4324 - normXYReal: 36.2445 - mseXYReal: 1024.1945 - maeXYReal: 22.5296 - rmseXYReal: 32.0030 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.7513 - val_normXYReal: 34.5341 - val_mseXYReal: 874.1762 - val_maeXYReal: 21.4661 - val_rmseXYReal: 29.5665 - lr: 3.6883e-06
# Epoch 68/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 24.1900 - normXYReal: 36.5881 - mseXYReal: 1037.1456 - maeXYReal: 22.7262 - rmseXYReal: 32.2047 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.2169 - val_normXYReal: 34.4479 - val_mseXYReal: 871.9335 - val_maeXYReal: 21.3916 - val_rmseXYReal: 29.5285 - lr: 3.5084e-06
# Epoch 69/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 23.4296 - normXYReal: 36.3960 - mseXYReal: 1032.2306 - maeXYReal: 22.6139 - rmseXYReal: 32.1283 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.9384 - val_normXYReal: 34.4826 - val_mseXYReal: 871.4352 - val_maeXYReal: 21.4289 - val_rmseXYReal: 29.5201 - lr: 3.3373e-06
# Epoch 70/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 22.5598 - normXYReal: 36.3690 - mseXYReal: 1031.2709 - maeXYReal: 22.6083 - rmseXYReal: 32.1134 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 23.6751 - val_normXYReal: 34.4773 - val_mseXYReal: 871.9135 - val_maeXYReal: 21.3919 - val_rmseXYReal: 29.5282 - lr: 3.1746e-06
# Epoch 71/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 24.0728 - normXYReal: 36.2872 - mseXYReal: 1021.8371 - maeXYReal: 22.5588 - rmseXYReal: 31.9662 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 23.8490 - val_normXYReal: 34.5136 - val_mseXYReal: 872.1167 - val_maeXYReal: 21.4038 - val_rmseXYReal: 29.5316 - lr: 3.0197e-06
# Epoch 72/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 23.4320 - normXYReal: 36.3941 - mseXYReal: 1035.1843 - maeXYReal: 22.6092 - rmseXYReal: 32.1743 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 25.3864 - val_normXYReal: 34.5842 - val_mseXYReal: 874.1100 - val_maeXYReal: 21.4643 - val_rmseXYReal: 29.5654 - lr: 2.8725e-06
# Epoch 73/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 22.9755 - normXYReal: 36.3218 - mseXYReal: 1026.5389 - maeXYReal: 22.5406 - rmseXYReal: 32.0396 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.2067 - val_normXYReal: 34.4191 - val_mseXYReal: 869.6028 - val_maeXYReal: 21.3651 - val_rmseXYReal: 29.4890 - lr: 2.7324e-06
# Epoch 74/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 24.2401 - normXYReal: 36.2348 - mseXYReal: 1022.2823 - maeXYReal: 22.5420 - rmseXYReal: 31.9732 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 23.6049 - val_normXYReal: 34.5335 - val_mseXYReal: 872.4911 - val_maeXYReal: 21.4292 - val_rmseXYReal: 29.5380 - lr: 2.5991e-06
# Epoch 75/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.8815 - normXYReal: 36.1600 - mseXYReal: 1022.4495 - maeXYReal: 22.5003 - rmseXYReal: 31.9758 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.7743 - val_normXYReal: 34.4970 - val_mseXYReal: 870.4324 - val_maeXYReal: 21.4040 - val_rmseXYReal: 29.5031 - lr: 2.4724e-06
# Epoch 76/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 24.2185 - normXYReal: 36.3113 - mseXYReal: 1027.2794 - maeXYReal: 22.5507 - rmseXYReal: 32.0512 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.3095 - val_normXYReal: 34.4277 - val_mseXYReal: 868.8557 - val_maeXYReal: 21.3859 - val_rmseXYReal: 29.4764 - lr: 2.3518e-06
# Epoch 77/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.5242 - normXYReal: 36.2182 - mseXYReal: 1018.5700 - maeXYReal: 22.4875 - rmseXYReal: 31.9150 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.2391 - val_normXYReal: 34.5087 - val_mseXYReal: 871.7808 - val_maeXYReal: 21.4117 - val_rmseXYReal: 29.5259 - lr: 2.2371e-06
# Epoch 78/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.5217 - normXYReal: 36.2508 - mseXYReal: 1023.8234 - maeXYReal: 22.5521 - rmseXYReal: 31.9972 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.2544 - val_normXYReal: 34.4702 - val_mseXYReal: 869.5496 - val_maeXYReal: 21.4148 - val_rmseXYReal: 29.4881 - lr: 2.1280e-06
# Epoch 79/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 24.0502 - normXYReal: 36.1927 - mseXYReal: 1025.2888 - maeXYReal: 22.4784 - rmseXYReal: 32.0201 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.3025 - val_normXYReal: 34.4266 - val_mseXYReal: 868.3100 - val_maeXYReal: 21.3784 - val_rmseXYReal: 29.4671 - lr: 2.0242e-06
# Epoch 80/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 24.7951 - normXYReal: 36.0040 - mseXYReal: 1013.7443 - maeXYReal: 22.3707 - rmseXYReal: 31.8394 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.3104 - val_normXYReal: 34.4080 - val_mseXYReal: 867.3944 - val_maeXYReal: 21.3757 - val_rmseXYReal: 29.4516 - lr: 1.9255e-06
# Epoch 81/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 24.7300 - normXYReal: 36.1265 - mseXYReal: 1016.3078 - maeXYReal: 22.4641 - rmseXYReal: 31.8796 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.2614 - val_normXYReal: 34.3991 - val_mseXYReal: 867.5267 - val_maeXYReal: 21.3682 - val_rmseXYReal: 29.4538 - lr: 1.8316e-06
# Epoch 82/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.8982 - normXYReal: 36.0695 - mseXYReal: 1012.5641 - maeXYReal: 22.4283 - rmseXYReal: 31.8208 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.5525 - val_normXYReal: 34.4540 - val_mseXYReal: 868.3116 - val_maeXYReal: 21.3976 - val_rmseXYReal: 29.4671 - lr: 1.7422e-06
# Epoch 83/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 24.0087 - normXYReal: 36.1477 - mseXYReal: 1017.4464 - maeXYReal: 22.4686 - rmseXYReal: 31.8974 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.4914 - val_normXYReal: 34.4194 - val_mseXYReal: 866.6938 - val_maeXYReal: 21.3838 - val_rmseXYReal: 29.4397 - lr: 1.6573e-06
# Epoch 84/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.9008 - normXYReal: 36.0289 - mseXYReal: 1013.8281 - maeXYReal: 22.3893 - rmseXYReal: 31.8407 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.5751 - val_normXYReal: 34.4230 - val_mseXYReal: 866.2005 - val_maeXYReal: 21.3788 - val_rmseXYReal: 29.4313 - lr: 1.5764e-06
# Epoch 85/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.4463 - normXYReal: 36.0087 - mseXYReal: 1017.0659 - maeXYReal: 22.4099 - rmseXYReal: 31.8915 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.5417 - val_normXYReal: 34.4028 - val_mseXYReal: 866.0797 - val_maeXYReal: 21.3619 - val_rmseXYReal: 29.4292 - lr: 1.4996e-06
# Epoch 86/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 21.5163 - normXYReal: 36.0204 - mseXYReal: 1010.4149 - maeXYReal: 22.3794 - rmseXYReal: 31.7870 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.6444 - val_normXYReal: 34.4212 - val_mseXYReal: 866.1898 - val_maeXYReal: 21.3766 - val_rmseXYReal: 29.4311 - lr: 1.4264e-06
# Epoch 87/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.4674 - normXYReal: 36.1572 - mseXYReal: 1016.5298 - maeXYReal: 22.4737 - rmseXYReal: 31.8831 - val_loss: 0.0038 - val_mse: 0.0038 - val_centernormXYReal: 24.4845 - val_normXYReal: 34.3614 - val_mseXYReal: 864.1827 - val_maeXYReal: 21.3438 - val_rmseXYReal: 29.3970 - lr: 1.3569e-06
# Epoch 88/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.6988 - normXYReal: 36.0607 - mseXYReal: 1016.3699 - maeXYReal: 22.4234 - rmseXYReal: 31.8806 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3445 - val_normXYReal: 34.3003 - val_mseXYReal: 862.5727 - val_maeXYReal: 21.3081 - val_rmseXYReal: 29.3696 - lr: 1.2907e-06
# Epoch 89/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 23.1711 - normXYReal: 35.8026 - mseXYReal: 999.8613 - maeXYReal: 22.2804 - rmseXYReal: 31.6206 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.6719 - val_normXYReal: 34.2857 - val_mseXYReal: 862.2563 - val_maeXYReal: 21.2978 - val_rmseXYReal: 29.3642 - lr: 1.2277e-06
# Epoch 90/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.6663 - normXYReal: 36.0603 - mseXYReal: 1014.6924 - maeXYReal: 22.3942 - rmseXYReal: 31.8542 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.6654 - val_normXYReal: 34.3663 - val_mseXYReal: 863.6971 - val_maeXYReal: 21.3423 - val_rmseXYReal: 29.3887 - lr: 1.1679e-06
# Epoch 91/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.3796 - normXYReal: 36.0395 - mseXYReal: 1015.2836 - maeXYReal: 22.4181 - rmseXYReal: 31.8635 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.5158 - val_normXYReal: 34.3283 - val_mseXYReal: 862.9973 - val_maeXYReal: 21.3192 - val_rmseXYReal: 29.3768 - lr: 1.1109e-06
# Epoch 92/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.5811 - normXYReal: 36.0907 - mseXYReal: 1014.3785 - maeXYReal: 22.4160 - rmseXYReal: 31.8493 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.4375 - val_normXYReal: 34.3538 - val_mseXYReal: 863.3381 - val_maeXYReal: 21.3426 - val_rmseXYReal: 29.3826 - lr: 1.0567e-06
# Epoch 93/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.9574 - normXYReal: 35.9523 - mseXYReal: 1010.7368 - maeXYReal: 22.3521 - rmseXYReal: 31.7921 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.4305 - val_normXYReal: 34.3287 - val_mseXYReal: 862.4659 - val_maeXYReal: 21.3264 - val_rmseXYReal: 29.3678 - lr: 1.0052e-06
# Epoch 94/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 24.3641 - normXYReal: 36.0603 - mseXYReal: 1012.8813 - maeXYReal: 22.4297 - rmseXYReal: 31.8258 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.5284 - val_normXYReal: 34.3610 - val_mseXYReal: 863.1157 - val_maeXYReal: 21.3455 - val_rmseXYReal: 29.3788 - lr: 9.5616e-07
# Epoch 95/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.4474 - normXYReal: 35.9906 - mseXYReal: 1011.9144 - maeXYReal: 22.3746 - rmseXYReal: 31.8106 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.2439 - val_normXYReal: 34.2898 - val_mseXYReal: 861.2009 - val_maeXYReal: 21.3108 - val_rmseXYReal: 29.3462 - lr: 9.0953e-07
# Epoch 96/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.5690 - normXYReal: 36.0221 - mseXYReal: 1012.2781 - maeXYReal: 22.3868 - rmseXYReal: 31.8163 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3748 - val_normXYReal: 34.2969 - val_mseXYReal: 861.3336 - val_maeXYReal: 21.3054 - val_rmseXYReal: 29.3485 - lr: 8.6517e-07
# Epoch 97/200
# 75/75 [==============================] - 1s 20ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.9570 - normXYReal: 35.9412 - mseXYReal: 1006.1298 - maeXYReal: 22.3302 - rmseXYReal: 31.7195 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.2813 - val_normXYReal: 34.2537 - val_mseXYReal: 859.8411 - val_maeXYReal: 21.2825 - val_rmseXYReal: 29.3230 - lr: 8.2297e-07
# Epoch 98/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 21.9301 - normXYReal: 35.9914 - mseXYReal: 1011.9633 - maeXYReal: 22.3799 - rmseXYReal: 31.8114 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.4446 - val_normXYReal: 34.2629 - val_mseXYReal: 860.0344 - val_maeXYReal: 21.2806 - val_rmseXYReal: 29.3263 - lr: 7.8284e-07
# Epoch 99/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.2260 - normXYReal: 35.9485 - mseXYReal: 1011.5308 - maeXYReal: 22.3593 - rmseXYReal: 31.8046 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3860 - val_normXYReal: 34.2772 - val_mseXYReal: 859.7800 - val_maeXYReal: 21.2979 - val_rmseXYReal: 29.3220 - lr: 7.4466e-07
# Epoch 100/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.9309 - normXYReal: 36.1096 - mseXYReal: 1012.4938 - maeXYReal: 22.4283 - rmseXYReal: 31.8197 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.4000 - val_normXYReal: 34.2904 - val_mseXYReal: 860.4355 - val_maeXYReal: 21.3081 - val_rmseXYReal: 29.3332 - lr: 7.0834e-07
# Epoch 101/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.0304 - normXYReal: 36.1578 - mseXYReal: 1015.4564 - maeXYReal: 22.4739 - rmseXYReal: 31.8662 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.4486 - val_normXYReal: 34.2806 - val_mseXYReal: 859.6490 - val_maeXYReal: 21.3020 - val_rmseXYReal: 29.3198 - lr: 6.7379e-07
# Epoch 102/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.4791 - normXYReal: 35.8262 - mseXYReal: 1008.1301 - maeXYReal: 22.3281 - rmseXYReal: 31.7511 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.4823 - val_normXYReal: 34.3028 - val_mseXYReal: 860.8112 - val_maeXYReal: 21.3120 - val_rmseXYReal: 29.3396 - lr: 6.4093e-07
# Epoch 103/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.1852 - normXYReal: 35.8963 - mseXYReal: 1006.1334 - maeXYReal: 22.3591 - rmseXYReal: 31.7196 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.4750 - val_normXYReal: 34.3102 - val_mseXYReal: 860.9995 - val_maeXYReal: 21.3162 - val_rmseXYReal: 29.3428 - lr: 6.0967e-07
# Epoch 104/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.2823 - normXYReal: 35.8928 - mseXYReal: 1007.0084 - maeXYReal: 22.3669 - rmseXYReal: 31.7334 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3837 - val_normXYReal: 34.3050 - val_mseXYReal: 860.9187 - val_maeXYReal: 21.3172 - val_rmseXYReal: 29.3414 - lr: 5.7994e-07
# Epoch 105/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.7052 - normXYReal: 35.9251 - mseXYReal: 1009.3135 - maeXYReal: 22.3349 - rmseXYReal: 31.7697 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3734 - val_normXYReal: 34.2932 - val_mseXYReal: 860.3292 - val_maeXYReal: 21.3100 - val_rmseXYReal: 29.3314 - lr: 5.5166e-07
# Epoch 106/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.8044 - normXYReal: 35.9283 - mseXYReal: 1010.0263 - maeXYReal: 22.3493 - rmseXYReal: 31.7809 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3784 - val_normXYReal: 34.2933 - val_mseXYReal: 860.4402 - val_maeXYReal: 21.3071 - val_rmseXYReal: 29.3333 - lr: 5.2475e-07
# Epoch 107/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 21.8191 - normXYReal: 35.8440 - mseXYReal: 1005.8032 - maeXYReal: 22.2958 - rmseXYReal: 31.7144 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.2889 - val_normXYReal: 34.2664 - val_mseXYReal: 859.7198 - val_maeXYReal: 21.2932 - val_rmseXYReal: 29.3210 - lr: 4.9916e-07
# Epoch 108/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.5904 - normXYReal: 36.0415 - mseXYReal: 1015.1154 - maeXYReal: 22.4012 - rmseXYReal: 31.8609 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3929 - val_normXYReal: 34.2929 - val_mseXYReal: 859.9575 - val_maeXYReal: 21.3080 - val_rmseXYReal: 29.3250 - lr: 4.7482e-07
# Epoch 109/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.6054 - normXYReal: 35.9022 - mseXYReal: 1011.9584 - maeXYReal: 22.3586 - rmseXYReal: 31.8113 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3655 - val_normXYReal: 34.2855 - val_mseXYReal: 859.5546 - val_maeXYReal: 21.3049 - val_rmseXYReal: 29.3182 - lr: 4.5166e-07
# Epoch 110/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.5913 - normXYReal: 35.8880 - mseXYReal: 1005.8358 - maeXYReal: 22.3317 - rmseXYReal: 31.7149 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.2914 - val_normXYReal: 34.2641 - val_mseXYReal: 859.3647 - val_maeXYReal: 21.2916 - val_rmseXYReal: 29.3149 - lr: 4.2963e-07
# Epoch 111/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.5175 - normXYReal: 35.8197 - mseXYReal: 1005.0357 - maeXYReal: 22.2751 - rmseXYReal: 31.7023 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3846 - val_normXYReal: 34.2780 - val_mseXYReal: 859.5425 - val_maeXYReal: 21.3011 - val_rmseXYReal: 29.3180 - lr: 4.0868e-07
# Epoch 112/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.0923 - normXYReal: 35.8938 - mseXYReal: 1006.9266 - maeXYReal: 22.3429 - rmseXYReal: 31.7321 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3735 - val_normXYReal: 34.2613 - val_mseXYReal: 858.9667 - val_maeXYReal: 21.2906 - val_rmseXYReal: 29.3081 - lr: 3.8875e-07
# Epoch 113/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.8713 - normXYReal: 35.9205 - mseXYReal: 1009.3751 - maeXYReal: 22.3295 - rmseXYReal: 31.7707 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.4147 - val_normXYReal: 34.2694 - val_mseXYReal: 859.1529 - val_maeXYReal: 21.2943 - val_rmseXYReal: 29.3113 - lr: 3.6979e-07
# Epoch 114/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.6885 - normXYReal: 35.8770 - mseXYReal: 1007.7384 - maeXYReal: 22.3101 - rmseXYReal: 31.7449 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3474 - val_normXYReal: 34.2556 - val_mseXYReal: 858.8925 - val_maeXYReal: 21.2869 - val_rmseXYReal: 29.3069 - lr: 3.5175e-07
# Epoch 115/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.4402 - normXYReal: 35.9933 - mseXYReal: 1013.5925 - maeXYReal: 22.3991 - rmseXYReal: 31.8370 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3103 - val_normXYReal: 34.2526 - val_mseXYReal: 859.0563 - val_maeXYReal: 21.2879 - val_rmseXYReal: 29.3097 - lr: 3.3460e-07
# Epoch 116/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.4266 - normXYReal: 35.8978 - mseXYReal: 1006.5040 - maeXYReal: 22.3263 - rmseXYReal: 31.7254 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3102 - val_normXYReal: 34.2563 - val_mseXYReal: 859.1028 - val_maeXYReal: 21.2903 - val_rmseXYReal: 29.3105 - lr: 3.1828e-07
# Epoch 117/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.0335 - normXYReal: 35.8906 - mseXYReal: 1010.7280 - maeXYReal: 22.3247 - rmseXYReal: 31.7919 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3494 - val_normXYReal: 34.2570 - val_mseXYReal: 859.1567 - val_maeXYReal: 21.2885 - val_rmseXYReal: 29.3114 - lr: 3.0276e-07
# Epoch 118/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.8564 - normXYReal: 35.9143 - mseXYReal: 1007.1008 - maeXYReal: 22.3229 - rmseXYReal: 31.7349 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3280 - val_normXYReal: 34.2561 - val_mseXYReal: 858.7713 - val_maeXYReal: 21.2914 - val_rmseXYReal: 29.3048 - lr: 2.8799e-07
# Epoch 119/200
# ...
# Epoch 162/200
# 75/75 [==============================] - 1s 20ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.6409 - normXYReal: 35.8183 - mseXYReal: 1005.3472 - maeXYReal: 22.2704 - rmseXYReal: 31.7072 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3379 - val_normXYReal: 34.2384 - val_mseXYReal: 857.7646 - val_maeXYReal: 21.2808 - val_rmseXYReal: 29.2876 - lr: 3.1910e-08
# Epoch 163/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 23.1580 - normXYReal: 35.8298 - mseXYReal: 999.8970 - maeXYReal: 22.3038 - rmseXYReal: 31.6211 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3368 - val_normXYReal: 34.2390 - val_mseXYReal: 857.7825 - val_maeXYReal: 21.2811 - val_rmseXYReal: 29.2879 - lr: 3.0354e-08
# Epoch 164/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.6577 - normXYReal: 35.8089 - mseXYReal: 1006.0989 - maeXYReal: 22.2576 - rmseXYReal: 31.7191 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3352 - val_normXYReal: 34.2388 - val_mseXYReal: 857.7702 - val_maeXYReal: 21.2811 - val_rmseXYReal: 29.2877 - lr: 2.8874e-08
# Epoch 165/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.4268 - normXYReal: 35.9938 - mseXYReal: 1010.6476 - maeXYReal: 22.4062 - rmseXYReal: 31.7907 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3376 - val_normXYReal: 34.2399 - val_mseXYReal: 857.7874 - val_maeXYReal: 21.2818 - val_rmseXYReal: 29.2880 - lr: 2.7465e-08
# Epoch 166/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 22.6594 - normXYReal: 35.6312 - mseXYReal: 996.5087 - maeXYReal: 22.1849 - rmseXYReal: 31.5675 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3442 - val_normXYReal: 34.2409 - val_mseXYReal: 857.7998 - val_maeXYReal: 21.2821 - val_rmseXYReal: 29.2882 - lr: 2.6126e-08
# Epoch 167/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.7968 - normXYReal: 35.9483 - mseXYReal: 1007.2499 - maeXYReal: 22.3776 - rmseXYReal: 31.7372 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3398 - val_normXYReal: 34.2403 - val_mseXYReal: 857.7711 - val_maeXYReal: 21.2820 - val_rmseXYReal: 29.2877 - lr: 2.4852e-08
# Epoch 168/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.3600 - normXYReal: 35.8460 - mseXYReal: 1013.8638 - maeXYReal: 22.2851 - rmseXYReal: 31.8412 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3432 - val_normXYReal: 34.2408 - val_mseXYReal: 857.7828 - val_maeXYReal: 21.2822 - val_rmseXYReal: 29.2879 - lr: 2.3640e-08
# Epoch 169/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 23.8388 - normXYReal: 35.7233 - mseXYReal: 1000.8641 - maeXYReal: 22.2141 - rmseXYReal: 31.6364 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3415 - val_normXYReal: 34.2387 - val_mseXYReal: 857.7273 - val_maeXYReal: 21.2809 - val_rmseXYReal: 29.2870 - lr: 2.2487e-08
# Epoch 170/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.3274 - normXYReal: 35.9072 - mseXYReal: 1005.3131 - maeXYReal: 22.3166 - rmseXYReal: 31.7067 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3402 - val_normXYReal: 34.2388 - val_mseXYReal: 857.7212 - val_maeXYReal: 21.2810 - val_rmseXYReal: 29.2869 - lr: 2.1390e-08
# Epoch 171/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.9869 - normXYReal: 35.8647 - mseXYReal: 1006.7719 - maeXYReal: 22.3122 - rmseXYReal: 31.7297 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3413 - val_normXYReal: 34.2390 - val_mseXYReal: 857.7390 - val_maeXYReal: 21.2810 - val_rmseXYReal: 29.2872 - lr: 2.0347e-08
# Epoch 172/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.5462 - normXYReal: 35.8477 - mseXYReal: 1006.8272 - maeXYReal: 22.3018 - rmseXYReal: 31.7305 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3403 - val_normXYReal: 34.2383 - val_mseXYReal: 857.7142 - val_maeXYReal: 21.2808 - val_rmseXYReal: 29.2868 - lr: 1.9355e-08
# Epoch 173/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.1161 - normXYReal: 35.9609 - mseXYReal: 1007.2965 - maeXYReal: 22.3729 - rmseXYReal: 31.7379 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3423 - val_normXYReal: 34.2394 - val_mseXYReal: 857.7325 - val_maeXYReal: 21.2815 - val_rmseXYReal: 29.2871 - lr: 1.8411e-08
# Epoch 174/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.2958 - normXYReal: 35.9496 - mseXYReal: 1009.8556 - maeXYReal: 22.3591 - rmseXYReal: 31.7782 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3427 - val_normXYReal: 34.2388 - val_mseXYReal: 857.7436 - val_maeXYReal: 21.2809 - val_rmseXYReal: 29.2873 - lr: 1.7513e-08
# Epoch 175/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.3864 - normXYReal: 35.8154 - mseXYReal: 1003.7888 - maeXYReal: 22.2911 - rmseXYReal: 31.6826 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3464 - val_normXYReal: 34.2401 - val_mseXYReal: 857.7640 - val_maeXYReal: 21.2817 - val_rmseXYReal: 29.2876 - lr: 1.6659e-08
# Epoch 176/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.1643 - normXYReal: 35.8958 - mseXYReal: 1011.5344 - maeXYReal: 22.3431 - rmseXYReal: 31.8046 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3421 - val_normXYReal: 34.2393 - val_mseXYReal: 857.7411 - val_maeXYReal: 21.2814 - val_rmseXYReal: 29.2872 - lr: 1.5846e-08
# Epoch 177/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.5940 - normXYReal: 35.9197 - mseXYReal: 1008.4279 - maeXYReal: 22.3164 - rmseXYReal: 31.7558 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3424 - val_normXYReal: 34.2391 - val_mseXYReal: 857.7374 - val_maeXYReal: 21.2812 - val_rmseXYReal: 29.2872 - lr: 1.5073e-08
# Epoch 178/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 21.9566 - normXYReal: 35.9856 - mseXYReal: 1014.3172 - maeXYReal: 22.3807 - rmseXYReal: 31.8483 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3451 - val_normXYReal: 34.2398 - val_mseXYReal: 857.7606 - val_maeXYReal: 21.2815 - val_rmseXYReal: 29.2875 - lr: 1.4338e-08
# Epoch 179/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 23.7453 - normXYReal: 35.7183 - mseXYReal: 1001.1870 - maeXYReal: 22.2271 - rmseXYReal: 31.6415 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3435 - val_normXYReal: 34.2394 - val_mseXYReal: 857.7493 - val_maeXYReal: 21.2814 - val_rmseXYReal: 29.2874 - lr: 1.3639e-08
# Epoch 180/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 21.7178 - normXYReal: 35.7284 - mseXYReal: 1002.0516 - maeXYReal: 22.2580 - rmseXYReal: 31.6552 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3434 - val_normXYReal: 34.2394 - val_mseXYReal: 857.7486 - val_maeXYReal: 21.2814 - val_rmseXYReal: 29.2873 - lr: 1.2974e-08
# Epoch 181/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 22.6698 - normXYReal: 35.7188 - mseXYReal: 998.2428 - maeXYReal: 22.2104 - rmseXYReal: 31.5950 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3431 - val_normXYReal: 34.2394 - val_mseXYReal: 857.7535 - val_maeXYReal: 21.2814 - val_rmseXYReal: 29.2874 - lr: 1.2341e-08
# Epoch 182/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 24.5582 - normXYReal: 35.8248 - mseXYReal: 1003.1307 - maeXYReal: 22.2626 - rmseXYReal: 31.6722 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3403 - val_normXYReal: 34.2389 - val_mseXYReal: 857.7426 - val_maeXYReal: 21.2812 - val_rmseXYReal: 29.2872 - lr: 1.1739e-08
# Epoch 183/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.0521 - normXYReal: 35.8922 - mseXYReal: 1004.0338 - maeXYReal: 22.3261 - rmseXYReal: 31.6865 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3411 - val_normXYReal: 34.2392 - val_mseXYReal: 857.7503 - val_maeXYReal: 21.2813 - val_rmseXYReal: 29.2874 - lr: 1.1167e-08
# Epoch 184/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.9336 - normXYReal: 36.0046 - mseXYReal: 1008.4667 - maeXYReal: 22.4260 - rmseXYReal: 31.7564 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3407 - val_normXYReal: 34.2388 - val_mseXYReal: 857.7372 - val_maeXYReal: 21.2811 - val_rmseXYReal: 29.2872 - lr: 1.0622e-08
# Epoch 185/200
# 75/75 [==============================] - 1s 19ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.1439 - normXYReal: 35.8752 - mseXYReal: 1003.5853 - maeXYReal: 22.3413 - rmseXYReal: 31.6794 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3431 - val_normXYReal: 34.2394 - val_mseXYReal: 857.7541 - val_maeXYReal: 21.2814 - val_rmseXYReal: 29.2874 - lr: 1.0104e-08
# Epoch 186/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.9790 - normXYReal: 35.9603 - mseXYReal: 1005.7437 - maeXYReal: 22.4007 - rmseXYReal: 31.7135 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3410 - val_normXYReal: 34.2387 - val_mseXYReal: 857.7357 - val_maeXYReal: 21.2810 - val_rmseXYReal: 29.2871 - lr: 9.6112e-09
# Epoch 187/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.8184 - normXYReal: 35.8986 - mseXYReal: 1014.4909 - maeXYReal: 22.3038 - rmseXYReal: 31.8511 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3412 - val_normXYReal: 34.2391 - val_mseXYReal: 857.7462 - val_maeXYReal: 21.2813 - val_rmseXYReal: 29.2873 - lr: 9.1424e-09
# Epoch 188/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.0007 - normXYReal: 36.0712 - mseXYReal: 1013.1357 - maeXYReal: 22.4529 - rmseXYReal: 31.8298 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3420 - val_normXYReal: 34.2390 - val_mseXYReal: 857.7377 - val_maeXYReal: 21.2812 - val_rmseXYReal: 29.2872 - lr: 8.6965e-09
# Epoch 189/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.1982 - normXYReal: 35.9148 - mseXYReal: 1002.5206 - maeXYReal: 22.3609 - rmseXYReal: 31.6626 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3409 - val_normXYReal: 34.2389 - val_mseXYReal: 857.7411 - val_maeXYReal: 21.2812 - val_rmseXYReal: 29.2872 - lr: 8.2724e-09
# Epoch 190/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 22.6674 - normXYReal: 35.7612 - mseXYReal: 997.8680 - maeXYReal: 22.2322 - rmseXYReal: 31.5890 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3408 - val_normXYReal: 34.2390 - val_mseXYReal: 857.7393 - val_maeXYReal: 21.2813 - val_rmseXYReal: 29.2872 - lr: 7.8690e-09
# Epoch 191/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.8762 - normXYReal: 35.8764 - mseXYReal: 1002.7010 - maeXYReal: 22.3135 - rmseXYReal: 31.6655 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3415 - val_normXYReal: 34.2394 - val_mseXYReal: 857.7501 - val_maeXYReal: 21.2815 - val_rmseXYReal: 29.2874 - lr: 7.4852e-09
# Epoch 192/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.0670 - normXYReal: 35.8664 - mseXYReal: 1003.0908 - maeXYReal: 22.3238 - rmseXYReal: 31.6716 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3411 - val_normXYReal: 34.2391 - val_mseXYReal: 857.7438 - val_maeXYReal: 21.2813 - val_rmseXYReal: 29.2873 - lr: 7.1201e-09
# Epoch 193/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.9373 - normXYReal: 35.8511 - mseXYReal: 1006.1805 - maeXYReal: 22.3283 - rmseXYReal: 31.7204 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3416 - val_normXYReal: 34.2390 - val_mseXYReal: 857.7404 - val_maeXYReal: 21.2812 - val_rmseXYReal: 29.2872 - lr: 6.7729e-09
# Epoch 194/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 23.2991 - normXYReal: 35.8531 - mseXYReal: 1003.9465 - maeXYReal: 22.3076 - rmseXYReal: 31.6851 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3414 - val_normXYReal: 34.2388 - val_mseXYReal: 857.7347 - val_maeXYReal: 21.2811 - val_rmseXYReal: 29.2871 - lr: 6.4426e-09
# Epoch 195/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 22.0052 - normXYReal: 35.6798 - mseXYReal: 996.3797 - maeXYReal: 22.1775 - rmseXYReal: 31.5655 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3407 - val_normXYReal: 34.2389 - val_mseXYReal: 857.7339 - val_maeXYReal: 21.2812 - val_rmseXYReal: 29.2871 - lr: 6.1283e-09
# Epoch 196/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 23.1623 - normXYReal: 35.6251 - mseXYReal: 996.0718 - maeXYReal: 22.1339 - rmseXYReal: 31.5606 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3414 - val_normXYReal: 34.2389 - val_mseXYReal: 857.7355 - val_maeXYReal: 21.2811 - val_rmseXYReal: 29.2871 - lr: 5.8295e-09
# Epoch 197/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 22.2721 - normXYReal: 35.8166 - mseXYReal: 1001.1224 - maeXYReal: 22.2829 - rmseXYReal: 31.6405 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3431 - val_normXYReal: 34.2392 - val_mseXYReal: 857.7371 - val_maeXYReal: 21.2812 - val_rmseXYReal: 29.2871 - lr: 5.5452e-09
# Epoch 198/200
# 75/75 [==============================] - 1s 18ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.7628 - normXYReal: 35.8624 - mseXYReal: 1006.0694 - maeXYReal: 22.3140 - rmseXYReal: 31.7186 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3418 - val_normXYReal: 34.2389 - val_mseXYReal: 857.7315 - val_maeXYReal: 21.2811 - val_rmseXYReal: 29.2871 - lr: 5.2747e-09
# Epoch 199/200
# 75/75 [==============================] - 1s 17ms/step - loss: 0.0044 - mse: 0.0044 - centernormXYReal: 22.5977 - normXYReal: 35.8351 - mseXYReal: 1005.9667 - maeXYReal: 22.2795 - rmseXYReal: 31.7170 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3423 - val_normXYReal: 34.2390 - val_mseXYReal: 857.7327 - val_maeXYReal: 21.2812 - val_rmseXYReal: 29.2871 - lr: 5.0175e-09
# Epoch 200/200
# 75/75 [==============================] - 1s 16ms/step - loss: 0.0043 - mse: 0.0043 - centernormXYReal: 23.2437 - normXYReal: 35.7676 - mseXYReal: 997.2698 - maeXYReal: 22.2606 - rmseXYReal: 31.5796 - val_loss: 0.0037 - val_mse: 0.0037 - val_centernormXYReal: 24.3415 - val_normXYReal: 34.2388 - val_mseXYReal: 857.7260 - val_maeXYReal: 21.2811 - val_rmseXYReal: 29.2870 - lr: 4.7728e-09

# %% [markdown]
# ## Analysis of the model

# %%
plt.plot(history.history["mse"], 'b', label="mse")
plt.plot(history.history["val_mse"], 'r', label="val_mse")
plt.ylabel("mse")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["loss"], 'b', label="loss")
plt.plot(history.history["val_loss"], 'r', label="val_loss")
plt.ylabel("losses")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["centernormXYReal"], 'b', label="centernormXYReal")
plt.plot(history.history["val_centernormXYReal"], 'r', label="val_centernormXYReal")
plt.ylabel("centernormXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["normXYReal"], 'b', label="normXYReal")
plt.plot(history.history["val_normXYReal"], 'r', label="val_normXYReal")
plt.ylabel("normXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
results = model.evaluate(test_data, test_labels)
dict(zip(model.metrics_names, results))
# Out:
# 17/17 [==============================] - 0s 21ms/step - loss: 0.0040 - mse: 0.0040 - centernormXYReal: 33.2689 - normXYReal: 34.7730 - mseXYReal: 928.5331 - maeXYReal: 21.5703 - rmseXYReal: 30.4718
# {'loss': 0.004030092153698206,
#  'mse': 0.004030092153698206,
#  'centernormXYReal': 33.268856048583984,
#  'normXYReal': 34.77298355102539,
#  'mseXYReal': 928.5330810546875,
#  'maeXYReal': 21.570301055908203,
#  'rmseXYReal': 30.471839904785156}
