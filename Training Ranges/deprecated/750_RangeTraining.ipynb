# %% [markdown]
# # Preamble

# %% [markdown]
# This notebook shows the results of training with different data ranges. Due to past findings the prediction of the ai can be signifcantly better when trained on specific parts of the dataset. Here the ai has been trained on data within the range (distance) of 750 to the midpoint.

# %% [markdown]
# # Preparation of data

# %% [markdown]
# ## Setting up dataframe

# %%
import pandas as pd
import numpy as np
import glob
import os
from typing import List
import os 
import sklearn.preprocessing

# %%
HEIGHT_CONSTANT = False
directory_path = '/Users/benedictkunzmann/Desktop/Bachelorarbeit/Verlauf/Modelle/20230902_version_3.1/01_measurement_data'

# %%
### function definition section:
def sort_key(file_path): # define a custom sorting key function to sort filenames alphabetically
    """ notes here """
    
    file_name = os.path.basename(file_path)
    
    return file_name

def get_csv_paths_list(directory_path: str):
    """ notes:
        this function is meant to list all A4T-, A5T-, A6T- and A7T-measurement files
         for different coil-coil-distances in form of her absolute filepathes."""

    csv_files = []

    parPath = os.getcwd()
    dataFolder = directory_path
    dataPath = os.path.join(parPath, dataFolder)

    subfolders = [f.path for f in os.scandir(dataPath) if f.is_dir()]

    for folder in subfolders:
        files_in_dir = glob.glob(os.path.join(folder, "*.csv"))
        sorted_files = sorted(files_in_dir, key=sort_key)
        csv_files.append(sorted_files)

    csv_files = csv_files[0:-1]

    return csv_files

def process_csv_files(csv_block: List[str]) -> pd.DataFrame:
    """ notes:
        parameter csv_block needs to be a list of 4 filepath strings.
        those strings refer to 4 different measurement files of sensors
         A4T, A5T, A6T and A7T.
        for a different height (coil-coil-distance) another csv_block
         has to be passed in.
        this function returns a combined/merged pd.dataframe in which
         the structure is ["A4T","A5T","A6T","A7T","x","y","z"], 
         thus all XxY-grids within each individual measurment file
         are flattened."""

    tmp_dfs = []
    columns = ["A4T","A5T","A6T","A7T","x","y","z"]
    merged_df = pd.DataFrame(columns=columns)

    curr_dz = float(csv_block[0].split("_dz")[1].split("/")[0]) # extract current z-height of dataset
    for _, sensor_file in enumerate(csv_block):
        data_list = [] # create a list to store the data

        curr_sensor = sensor_file.split("_")[-1].split(".")[0]  # extract current sensor's name in dataset

        df = pd.read_csv(sensor_file,skiprows=28,sep=",",index_col=0)
        df.index = pd.to_numeric(df.index)
        df.columns = pd.to_numeric(df.columns)

        for row_label, row in df.iterrows():
            for col_label, value in row.items():
                data_list.append((value, col_label, row_label, curr_dz, curr_sensor))

        tmp_dfs.append(pd.DataFrame(data_list, columns=["data","x","y","z","sensor"]))

        for _, tmp_df in enumerate(tmp_dfs):
            sensor_name = tmp_df["sensor"][0]
            merged_df[sensor_name] = tmp_df["data"]
        merged_df["x"] = tmp_df["x"]
        merged_df["y"] = tmp_df["y"]
        merged_df["z"] = tmp_df["z"]
        
    return merged_df

# %%
def extend_array(arr: np.ndarray, n: int):
    if arr.ndim == 1:
        result = []
        result.extend([arr[0]])
        for i in range(1, len(arr)):
            diff = (arr[i] - arr[i-1]) / (n+1)
            new_elements = [arr[i-1] + j*diff for j in range(1, (n+1))]
            result.extend(new_elements)
            result.extend([arr[i]])
        return np.array(result)

    result = []
    for row in arr:
        new_row = [row[0]]
        for i in range(1, len(row)):
            diff = (row[i] - row[i-1]) / (n+1)
            new_elements = [row[i-1] + j*diff for j in range(1, (n+1))]
            new_row.extend(new_elements)
            new_row.append(row[i])
        result.append(new_row)
    return np.array(result)

# %%
csv_files = []
merged_df_list = []

csv_files = get_csv_paths_list(directory_path) # function call to get the filepathes of all measurement files
csv_files # jupyter print

for idx, z_height_group in enumerate(csv_files): # loop through each group of files (A4T, A5T, A6T, A7T)
    merged_df_list.append(process_csv_files(z_height_group))

final_combined_df = pd.concat(merged_df_list, ignore_index=True)
final_combined_df
# Out:
#          A4T    A5T    A6T    A7T      x       y      z
# 0      0.122  0.159  0.161  0.148  620.0 -1120.0  190.0
# 1      0.160  0.194  0.192  0.173  600.0 -1120.0  190.0
# 2      0.145  0.186  0.189  0.178  580.0 -1120.0  190.0
# 3      0.132  0.167  0.168  0.154  560.0 -1120.0  190.0
# 4      0.132  0.167  0.172  0.161  540.0 -1120.0  190.0
# ...      ...    ...    ...    ...    ...     ...    ...
# 49828  0.143  0.179  0.176  0.156 -540.0  1120.0  180.0
# 49829  0.110  0.151  0.143  0.128 -560.0  1120.0  180.0
# 49830  0.114  0.159  0.156  0.143 -580.0  1120.0  180.0
# 49831  0.157  0.192  0.187  0.167 -600.0  1120.0  180.0
# 49832  0.000  0.000  0.000  0.000 -620.0  1120.0  180.0
#
# [49833 rows x 7 columns]

# %%
final_combined_df["A4T"].max()
# Out:
# 3.934

# %% [markdown]
# ### Cuttting the Frame

# %%
distance_threshold = 750

# Calculate Euclidean distance
final_combined_df['distance'] = np.sqrt(final_combined_df['x']**2 + final_combined_df['y']**2)

# Filter the DataFrame based on the distance threshold
filtered_df = final_combined_df[final_combined_df['distance'] <= distance_threshold]

# Drop the 'distance' column if you don't need it anymore
filtered_df = filtered_df.drop(columns=['distance'])

# Display the filtered DataFrame
filtered_df
# Out:
#          A4T    A5T    A6T    A7T      x      y      z
# 1222   0.293  0.183  0.780  0.662  120.0 -740.0  190.0
# 1223   0.300  0.178  0.776  0.630  100.0 -740.0  190.0
# 1224   0.317  0.200  0.775  0.601   80.0 -740.0  190.0
# 1225   0.316  0.177  0.770  0.565   60.0 -740.0  190.0
# 1226   0.322  0.172  0.764  0.548   40.0 -740.0  190.0
# ...      ...    ...    ...    ...    ...    ...    ...
# 48606  0.848  0.454  0.402  0.190  -40.0  740.0  180.0
# 48607  0.851  0.466  0.389  0.179  -60.0  740.0  180.0
# 48608  0.859  0.496  0.378  0.183  -80.0  740.0  180.0
# 48609  0.863  0.526  0.369  0.179 -100.0  740.0  180.0
# 48610  0.864  0.554  0.355  0.172 -120.0  740.0  180.0
#
# [28623 rows x 7 columns]

# %%
# input_data = final_combined_df[["A4T", "A5T", "A6T", "A7T"]]
input_data = filtered_df[["A4T", "A5T", "A6T", "A7T"]]
input_data
# Out:
#          A4T    A5T    A6T    A7T
# 1222   0.293  0.183  0.780  0.662
# 1223   0.300  0.178  0.776  0.630
# 1224   0.317  0.200  0.775  0.601
# 1225   0.316  0.177  0.770  0.565
# 1226   0.322  0.172  0.764  0.548
# ...      ...    ...    ...    ...
# 48606  0.848  0.454  0.402  0.190
# 48607  0.851  0.466  0.389  0.179
# 48608  0.859  0.496  0.378  0.183
# 48609  0.863  0.526  0.369  0.179
# 48610  0.864  0.554  0.355  0.172
#
# [28623 rows x 4 columns]

# %%
# target_data = final_combined_df[["x", "y"]]
target_data = filtered_df[["x", "y"]]
target_data
# Out:
#            x      y
# 1222   120.0 -740.0
# 1223   100.0 -740.0
# 1224    80.0 -740.0
# 1225    60.0 -740.0
# 1226    40.0 -740.0
# ...      ...    ...
# 48606  -40.0  740.0
# 48607  -60.0  740.0
# 48608  -80.0  740.0
# 48609 -100.0  740.0
# 48610 -120.0  740.0
#
# [28623 rows x 2 columns]

# %% [markdown]
# ## Scale the dataframe

# %%
scaler_input = sklearn.preprocessing.MinMaxScaler()
scaled_input_data = scaler_input.fit_transform(input_data)
scaled_input_data.max(axis=0)
# Out:
# array([1., 1., 1., 1.])

# %%
scaler_target = sklearn.preprocessing.MinMaxScaler()
scaled_target_data = scaler_target.fit_transform(target_data)
scaled_target_data.max(axis=0)
# Out:
# array([1., 1.])

# %% [markdown]
# ## Get distribution of the datapoints

# %%
import matplotlib.pyplot as plt

percentages = []
thresholds = []

for threshold in np.arange(0.05, 1, 0.05):
    thresholds.append(threshold)
    filtered_arr = scaled_input_data[scaled_input_data >= threshold]
    percentage = len(filtered_arr) / scaled_input_data.size * 100
    percentages.append(percentage)
    # print(f"Threshold: {threshold:.2f}, Percentage: {percentage:.2f}%")

plt.bar(thresholds, percentages, width= 0.025)
plt.show()

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dropout, Input, Activation, Dense
from keras.initializers import HeUniform
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.losses import MeanSquaredError

# %%
import metrics
import time

# %% [markdown]
# ## Generating training and testing data

# %%
input_tensor = tf.convert_to_tensor(scaled_input_data)
target_tensor = tf.convert_to_tensor(scaled_target_data)
n_features = 4
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2023-09-24 17:02:08.380647: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-09-24 17:02:08.380669: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Create a dataset with the input and target tensors
dataset = tf.data.Dataset.from_tensor_slices((input_tensor, target_tensor))

# Shuffle the dataset with a buffer size of the number of samples
buffer_size = input_tensor.shape[0]
shuffled_dataset = dataset.shuffle(buffer_size)

# Extract the shuffled input and target tensors from the shuffled dataset
input_tensor, target_tensor = next(iter(shuffled_dataset.batch(buffer_size)))

input_dataset = tf.data.Dataset.from_tensor_slices(input_data)
target_dataset = tf.data.Dataset.from_tensor_slices(target_tensor)

print(input_tensor.shape)
# Out:
# (28623, 4)

# %%
# # split the data and labels into training and testing sets
# train_size = int(0.7 * len(input_tensor)) # 80% of data for training
# train_data, test_data = tf.split(input_tensor, [train_size, len(input_tensor)-train_size], axis=0)
# train_labels, test_labels = tf.split(target_tensor, [train_size, len(target_tensor)-train_size], axis=0)
# print(train_data.shape, train_labels.shape)

buffer_size = input_tensor.shape[0]
indices = np.arange(buffer_size)
np.random.shuffle(indices)

# Define the sizes for training, validation, and test sets
train_size = int(0.7 * buffer_size)  # 70% of data for training
val_size = int(0.15 * buffer_size)   # 15% of data for validation
test_size = buffer_size - train_size - val_size  # Rest for testing

# Split the shuffled indices into training, validation, and test sets
train_indices = indices[:train_size]
val_indices = indices[train_size:train_size + val_size]
test_indices = indices[train_size + val_size:]

# Convert the indices to TensorFlow tensors
train_indices = tf.convert_to_tensor(train_indices, dtype=tf.int32)
val_indices = tf.convert_to_tensor(val_indices, dtype=tf.int32)
test_indices = tf.convert_to_tensor(test_indices, dtype=tf.int32)

# Use the indices to create tensors for training, validation, and test sets
train_data = tf.gather(input_tensor, train_indices)
train_labels = tf.gather(target_tensor, train_indices)

val_data = tf.gather(input_tensor, val_indices)
val_labels = tf.gather(target_tensor, val_indices)

test_data = tf.gather(input_tensor, test_indices)
test_labels = tf.gather(target_tensor, test_indices)

# %% [markdown]
# ## Building the model

# %%
n_hidden = 1024

model = Sequential()
model.add(Input(shape= (n_features), name='Dense_Input'))
model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_1'))
model.add(Activation('relu', name='relu_1'))
model.add(Dropout(rate=0.2, name='dropout_1'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_2'))
model.add(Activation('relu', name='relu_2'))
model.add(Dropout(rate=0.2, name='dropout_2'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_3'))
model.add(Activation('relu', name='relu_3'))
model.add(Dropout(rate=0.2, name='dropout_3'))
model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_4'))
model.add(Activation('relu', name='relu_4'))
model.add(Dense(2, name='Dense_Out'))
model.add(Activation('sigmoid', name='sigmoid_Out'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_1 (Dense)             (None, 512)               2560
#
#  relu_1 (Activation)         (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  Dense_2 (Dense)             (None, 1024)              525312
#
#  relu_2 (Activation)         (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  Dense_3 (Dense)             (None, 1024)              1049600
#
#  relu_3 (Activation)         (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  Dense_4 (Dense)             (None, 512)               524800
#
#  relu_4 (Activation)         (None, 512)               0
#
#  Dense_Out (Dense)           (None, 2)                 1026
#
#  sigmoid_Out (Activation)    (None, 2)                 0
#
# =================================================================
# Total params: 2,103,298
# Trainable params: 2,103,298
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
import math
# Define configuration parameters
start_lr = 0.0001
rampup_epochs = 20
exp_decay = 0.1

# Define the scheduling function
def scheduler(epoch):
  def lr(epoch, start_lr, rampup_epochs, exp_decay):
    if epoch < rampup_epochs:
      return start_lr
    else:
      return start_lr * math.exp(-exp_decay * epoch)
  return lr(epoch, start_lr, rampup_epochs, exp_decay)

# %%
optimizer = Adam()
loss = MeanSquaredError()

mcp_save = ModelCheckpoint(f'MLP-NewData-ZInput_mse_{int(time.time())}.h5', 
                           save_best_only=True,
                           monitor='val_mse', 
                           mode='min')

learning_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
model.compile(optimizer=optimizer, 
                loss="mse",
                metrics=["mse", metrics.CenterMeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYSquarredErrorRealWorld(scaler=scaler_target),  
                                metrics.MeanXYAbsoluteErrorRealWorld(scaler=scaler_target),
                                metrics.MeanXYRootSquarredErrorRealWorld(scaler=scaler_target)]
)

# %%
history = model.fit(
    x = train_data,
    y = train_labels, 
    epochs = 40,
    validation_data = [val_data, val_labels],
    callbacks = [learning_callback]
)
# Out:
# Epoch 1/40
# 2023-09-24 17:02:10.624527: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-09-24 17:02:11.137527: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 627/627 [==============================] - ETA: 0s - loss: 0.0283 - mse: 0.0283 - centernormXYReal: 409.3340 - normXYReal: 277.8643 - mseXYReal: 52362.8672 - maeXYReal: 178.3855 - rmseXYReal: 228.8293
# 2023-09-24 17:02:20.563919: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 627/627 [==============================] - 11s 16ms/step - loss: 0.0283 - mse: 0.0283 - centernormXYReal: 409.3340 - normXYReal: 277.8643 - mseXYReal: 52362.8672 - maeXYReal: 178.3855 - rmseXYReal: 228.8293 - val_loss: 0.0216 - val_mse: 0.0216 - val_centernormXYReal: 369.9171 - val_normXYReal: 235.1270 - val_mseXYReal: 39554.7578 - val_maeXYReal: 150.1964 - val_rmseXYReal: 198.8838 - lr: 1.0000e-04
# Epoch 2/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0212 - mse: 0.0212 - centernormXYReal: 312.5581 - normXYReal: 235.5273 - mseXYReal: 39210.7578 - maeXYReal: 149.8549 - rmseXYReal: 198.0171 - val_loss: 0.0186 - val_mse: 0.0186 - val_centernormXYReal: 279.5490 - val_normXYReal: 218.9050 - val_mseXYReal: 33827.5586 - val_maeXYReal: 139.8234 - val_rmseXYReal: 183.9227 - lr: 1.0000e-04
# Epoch 3/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0179 - mse: 0.0179 - centernormXYReal: 268.6260 - normXYReal: 213.1485 - mseXYReal: 32949.3711 - maeXYReal: 135.5303 - rmseXYReal: 181.5196 - val_loss: 0.0164 - val_mse: 0.0164 - val_centernormXYReal: 301.8134 - val_normXYReal: 201.1066 - val_mseXYReal: 29817.4727 - val_maeXYReal: 127.9262 - val_rmseXYReal: 172.6774 - lr: 1.0000e-04
# Epoch 4/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0157 - mse: 0.0157 - centernormXYReal: 235.5084 - normXYReal: 195.8637 - mseXYReal: 28781.1309 - maeXYReal: 124.2336 - rmseXYReal: 169.6500 - val_loss: 0.0142 - val_mse: 0.0142 - val_centernormXYReal: 235.1997 - val_normXYReal: 183.3025 - val_mseXYReal: 25917.5527 - val_maeXYReal: 116.6466 - val_rmseXYReal: 160.9893 - lr: 1.0000e-04
# Epoch 5/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0142 - mse: 0.0142 - centernormXYReal: 198.6449 - normXYReal: 183.1435 - mseXYReal: 26018.9004 - maeXYReal: 115.7796 - rmseXYReal: 161.3038 - val_loss: 0.0130 - val_mse: 0.0130 - val_centernormXYReal: 193.3364 - val_normXYReal: 172.4067 - val_mseXYReal: 23963.4180 - val_maeXYReal: 109.1628 - val_rmseXYReal: 154.8012 - lr: 1.0000e-04
# Epoch 6/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0130 - mse: 0.0130 - centernormXYReal: 192.8290 - normXYReal: 174.1600 - mseXYReal: 23920.3379 - maeXYReal: 109.8476 - rmseXYReal: 154.6620 - val_loss: 0.0116 - val_mse: 0.0116 - val_centernormXYReal: 172.8575 - val_normXYReal: 161.1234 - val_mseXYReal: 21328.1543 - val_maeXYReal: 101.8882 - val_rmseXYReal: 146.0416 - lr: 1.0000e-04
# Epoch 7/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0120 - mse: 0.0120 - centernormXYReal: 185.9772 - normXYReal: 165.5136 - mseXYReal: 22093.9590 - maeXYReal: 104.5048 - rmseXYReal: 148.6404 - val_loss: 0.0115 - val_mse: 0.0115 - val_centernormXYReal: 355.4821 - val_normXYReal: 163.5593 - val_mseXYReal: 21280.2461 - val_maeXYReal: 103.5431 - val_rmseXYReal: 145.8775 - lr: 1.0000e-04
# Epoch 8/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0112 - mse: 0.0112 - centernormXYReal: 188.2462 - normXYReal: 158.8059 - mseXYReal: 20536.6133 - maeXYReal: 100.0997 - rmseXYReal: 143.3060 - val_loss: 0.0106 - val_mse: 0.0106 - val_centernormXYReal: 172.6036 - val_normXYReal: 153.5000 - val_mseXYReal: 19425.6270 - val_maeXYReal: 97.2320 - val_rmseXYReal: 139.3759 - lr: 1.0000e-04
# Epoch 9/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0104 - mse: 0.0104 - centernormXYReal: 159.7713 - normXYReal: 152.1974 - mseXYReal: 19207.7559 - maeXYReal: 95.9426 - rmseXYReal: 138.5921 - val_loss: 0.0096 - val_mse: 0.0096 - val_centernormXYReal: 231.1314 - val_normXYReal: 144.8260 - val_mseXYReal: 17531.9473 - val_maeXYReal: 91.2582 - val_rmseXYReal: 132.4083 - lr: 1.0000e-04
# Epoch 10/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0098 - mse: 0.0098 - centernormXYReal: 184.6217 - normXYReal: 146.5452 - mseXYReal: 17962.0000 - maeXYReal: 92.5395 - rmseXYReal: 134.0224 - val_loss: 0.0090 - val_mse: 0.0090 - val_centernormXYReal: 186.0624 - val_normXYReal: 143.0569 - val_mseXYReal: 16467.2812 - val_maeXYReal: 90.4262 - val_rmseXYReal: 128.3249 - lr: 1.0000e-04
# Epoch 11/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0091 - mse: 0.0091 - centernormXYReal: 179.9966 - normXYReal: 140.4829 - mseXYReal: 16724.3242 - maeXYReal: 88.7742 - rmseXYReal: 129.3226 - val_loss: 0.0090 - val_mse: 0.0090 - val_centernormXYReal: 197.0357 - val_normXYReal: 141.5182 - val_mseXYReal: 16555.8105 - val_maeXYReal: 89.3741 - val_rmseXYReal: 128.6694 - lr: 1.0000e-04
# Epoch 12/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0085 - mse: 0.0085 - centernormXYReal: 205.8654 - normXYReal: 135.6432 - mseXYReal: 15782.3838 - maeXYReal: 85.7158 - rmseXYReal: 125.6280 - val_loss: 0.0078 - val_mse: 0.0078 - val_centernormXYReal: 154.6236 - val_normXYReal: 131.2357 - val_mseXYReal: 14345.4248 - val_maeXYReal: 83.1873 - val_rmseXYReal: 119.7724 - lr: 1.0000e-04
# Epoch 13/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0080 - mse: 0.0080 - centernormXYReal: 164.7862 - normXYReal: 130.2832 - mseXYReal: 14750.2891 - maeXYReal: 82.3801 - rmseXYReal: 121.4508 - val_loss: 0.0077 - val_mse: 0.0077 - val_centernormXYReal: 212.5781 - val_normXYReal: 129.7948 - val_mseXYReal: 14136.9023 - val_maeXYReal: 82.1118 - val_rmseXYReal: 118.8987 - lr: 1.0000e-04
# Epoch 14/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0076 - mse: 0.0076 - centernormXYReal: 162.9379 - normXYReal: 126.1974 - mseXYReal: 14015.7412 - maeXYReal: 79.8642 - rmseXYReal: 118.3881 - val_loss: 0.0069 - val_mse: 0.0069 - val_centernormXYReal: 175.3520 - val_normXYReal: 121.2824 - val_mseXYReal: 12616.2617 - val_maeXYReal: 76.5443 - val_rmseXYReal: 112.3221 - lr: 1.0000e-04
# Epoch 15/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0071 - mse: 0.0071 - centernormXYReal: 164.1738 - normXYReal: 121.8571 - mseXYReal: 13211.8965 - maeXYReal: 77.1140 - rmseXYReal: 114.9430 - val_loss: 0.0070 - val_mse: 0.0070 - val_centernormXYReal: 173.6045 - val_normXYReal: 121.8913 - val_mseXYReal: 12872.5557 - val_maeXYReal: 77.3498 - val_rmseXYReal: 113.4573 - lr: 1.0000e-04
# Epoch 16/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0069 - mse: 0.0069 - centernormXYReal: 169.4293 - normXYReal: 118.7871 - mseXYReal: 12681.8828 - maeXYReal: 75.1025 - rmseXYReal: 112.6139 - val_loss: 0.0067 - val_mse: 0.0067 - val_centernormXYReal: 151.1073 - val_normXYReal: 120.6085 - val_mseXYReal: 12494.7510 - val_maeXYReal: 76.3204 - val_rmseXYReal: 111.7799 - lr: 1.0000e-04
# Epoch 17/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0066 - mse: 0.0066 - centernormXYReal: 173.5981 - normXYReal: 115.7511 - mseXYReal: 12162.4551 - maeXYReal: 73.1893 - rmseXYReal: 110.2835 - val_loss: 0.0062 - val_mse: 0.0062 - val_centernormXYReal: 165.6365 - val_normXYReal: 114.8701 - val_mseXYReal: 11388.2188 - val_maeXYReal: 72.7443 - val_rmseXYReal: 106.7156 - lr: 1.0000e-04
# Epoch 18/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0064 - mse: 0.0064 - centernormXYReal: 157.3390 - normXYReal: 113.9547 - mseXYReal: 11934.1094 - maeXYReal: 71.9826 - rmseXYReal: 109.2433 - val_loss: 0.0061 - val_mse: 0.0061 - val_centernormXYReal: 144.8051 - val_normXYReal: 113.9419 - val_mseXYReal: 11283.4990 - val_maeXYReal: 71.8353 - val_rmseXYReal: 106.2238 - lr: 1.0000e-04
# Epoch 19/40
# 627/627 [==============================] - 10s 17ms/step - loss: 0.0061 - mse: 0.0061 - centernormXYReal: 157.4846 - normXYReal: 109.7357 - mseXYReal: 11267.8281 - maeXYReal: 69.3473 - rmseXYReal: 106.1500 - val_loss: 0.0060 - val_mse: 0.0060 - val_centernormXYReal: 186.3643 - val_normXYReal: 111.3270 - val_mseXYReal: 10940.3662 - val_maeXYReal: 70.3854 - val_rmseXYReal: 104.5962 - lr: 1.0000e-04
# Epoch 20/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0060 - mse: 0.0060 - centernormXYReal: 160.3353 - normXYReal: 108.8161 - mseXYReal: 11113.1338 - maeXYReal: 68.8380 - rmseXYReal: 105.4188 - val_loss: 0.0057 - val_mse: 0.0057 - val_centernormXYReal: 124.5385 - val_normXYReal: 110.4194 - val_mseXYReal: 10472.8105 - val_maeXYReal: 69.7969 - val_rmseXYReal: 102.3368 - lr: 1.0000e-04
# Epoch 21/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0052 - mse: 0.0052 - centernormXYReal: 140.3903 - normXYReal: 99.5286 - mseXYReal: 9707.3750 - maeXYReal: 62.9900 - rmseXYReal: 98.5260 - val_loss: 0.0055 - val_mse: 0.0055 - val_centernormXYReal: 177.9855 - val_normXYReal: 108.0582 - val_mseXYReal: 10034.0195 - val_maeXYReal: 68.3696 - val_rmseXYReal: 100.1700 - lr: 1.3534e-05
# Epoch 22/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0051 - mse: 0.0051 - centernormXYReal: 161.0495 - normXYReal: 97.0604 - mseXYReal: 9387.3467 - maeXYReal: 61.3834 - rmseXYReal: 96.8883 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 137.3539 - val_normXYReal: 104.0139 - val_mseXYReal: 9689.0674 - val_maeXYReal: 65.7403 - val_rmseXYReal: 98.4331 - lr: 1.2246e-05
# Epoch 23/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0050 - mse: 0.0050 - centernormXYReal: 149.8189 - normXYReal: 96.0622 - mseXYReal: 9332.8135 - maeXYReal: 60.7207 - rmseXYReal: 96.6065 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 143.5030 - val_normXYReal: 106.1390 - val_mseXYReal: 9913.3301 - val_maeXYReal: 67.1618 - val_rmseXYReal: 99.5657 - lr: 1.1080e-05
# Epoch 24/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 157.3227 - normXYReal: 94.8922 - mseXYReal: 9068.7334 - maeXYReal: 59.9735 - rmseXYReal: 95.2299 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 130.9298 - val_normXYReal: 105.2246 - val_mseXYReal: 9826.8613 - val_maeXYReal: 66.6212 - val_rmseXYReal: 99.1305 - lr: 1.0026e-05
# Epoch 25/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 151.0645 - normXYReal: 94.2198 - mseXYReal: 8978.8564 - maeXYReal: 59.6262 - rmseXYReal: 94.7568 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 157.4106 - val_normXYReal: 107.1659 - val_mseXYReal: 9952.3223 - val_maeXYReal: 67.7702 - val_rmseXYReal: 99.7613 - lr: 9.0718e-06
# Epoch 26/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 172.9869 - normXYReal: 93.8868 - mseXYReal: 8992.9922 - maeXYReal: 59.3733 - rmseXYReal: 94.8314 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 130.0424 - val_normXYReal: 104.4696 - val_mseXYReal: 9743.2568 - val_maeXYReal: 66.1132 - val_rmseXYReal: 98.7079 - lr: 8.2085e-06
# Epoch 27/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 134.9111 - normXYReal: 93.2158 - mseXYReal: 8871.5273 - maeXYReal: 58.9581 - rmseXYReal: 94.1888 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 159.2982 - val_normXYReal: 104.5196 - val_mseXYReal: 9755.1777 - val_maeXYReal: 66.1299 - val_rmseXYReal: 98.7683 - lr: 7.4274e-06
# Epoch 28/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 134.0990 - normXYReal: 92.6715 - mseXYReal: 8824.5146 - maeXYReal: 58.5871 - rmseXYReal: 93.9389 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 167.2890 - val_normXYReal: 105.5407 - val_mseXYReal: 9819.3398 - val_maeXYReal: 66.6840 - val_rmseXYReal: 99.0926 - lr: 6.7206e-06
# Epoch 29/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 141.3979 - normXYReal: 92.6568 - mseXYReal: 8817.7100 - maeXYReal: 58.6144 - rmseXYReal: 93.9027 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 170.2272 - val_normXYReal: 103.6728 - val_mseXYReal: 9700.8623 - val_maeXYReal: 65.6073 - val_rmseXYReal: 98.4930 - lr: 6.0810e-06
# Epoch 30/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0047 - mse: 0.0047 - centernormXYReal: 153.0692 - normXYReal: 92.1081 - mseXYReal: 8665.1523 - maeXYReal: 58.2895 - rmseXYReal: 93.0868 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 153.6443 - val_normXYReal: 104.2333 - val_mseXYReal: 9732.4902 - val_maeXYReal: 65.8830 - val_rmseXYReal: 98.6534 - lr: 5.5023e-06
# Epoch 31/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0047 - mse: 0.0047 - centernormXYReal: 144.8171 - normXYReal: 91.9070 - mseXYReal: 8678.1123 - maeXYReal: 58.1069 - rmseXYReal: 93.1564 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 136.0960 - val_normXYReal: 104.7840 - val_mseXYReal: 9770.5400 - val_maeXYReal: 66.2637 - val_rmseXYReal: 98.8460 - lr: 4.9787e-06
# Epoch 32/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0047 - mse: 0.0047 - centernormXYReal: 138.2653 - normXYReal: 91.8725 - mseXYReal: 8680.5225 - maeXYReal: 58.0811 - rmseXYReal: 93.1693 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 138.2175 - val_normXYReal: 102.8205 - val_mseXYReal: 9518.1553 - val_maeXYReal: 65.0103 - val_rmseXYReal: 97.5610 - lr: 4.5049e-06
# Epoch 33/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 157.4531 - normXYReal: 91.3028 - mseXYReal: 8583.3057 - maeXYReal: 57.7457 - rmseXYReal: 92.6461 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 148.5282 - val_normXYReal: 105.1025 - val_mseXYReal: 9786.7217 - val_maeXYReal: 66.3694 - val_rmseXYReal: 98.9279 - lr: 4.0762e-06
# Epoch 34/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 141.0711 - normXYReal: 91.1384 - mseXYReal: 8514.4648 - maeXYReal: 57.6066 - rmseXYReal: 92.2739 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 144.4106 - val_normXYReal: 103.8417 - val_mseXYReal: 9630.4619 - val_maeXYReal: 65.6309 - val_rmseXYReal: 98.1349 - lr: 3.6883e-06
# Epoch 35/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 165.2204 - normXYReal: 90.9532 - mseXYReal: 8501.7129 - maeXYReal: 57.5340 - rmseXYReal: 92.2047 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 142.6879 - val_normXYReal: 103.7464 - val_mseXYReal: 9628.4170 - val_maeXYReal: 65.5849 - val_rmseXYReal: 98.1245 - lr: 3.3373e-06
# Epoch 36/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 132.7050 - normXYReal: 90.6989 - mseXYReal: 8459.0586 - maeXYReal: 57.3901 - rmseXYReal: 91.9731 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 170.0258 - val_normXYReal: 103.8486 - val_mseXYReal: 9667.2002 - val_maeXYReal: 65.6633 - val_rmseXYReal: 98.3219 - lr: 3.0197e-06
# Epoch 37/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 130.9742 - normXYReal: 90.7912 - mseXYReal: 8522.1582 - maeXYReal: 57.4400 - rmseXYReal: 92.3155 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 157.3154 - val_normXYReal: 102.5889 - val_mseXYReal: 9516.1689 - val_maeXYReal: 64.8989 - val_rmseXYReal: 97.5508 - lr: 2.7324e-06
# Epoch 38/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0046 - mse: 0.0046 - centernormXYReal: 124.5829 - normXYReal: 90.5215 - mseXYReal: 8492.1934 - maeXYReal: 57.2527 - rmseXYReal: 92.1531 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 143.0762 - val_normXYReal: 103.5088 - val_mseXYReal: 9585.6943 - val_maeXYReal: 65.4888 - val_rmseXYReal: 97.9066 - lr: 2.4724e-06
# Epoch 39/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 147.2058 - normXYReal: 90.3010 - mseXYReal: 8401.0723 - maeXYReal: 57.1022 - rmseXYReal: 91.6574 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 150.9004 - val_normXYReal: 103.2595 - val_mseXYReal: 9557.1514 - val_maeXYReal: 65.3145 - val_rmseXYReal: 97.7607 - lr: 2.2371e-06
# Epoch 40/40
# 627/627 [==============================] - 10s 16ms/step - loss: 0.0045 - mse: 0.0045 - centernormXYReal: 122.4260 - normXYReal: 90.2482 - mseXYReal: 8441.9873 - maeXYReal: 57.0397 - rmseXYReal: 91.8803 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 161.6798 - val_normXYReal: 103.2917 - val_mseXYReal: 9573.0215 - val_maeXYReal: 65.3047 - val_rmseXYReal: 97.8418 - lr: 2.0242e-06

# %% [markdown]
# ## Analysis of the model

# %%
plt.plot(history.history["mse"], 'b', label="mse")
plt.plot(history.history["val_mse"], 'r', label="val_mse")
plt.ylabel("mse")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["loss"], 'b', label="loss")
plt.plot(history.history["val_loss"], 'r', label="val_loss")
plt.ylabel("losses")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["centernormXYReal"], 'b', label="centernormXYReal")
plt.plot(history.history["val_centernormXYReal"], 'r', label="val_centernormXYReal")
plt.ylabel("centernormXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["normXYReal"], 'b', label="normXYReal")
plt.plot(history.history["val_normXYReal"], 'r', label="val_normXYReal")
plt.ylabel("normXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
results = model.evaluate(test_data, test_labels)
dict(zip(model.metrics_names, results))
# Out:
# 135/135 [==============================] - 2s 12ms/step - loss: 0.0051 - mse: 0.0051 - centernormXYReal: 167.9562 - normXYReal: 101.2766 - mseXYReal: 9473.7178 - maeXYReal: 64.2169 - rmseXYReal: 97.3330
# {'loss': 0.005072598345577717,
#  'mse': 0.005072598345577717,
#  'centernormXYReal': 167.95623779296875,
#  'normXYReal': 101.27655792236328,
#  'mseXYReal': 9473.7177734375,
#  'maeXYReal': 64.21693420410156,
#  'rmseXYReal': 97.3330307006836}
