# %% [markdown]
# # Preamble

# %% [markdown]
# This notebook shows the results of training with different data ranges. Due to past findings the prediction of the ai can be signifcantly better when trained on specific parts of the dataset. Here the ai has been trained on data within the range (distance) of 500 to the midpoint.

# %% [markdown]
# # Preparation of data

# %% [markdown]
# ## Setting up dataframe

# %%
import pandas as pd
import numpy as np
import glob
import os
from typing import List
import os 
import sklearn.preprocessing

# %%
HEIGHT_CONSTANT = False
directory_path = '/Users/benedictkunzmann/Desktop/Bachelorarbeit/Verlauf/Modelle/20230902_version_3.1/01_measurement_data'

# %%
### function definition section:
def sort_key(file_path): # define a custom sorting key function to sort filenames alphabetically
    """ notes here """
    
    file_name = os.path.basename(file_path)
    
    return file_name

def get_csv_paths_list(directory_path: str):
    """ notes:
        this function is meant to list all A4T-, A5T-, A6T- and A7T-measurement files
         for different coil-coil-distances in form of her absolute filepathes."""

    csv_files = []

    parPath = os.getcwd()
    dataFolder = directory_path
    dataPath = os.path.join(parPath, dataFolder)

    subfolders = [f.path for f in os.scandir(dataPath) if f.is_dir()]

    for folder in subfolders:
        files_in_dir = glob.glob(os.path.join(folder, "*.csv"))
        sorted_files = sorted(files_in_dir, key=sort_key)
        csv_files.append(sorted_files)

    csv_files = csv_files[0:-1]

    return csv_files

def process_csv_files(csv_block: List[str]) -> pd.DataFrame:
    """ notes:
        parameter csv_block needs to be a list of 4 filepath strings.
        those strings refer to 4 different measurement files of sensors
         A4T, A5T, A6T and A7T.
        for a different height (coil-coil-distance) another csv_block
         has to be passed in.
        this function returns a combined/merged pd.dataframe in which
         the structure is ["A4T","A5T","A6T","A7T","x","y","z"], 
         thus all XxY-grids within each individual measurment file
         are flattened."""

    tmp_dfs = []
    columns = ["A4T","A5T","A6T","A7T","x","y","z"]
    merged_df = pd.DataFrame(columns=columns)

    curr_dz = float(csv_block[0].split("_dz")[1].split("/")[0]) # extract current z-height of dataset
    for _, sensor_file in enumerate(csv_block):
        data_list = [] # create a list to store the data

        curr_sensor = sensor_file.split("_")[-1].split(".")[0]  # extract current sensor's name in dataset

        df = pd.read_csv(sensor_file,skiprows=28,sep=",",index_col=0)
        df.index = pd.to_numeric(df.index)
        df.columns = pd.to_numeric(df.columns)

        for row_label, row in df.iterrows():
            for col_label, value in row.items():
                data_list.append((value, col_label, row_label, curr_dz, curr_sensor))

        tmp_dfs.append(pd.DataFrame(data_list, columns=["data","x","y","z","sensor"]))

        for _, tmp_df in enumerate(tmp_dfs):
            sensor_name = tmp_df["sensor"][0]
            merged_df[sensor_name] = tmp_df["data"]
        merged_df["x"] = tmp_df["x"]
        merged_df["y"] = tmp_df["y"]
        merged_df["z"] = tmp_df["z"]
        
    return merged_df

# %%
def extend_array(arr: np.ndarray, n: int):
    if arr.ndim == 1:
        result = []
        result.extend([arr[0]])
        for i in range(1, len(arr)):
            diff = (arr[i] - arr[i-1]) / (n+1)
            new_elements = [arr[i-1] + j*diff for j in range(1, (n+1))]
            result.extend(new_elements)
            result.extend([arr[i]])
        return np.array(result)

    result = []
    for row in arr:
        new_row = [row[0]]
        for i in range(1, len(row)):
            diff = (row[i] - row[i-1]) / (n+1)
            new_elements = [row[i-1] + j*diff for j in range(1, (n+1))]
            new_row.extend(new_elements)
            new_row.append(row[i])
        result.append(new_row)
    return np.array(result)

# %%
csv_files = []
merged_df_list = []

csv_files = get_csv_paths_list(directory_path) # function call to get the filepathes of all measurement files
csv_files # jupyter print

for idx, z_height_group in enumerate(csv_files): # loop through each group of files (A4T, A5T, A6T, A7T)
    merged_df_list.append(process_csv_files(z_height_group))

final_combined_df = pd.concat(merged_df_list, ignore_index=True)
final_combined_df
# Out:
#          A4T    A5T    A6T    A7T      x       y      z
# 0      0.122  0.159  0.161  0.148  620.0 -1120.0  190.0
# 1      0.160  0.194  0.192  0.173  600.0 -1120.0  190.0
# 2      0.145  0.186  0.189  0.178  580.0 -1120.0  190.0
# 3      0.132  0.167  0.168  0.154  560.0 -1120.0  190.0
# 4      0.132  0.167  0.172  0.161  540.0 -1120.0  190.0
# ...      ...    ...    ...    ...    ...     ...    ...
# 49828  0.143  0.179  0.176  0.156 -540.0  1120.0  180.0
# 49829  0.110  0.151  0.143  0.128 -560.0  1120.0  180.0
# 49830  0.114  0.159  0.156  0.143 -580.0  1120.0  180.0
# 49831  0.157  0.192  0.187  0.167 -600.0  1120.0  180.0
# 49832  0.000  0.000  0.000  0.000 -620.0  1120.0  180.0
#
# [49833 rows x 7 columns]

# %%
final_combined_df["A4T"].max()
# Out:
# 3.934

# %% [markdown]
# ### Cuttting the Frame

# %%
distance_threshold = 500

# Calculate Euclidean distance
final_combined_df['distance'] = np.sqrt(final_combined_df['x']**2 + final_combined_df['y']**2)

# Filter the DataFrame based on the distance threshold
filtered_df = final_combined_df[final_combined_df['distance'] <= distance_threshold]

# Drop the 'distance' column if you don't need it anymore
filtered_df = filtered_df.drop(columns=['distance'])

# Display the filtered DataFrame
filtered_df
# Out:
#          A4T    A5T    A6T    A7T      x      y      z
# 1984   0.275  0.549  1.332  1.625    0.0 -500.0  190.0
# 2040   0.229  0.623  1.074  1.973  140.0 -480.0  190.0
# 2041   0.344  0.625  1.082  1.874  120.0 -480.0  190.0
# 2042   0.452  0.629  1.086  1.797  100.0 -480.0  190.0
# 2043   0.532  0.636  1.099  1.708   80.0 -480.0  190.0
# ...      ...    ...    ...    ...    ...    ...    ...
# 47789  1.318  1.760  0.475  0.685  -80.0  480.0  180.0
# 47790  1.310  1.826  0.394  0.682 -100.0  480.0  180.0
# 47791  1.300  1.906  0.295  0.679 -120.0  480.0  180.0
# 47792  1.288  2.004  0.190  0.664 -140.0  480.0  180.0
# 47848  1.592  1.687  0.262  0.612    0.0  500.0  180.0
#
# [13727 rows x 7 columns]

# %%
# input_data = final_combined_df[["A4T", "A5T", "A6T", "A7T"]]
input_data = filtered_df[["A4T", "A5T", "A6T", "A7T"]]
input_data
# Out:
#          A4T    A5T    A6T    A7T
# 1984   0.275  0.549  1.332  1.625
# 2040   0.229  0.623  1.074  1.973
# 2041   0.344  0.625  1.082  1.874
# 2042   0.452  0.629  1.086  1.797
# 2043   0.532  0.636  1.099  1.708
# ...      ...    ...    ...    ...
# 47789  1.318  1.760  0.475  0.685
# 47790  1.310  1.826  0.394  0.682
# 47791  1.300  1.906  0.295  0.679
# 47792  1.288  2.004  0.190  0.664
# 47848  1.592  1.687  0.262  0.612
#
# [13727 rows x 4 columns]

# %%
# target_data = final_combined_df[["x", "y"]]
target_data = filtered_df[["x", "y"]]
target_data
# Out:
#            x      y
# 1984     0.0 -500.0
# 2040   140.0 -480.0
# 2041   120.0 -480.0
# 2042   100.0 -480.0
# 2043    80.0 -480.0
# ...      ...    ...
# 47789  -80.0  480.0
# 47790 -100.0  480.0
# 47791 -120.0  480.0
# 47792 -140.0  480.0
# 47848    0.0  500.0
#
# [13727 rows x 2 columns]

# %% [markdown]
# ## Scale the dataframe

# %%
scaler_input = sklearn.preprocessing.MinMaxScaler()
scaled_input_data = scaler_input.fit_transform(input_data)
scaled_input_data.max(axis=0)
# Out:
# array([1., 1., 1., 1.])

# %%
scaler_target = sklearn.preprocessing.MinMaxScaler()
scaled_target_data = scaler_target.fit_transform(target_data)
scaled_target_data.max(axis=0)
# Out:
# array([1., 1.])

# %% [markdown]
# ## Get distribution of the datapoints

# %%
import matplotlib.pyplot as plt

percentages = []
thresholds = []

for threshold in np.arange(0.05, 1, 0.05):
    thresholds.append(threshold)
    filtered_arr = scaled_input_data[scaled_input_data >= threshold]
    percentage = len(filtered_arr) / scaled_input_data.size * 100
    percentages.append(percentage)
    # print(f"Threshold: {threshold:.2f}, Percentage: {percentage:.2f}%")

plt.bar(thresholds, percentages, width= 0.025)
plt.show()

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dropout, Input, Activation, Dense
from keras.initializers import HeUniform
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.losses import MeanSquaredError

# %%
import metrics
import time

# %% [markdown]
# ## Generating training and testing data

# %%
input_tensor = tf.convert_to_tensor(scaled_input_data)
target_tensor = tf.convert_to_tensor(scaled_target_data)
n_features = 4
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2023-09-24 16:03:59.198384: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-09-24 16:03:59.198817: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Create a dataset with the input and target tensors
dataset = tf.data.Dataset.from_tensor_slices((input_tensor, target_tensor))

# Shuffle the dataset with a buffer size of the number of samples
buffer_size = input_tensor.shape[0]
shuffled_dataset = dataset.shuffle(buffer_size)

# Extract the shuffled input and target tensors from the shuffled dataset
input_tensor, target_tensor = next(iter(shuffled_dataset.batch(buffer_size)))

input_dataset = tf.data.Dataset.from_tensor_slices(input_data)
target_dataset = tf.data.Dataset.from_tensor_slices(target_tensor)

print(input_tensor.shape)
# Out:
# (13727, 4)

# %%
# # split the data and labels into training and testing sets
# train_size = int(0.7 * len(input_tensor)) # 80% of data for training
# train_data, test_data = tf.split(input_tensor, [train_size, len(input_tensor)-train_size], axis=0)
# train_labels, test_labels = tf.split(target_tensor, [train_size, len(target_tensor)-train_size], axis=0)
# print(train_data.shape, train_labels.shape)

buffer_size = input_tensor.shape[0]
indices = np.arange(buffer_size)
np.random.shuffle(indices)

# Define the sizes for training, validation, and test sets
train_size = int(0.7 * buffer_size)  # 70% of data for training
val_size = int(0.15 * buffer_size)   # 15% of data for validation
test_size = buffer_size - train_size - val_size  # Rest for testing

# Split the shuffled indices into training, validation, and test sets
train_indices = indices[:train_size]
val_indices = indices[train_size:train_size + val_size]
test_indices = indices[train_size + val_size:]

# Convert the indices to TensorFlow tensors
train_indices = tf.convert_to_tensor(train_indices, dtype=tf.int32)
val_indices = tf.convert_to_tensor(val_indices, dtype=tf.int32)
test_indices = tf.convert_to_tensor(test_indices, dtype=tf.int32)

# Use the indices to create tensors for training, validation, and test sets
train_data = tf.gather(input_tensor, train_indices)
train_labels = tf.gather(target_tensor, train_indices)

val_data = tf.gather(input_tensor, val_indices)
val_labels = tf.gather(target_tensor, val_indices)

test_data = tf.gather(input_tensor, test_indices)
test_labels = tf.gather(target_tensor, test_indices)

# %% [markdown]
# ## Building the model

# %%
n_hidden = 1024

model = Sequential()
model.add(Input(shape= (n_features), name='Dense_Input'))
model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_1'))
model.add(Activation('relu', name='relu_1'))
model.add(Dropout(rate=0.2, name='dropout_1'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_2'))
model.add(Activation('relu', name='relu_2'))
model.add(Dropout(rate=0.2, name='dropout_2'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_3'))
model.add(Activation('relu', name='relu_3'))
model.add(Dropout(rate=0.2, name='dropout_3'))
model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_4'))
model.add(Activation('relu', name='relu_4'))
model.add(Dense(2, name='Dense_Out'))
model.add(Activation('sigmoid', name='sigmoid_Out'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_1 (Dense)             (None, 512)               2560
#
#  relu_1 (Activation)         (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  Dense_2 (Dense)             (None, 1024)              525312
#
#  relu_2 (Activation)         (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  Dense_3 (Dense)             (None, 1024)              1049600
#
#  relu_3 (Activation)         (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  Dense_4 (Dense)             (None, 512)               524800
#
#  relu_4 (Activation)         (None, 512)               0
#
#  Dense_Out (Dense)           (None, 2)                 1026
#
#  sigmoid_Out (Activation)    (None, 2)                 0
#
# =================================================================
# Total params: 2,103,298
# Trainable params: 2,103,298
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
import math
# Define configuration parameters
start_lr = 0.0001
rampup_epochs = 20
exp_decay = 0.1

# Define the scheduling function
def scheduler(epoch):
  def lr(epoch, start_lr, rampup_epochs, exp_decay):
    if epoch < rampup_epochs:
      return start_lr
    else:
      return start_lr * math.exp(-exp_decay * epoch)
  return lr(epoch, start_lr, rampup_epochs, exp_decay)

# %%
optimizer = Adam()
loss = MeanSquaredError()

mcp_save = ModelCheckpoint(f'MLP-NewData-ZInput_mse_{int(time.time())}.h5', 
                           save_best_only=True,
                           monitor='val_mse', 
                           mode='min')

learning_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
model.compile(optimizer=optimizer, 
                loss="mse",
                metrics=["mse", metrics.CenterMeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYSquarredErrorRealWorld(scaler=scaler_target),  
                                metrics.MeanXYAbsoluteErrorRealWorld(scaler=scaler_target),
                                metrics.MeanXYRootSquarredErrorRealWorld(scaler=scaler_target)]
)

# %%
history = model.fit(
    x = train_data,
    y = train_labels, 
    epochs = 40,
    validation_data = [val_data, val_labels],
    callbacks = [learning_callback]
)
# Out:
# Epoch 1/40
# 2023-09-24 16:04:11.855646: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-09-24 16:04:12.370226: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 301/301 [==============================] - ETA: 0s - loss: 0.0280 - mse: 0.0280 - centernormXYReal: 210.6337 - normXYReal: 199.2953 - mseXYReal: 28044.5723 - maeXYReal: 127.0775 - rmseXYReal: 167.4651
# 2023-09-24 16:04:17.448123: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 301/301 [==============================] - 6s 18ms/step - loss: 0.0280 - mse: 0.0280 - centernormXYReal: 210.6337 - normXYReal: 199.2953 - mseXYReal: 28044.5723 - maeXYReal: 127.0775 - rmseXYReal: 167.4651 - val_loss: 0.0207 - val_mse: 0.0207 - val_centernormXYReal: 161.8753 - val_normXYReal: 167.3185 - val_mseXYReal: 20658.4277 - val_maeXYReal: 107.1246 - val_rmseXYReal: 143.7304 - lr: 1.0000e-04
# Epoch 2/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0211 - mse: 0.0211 - centernormXYReal: 187.8142 - normXYReal: 170.1255 - mseXYReal: 21141.3047 - maeXYReal: 108.3900 - rmseXYReal: 145.4005 - val_loss: 0.0206 - val_mse: 0.0206 - val_centernormXYReal: 176.7383 - val_normXYReal: 166.6852 - val_mseXYReal: 20588.4727 - val_maeXYReal: 107.4132 - val_rmseXYReal: 143.4868 - lr: 1.0000e-04
# Epoch 3/40
# 301/301 [==============================] - 5s 17ms/step - loss: 0.0196 - mse: 0.0196 - centernormXYReal: 166.5201 - normXYReal: 162.6997 - mseXYReal: 19553.3066 - maeXYReal: 103.6422 - rmseXYReal: 139.8331 - val_loss: 0.0182 - val_mse: 0.0182 - val_centernormXYReal: 144.3327 - val_normXYReal: 152.3208 - val_mseXYReal: 18215.4922 - val_maeXYReal: 97.5991 - val_rmseXYReal: 134.9648 - lr: 1.0000e-04
# Epoch 4/40
# 301/301 [==============================] - 5s 17ms/step - loss: 0.0184 - mse: 0.0184 - centernormXYReal: 166.5117 - normXYReal: 156.1226 - mseXYReal: 18350.5059 - maeXYReal: 99.2920 - rmseXYReal: 135.4640 - val_loss: 0.0171 - val_mse: 0.0171 - val_centernormXYReal: 146.8919 - val_normXYReal: 146.0844 - val_mseXYReal: 17131.2207 - val_maeXYReal: 92.6018 - val_rmseXYReal: 130.8863 - lr: 1.0000e-04
# Epoch 5/40
# 301/301 [==============================] - 5s 17ms/step - loss: 0.0174 - mse: 0.0174 - centernormXYReal: 145.4874 - normXYReal: 151.0711 - mseXYReal: 17392.0137 - maeXYReal: 96.0091 - rmseXYReal: 131.8788 - val_loss: 0.0157 - val_mse: 0.0157 - val_centernormXYReal: 198.1720 - val_normXYReal: 137.4130 - val_mseXYReal: 15730.1484 - val_maeXYReal: 86.4483 - val_rmseXYReal: 125.4199 - lr: 1.0000e-04
# Epoch 6/40
# 301/301 [==============================] - 5s 17ms/step - loss: 0.0167 - mse: 0.0167 - centernormXYReal: 140.9596 - normXYReal: 147.6273 - mseXYReal: 16735.0215 - maeXYReal: 93.5196 - rmseXYReal: 129.3639 - val_loss: 0.0155 - val_mse: 0.0155 - val_centernormXYReal: 142.0580 - val_normXYReal: 137.9924 - val_mseXYReal: 15532.1465 - val_maeXYReal: 86.7708 - val_rmseXYReal: 124.6280 - lr: 1.0000e-04
# Epoch 7/40
# 301/301 [==============================] - 5s 17ms/step - loss: 0.0161 - mse: 0.0161 - centernormXYReal: 139.9936 - normXYReal: 144.1918 - mseXYReal: 16133.2490 - maeXYReal: 91.3858 - rmseXYReal: 127.0167 - val_loss: 0.0146 - val_mse: 0.0146 - val_centernormXYReal: 146.7960 - val_normXYReal: 133.5850 - val_mseXYReal: 14584.2949 - val_maeXYReal: 83.2912 - val_rmseXYReal: 120.7654 - lr: 1.0000e-04
# Epoch 8/40
# 301/301 [==============================] - 5s 17ms/step - loss: 0.0153 - mse: 0.0153 - centernormXYReal: 141.5214 - normXYReal: 139.8351 - mseXYReal: 15296.7715 - maeXYReal: 88.4321 - rmseXYReal: 123.6801 - val_loss: 0.0142 - val_mse: 0.0142 - val_centernormXYReal: 148.7242 - val_normXYReal: 132.9711 - val_mseXYReal: 14176.0947 - val_maeXYReal: 83.3519 - val_rmseXYReal: 119.0634 - lr: 1.0000e-04
# Epoch 9/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0149 - mse: 0.0149 - centernormXYReal: 142.8635 - normXYReal: 137.6573 - mseXYReal: 14891.3691 - maeXYReal: 86.9826 - rmseXYReal: 122.0302 - val_loss: 0.0144 - val_mse: 0.0144 - val_centernormXYReal: 164.9818 - val_normXYReal: 137.2473 - val_mseXYReal: 14398.7451 - val_maeXYReal: 85.6282 - val_rmseXYReal: 119.9948 - lr: 1.0000e-04
# Epoch 10/40
# 301/301 [==============================] - 5s 17ms/step - loss: 0.0144 - mse: 0.0144 - centernormXYReal: 132.2486 - normXYReal: 135.2055 - mseXYReal: 14357.0703 - maeXYReal: 85.2465 - rmseXYReal: 119.8210 - val_loss: 0.0132 - val_mse: 0.0132 - val_centernormXYReal: 147.9365 - val_normXYReal: 129.5935 - val_mseXYReal: 13217.1875 - val_maeXYReal: 81.3419 - val_rmseXYReal: 114.9660 - lr: 1.0000e-04
# Epoch 11/40
# 301/301 [==============================] - 5s 17ms/step - loss: 0.0138 - mse: 0.0138 - centernormXYReal: 121.6919 - normXYReal: 132.4520 - mseXYReal: 13837.8330 - maeXYReal: 83.4821 - rmseXYReal: 117.6343 - val_loss: 0.0130 - val_mse: 0.0130 - val_centernormXYReal: 131.8147 - val_normXYReal: 128.5642 - val_mseXYReal: 13037.1885 - val_maeXYReal: 79.8213 - val_rmseXYReal: 114.1805 - lr: 1.0000e-04
# Epoch 12/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0134 - mse: 0.0134 - centernormXYReal: 134.6659 - normXYReal: 130.1884 - mseXYReal: 13363.4824 - maeXYReal: 82.0191 - rmseXYReal: 115.6005 - val_loss: 0.0122 - val_mse: 0.0122 - val_centernormXYReal: 149.3256 - val_normXYReal: 124.0346 - val_mseXYReal: 12172.5596 - val_maeXYReal: 77.3831 - val_rmseXYReal: 110.3293 - lr: 1.0000e-04
# Epoch 13/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0128 - mse: 0.0128 - centernormXYReal: 122.9914 - normXYReal: 127.3506 - mseXYReal: 12789.9141 - maeXYReal: 80.2291 - rmseXYReal: 113.0925 - val_loss: 0.0119 - val_mse: 0.0119 - val_centernormXYReal: 132.5407 - val_normXYReal: 125.9737 - val_mseXYReal: 11917.5459 - val_maeXYReal: 78.2568 - val_rmseXYReal: 109.1675 - lr: 1.0000e-04
# Epoch 14/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0122 - mse: 0.0122 - centernormXYReal: 124.9676 - normXYReal: 124.9662 - mseXYReal: 12247.1846 - maeXYReal: 78.5649 - rmseXYReal: 110.6670 - val_loss: 0.0113 - val_mse: 0.0113 - val_centernormXYReal: 109.6438 - val_normXYReal: 121.5446 - val_mseXYReal: 11297.7422 - val_maeXYReal: 75.1980 - val_rmseXYReal: 106.2908 - lr: 1.0000e-04
# Epoch 15/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0116 - mse: 0.0116 - centernormXYReal: 119.6359 - normXYReal: 122.1278 - mseXYReal: 11626.0137 - maeXYReal: 76.5898 - rmseXYReal: 107.8240 - val_loss: 0.0112 - val_mse: 0.0112 - val_centernormXYReal: 109.8236 - val_normXYReal: 121.9754 - val_mseXYReal: 11182.8916 - val_maeXYReal: 75.2526 - val_rmseXYReal: 105.7492 - lr: 1.0000e-04
# Epoch 16/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0110 - mse: 0.0110 - centernormXYReal: 110.4813 - normXYReal: 119.7123 - mseXYReal: 11048.7715 - maeXYReal: 75.1709 - rmseXYReal: 105.1131 - val_loss: 0.0105 - val_mse: 0.0105 - val_centernormXYReal: 129.4744 - val_normXYReal: 120.1107 - val_mseXYReal: 10493.6553 - val_maeXYReal: 74.7771 - val_rmseXYReal: 102.4385 - lr: 1.0000e-04
# Epoch 17/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0106 - mse: 0.0106 - centernormXYReal: 131.5027 - normXYReal: 117.0533 - mseXYReal: 10557.3857 - maeXYReal: 73.4957 - rmseXYReal: 102.7491 - val_loss: 0.0100 - val_mse: 0.0100 - val_centernormXYReal: 111.6217 - val_normXYReal: 117.5428 - val_mseXYReal: 9957.8145 - val_maeXYReal: 72.9733 - val_rmseXYReal: 99.7888 - lr: 1.0000e-04
# Epoch 18/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0100 - mse: 0.0100 - centernormXYReal: 109.4717 - normXYReal: 114.1560 - mseXYReal: 9977.3770 - maeXYReal: 71.7134 - rmseXYReal: 99.8868 - val_loss: 0.0106 - val_mse: 0.0106 - val_centernormXYReal: 118.4079 - val_normXYReal: 121.5504 - val_mseXYReal: 10585.4033 - val_maeXYReal: 75.3351 - val_rmseXYReal: 102.8854 - lr: 1.0000e-04
# Epoch 19/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0094 - mse: 0.0094 - centernormXYReal: 117.7069 - normXYReal: 111.2644 - mseXYReal: 9447.8447 - maeXYReal: 69.7695 - rmseXYReal: 97.2000 - val_loss: 0.0097 - val_mse: 0.0097 - val_centernormXYReal: 125.4211 - val_normXYReal: 114.4115 - val_mseXYReal: 9711.0098 - val_maeXYReal: 70.9835 - val_rmseXYReal: 98.5445 - lr: 1.0000e-04
# Epoch 20/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0091 - mse: 0.0091 - centernormXYReal: 117.3728 - normXYReal: 108.7696 - mseXYReal: 9076.7031 - maeXYReal: 68.2103 - rmseXYReal: 95.2717 - val_loss: 0.0085 - val_mse: 0.0085 - val_centernormXYReal: 123.2750 - val_normXYReal: 106.4009 - val_mseXYReal: 8516.1895 - val_maeXYReal: 66.4307 - val_rmseXYReal: 92.2832 - lr: 1.0000e-04
# Epoch 21/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0081 - mse: 0.0081 - centernormXYReal: 111.2113 - normXYReal: 101.5761 - mseXYReal: 8148.1851 - maeXYReal: 63.7742 - rmseXYReal: 90.2673 - val_loss: 0.0083 - val_mse: 0.0083 - val_centernormXYReal: 121.6533 - val_normXYReal: 104.9783 - val_mseXYReal: 8260.7588 - val_maeXYReal: 65.1597 - val_rmseXYReal: 90.8887 - lr: 1.3534e-05
# Epoch 22/40
# 301/301 [==============================] - 5s 18ms/step - loss: 0.0078 - mse: 0.0078 - centernormXYReal: 112.2471 - normXYReal: 99.0593 - mseXYReal: 7753.2681 - maeXYReal: 62.1416 - rmseXYReal: 88.0526 - val_loss: 0.0084 - val_mse: 0.0084 - val_centernormXYReal: 113.6712 - val_normXYReal: 106.8934 - val_mseXYReal: 8435.0186 - val_maeXYReal: 66.3890 - val_rmseXYReal: 91.8424 - lr: 1.2246e-05
# Epoch 23/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0077 - mse: 0.0077 - centernormXYReal: 113.2429 - normXYReal: 98.3471 - mseXYReal: 7700.9150 - maeXYReal: 61.7104 - rmseXYReal: 87.7549 - val_loss: 0.0082 - val_mse: 0.0082 - val_centernormXYReal: 123.6964 - val_normXYReal: 105.6708 - val_mseXYReal: 8228.1807 - val_maeXYReal: 65.7117 - val_rmseXYReal: 90.7093 - lr: 1.1080e-05
# Epoch 24/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0076 - mse: 0.0076 - centernormXYReal: 96.7924 - normXYReal: 97.8880 - mseXYReal: 7599.3340 - maeXYReal: 61.4085 - rmseXYReal: 87.1742 - val_loss: 0.0086 - val_mse: 0.0086 - val_centernormXYReal: 126.6389 - val_normXYReal: 108.1839 - val_mseXYReal: 8634.1602 - val_maeXYReal: 67.1944 - val_rmseXYReal: 92.9202 - lr: 1.0026e-05
# Epoch 25/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0075 - mse: 0.0075 - centernormXYReal: 106.1722 - normXYReal: 97.0056 - mseXYReal: 7486.7510 - maeXYReal: 60.9031 - rmseXYReal: 86.5260 - val_loss: 0.0082 - val_mse: 0.0082 - val_centernormXYReal: 123.7269 - val_normXYReal: 105.4350 - val_mseXYReal: 8248.8848 - val_maeXYReal: 65.5740 - val_rmseXYReal: 90.8234 - lr: 9.0718e-06
# Epoch 26/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0074 - mse: 0.0074 - centernormXYReal: 109.5861 - normXYReal: 96.5696 - mseXYReal: 7406.1533 - maeXYReal: 60.5892 - rmseXYReal: 86.0590 - val_loss: 0.0087 - val_mse: 0.0087 - val_centernormXYReal: 124.6688 - val_normXYReal: 108.5717 - val_mseXYReal: 8690.1816 - val_maeXYReal: 67.3449 - val_rmseXYReal: 93.2211 - lr: 8.2085e-06
# Epoch 27/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0074 - mse: 0.0074 - centernormXYReal: 105.3420 - normXYReal: 96.3384 - mseXYReal: 7356.0317 - maeXYReal: 60.4544 - rmseXYReal: 85.7673 - val_loss: 0.0085 - val_mse: 0.0085 - val_centernormXYReal: 124.0209 - val_normXYReal: 106.8018 - val_mseXYReal: 8450.6143 - val_maeXYReal: 66.3390 - val_rmseXYReal: 91.9272 - lr: 7.4274e-06
# Epoch 28/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0073 - mse: 0.0073 - centernormXYReal: 105.5477 - normXYReal: 95.6895 - mseXYReal: 7270.7510 - maeXYReal: 60.0031 - rmseXYReal: 85.2687 - val_loss: 0.0084 - val_mse: 0.0084 - val_centernormXYReal: 118.9541 - val_normXYReal: 106.7730 - val_mseXYReal: 8434.1484 - val_maeXYReal: 66.2048 - val_rmseXYReal: 91.8376 - lr: 6.7206e-06
# Epoch 29/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0072 - mse: 0.0072 - centernormXYReal: 112.1023 - normXYReal: 95.4154 - mseXYReal: 7239.6069 - maeXYReal: 59.8244 - rmseXYReal: 85.0859 - val_loss: 0.0081 - val_mse: 0.0081 - val_centernormXYReal: 126.1717 - val_normXYReal: 104.5445 - val_mseXYReal: 8138.2334 - val_maeXYReal: 65.0542 - val_rmseXYReal: 90.2122 - lr: 6.0810e-06
# Epoch 30/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0072 - mse: 0.0072 - centernormXYReal: 126.1193 - normXYReal: 95.4121 - mseXYReal: 7247.3574 - maeXYReal: 59.9130 - rmseXYReal: 85.1314 - val_loss: 0.0082 - val_mse: 0.0082 - val_centernormXYReal: 124.3676 - val_normXYReal: 105.4559 - val_mseXYReal: 8233.5791 - val_maeXYReal: 65.6183 - val_rmseXYReal: 90.7391 - lr: 5.5023e-06
# Epoch 31/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0072 - mse: 0.0072 - centernormXYReal: 113.0297 - normXYReal: 95.0128 - mseXYReal: 7181.4053 - maeXYReal: 59.6115 - rmseXYReal: 84.7432 - val_loss: 0.0084 - val_mse: 0.0084 - val_centernormXYReal: 122.0933 - val_normXYReal: 106.7319 - val_mseXYReal: 8374.4219 - val_maeXYReal: 66.3577 - val_rmseXYReal: 91.5119 - lr: 4.9787e-06
# Epoch 32/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0072 - mse: 0.0072 - centernormXYReal: 98.4594 - normXYReal: 94.6624 - mseXYReal: 7174.1465 - maeXYReal: 59.3849 - rmseXYReal: 84.7003 - val_loss: 0.0082 - val_mse: 0.0082 - val_centernormXYReal: 122.1652 - val_normXYReal: 105.1616 - val_mseXYReal: 8206.3389 - val_maeXYReal: 65.3124 - val_rmseXYReal: 90.5888 - lr: 4.5049e-06
# Epoch 33/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0071 - mse: 0.0071 - centernormXYReal: 112.2617 - normXYReal: 94.4540 - mseXYReal: 7131.9111 - maeXYReal: 59.3139 - rmseXYReal: 84.4506 - val_loss: 0.0083 - val_mse: 0.0083 - val_centernormXYReal: 121.6171 - val_normXYReal: 105.9377 - val_mseXYReal: 8254.5635 - val_maeXYReal: 65.8793 - val_rmseXYReal: 90.8546 - lr: 4.0762e-06
# Epoch 34/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0071 - mse: 0.0071 - centernormXYReal: 99.2761 - normXYReal: 94.1938 - mseXYReal: 7080.1572 - maeXYReal: 59.1199 - rmseXYReal: 84.1437 - val_loss: 0.0082 - val_mse: 0.0082 - val_centernormXYReal: 121.5093 - val_normXYReal: 105.1744 - val_mseXYReal: 8209.8691 - val_maeXYReal: 65.4161 - val_rmseXYReal: 90.6083 - lr: 3.6883e-06
# Epoch 35/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0071 - mse: 0.0071 - centernormXYReal: 109.9960 - normXYReal: 94.0792 - mseXYReal: 7086.1768 - maeXYReal: 59.0531 - rmseXYReal: 84.1794 - val_loss: 0.0083 - val_mse: 0.0083 - val_centernormXYReal: 122.6401 - val_normXYReal: 105.8424 - val_mseXYReal: 8264.8252 - val_maeXYReal: 65.8871 - val_rmseXYReal: 90.9111 - lr: 3.3373e-06
# Epoch 36/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0071 - mse: 0.0071 - centernormXYReal: 110.2236 - normXYReal: 94.0759 - mseXYReal: 7062.7134 - maeXYReal: 59.0156 - rmseXYReal: 84.0399 - val_loss: 0.0082 - val_mse: 0.0082 - val_centernormXYReal: 122.2198 - val_normXYReal: 105.2895 - val_mseXYReal: 8188.6924 - val_maeXYReal: 65.5175 - val_rmseXYReal: 90.4914 - lr: 3.0197e-06
# Epoch 37/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0070 - mse: 0.0070 - centernormXYReal: 114.9548 - normXYReal: 93.7594 - mseXYReal: 7021.1426 - maeXYReal: 58.8609 - rmseXYReal: 83.7923 - val_loss: 0.0084 - val_mse: 0.0084 - val_centernormXYReal: 124.3223 - val_normXYReal: 106.5844 - val_mseXYReal: 8361.4150 - val_maeXYReal: 66.2259 - val_rmseXYReal: 91.4408 - lr: 2.7324e-06
# Epoch 38/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0070 - mse: 0.0070 - centernormXYReal: 109.3489 - normXYReal: 93.6972 - mseXYReal: 7022.7036 - maeXYReal: 58.8351 - rmseXYReal: 83.8016 - val_loss: 0.0082 - val_mse: 0.0082 - val_centernormXYReal: 123.4978 - val_normXYReal: 105.1630 - val_mseXYReal: 8177.1279 - val_maeXYReal: 65.4990 - val_rmseXYReal: 90.4275 - lr: 2.4724e-06
# Epoch 39/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0070 - mse: 0.0070 - centernormXYReal: 96.2632 - normXYReal: 93.5100 - mseXYReal: 6981.6880 - maeXYReal: 58.6436 - rmseXYReal: 83.5565 - val_loss: 0.0083 - val_mse: 0.0083 - val_centernormXYReal: 124.2311 - val_normXYReal: 105.9860 - val_mseXYReal: 8287.5215 - val_maeXYReal: 65.9492 - val_rmseXYReal: 91.0358 - lr: 2.2371e-06
# Epoch 40/40
# 301/301 [==============================] - 5s 16ms/step - loss: 0.0070 - mse: 0.0070 - centernormXYReal: 111.9959 - normXYReal: 93.2700 - mseXYReal: 6974.3198 - maeXYReal: 58.5780 - rmseXYReal: 83.5124 - val_loss: 0.0083 - val_mse: 0.0083 - val_centernormXYReal: 124.0408 - val_normXYReal: 106.0543 - val_mseXYReal: 8297.8457 - val_maeXYReal: 65.9519 - val_rmseXYReal: 91.0925 - lr: 2.0242e-06

# %% [markdown]
# ## Analysis of the model

# %%
plt.plot(history.history["mse"], 'b', label="mse")
plt.plot(history.history["val_mse"], 'r', label="val_mse")
plt.ylabel("mse")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["loss"], 'b', label="loss")
plt.plot(history.history["val_loss"], 'r', label="val_loss")
plt.ylabel("losses")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["centernormXYReal"], 'b', label="centernormXYReal")
plt.plot(history.history["val_centernormXYReal"], 'r', label="val_centernormXYReal")
plt.ylabel("centernormXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["normXYReal"], 'b', label="normXYReal")
plt.plot(history.history["val_normXYReal"], 'r', label="val_normXYReal")
plt.ylabel("normXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
results = model.evaluate(test_data, test_labels)
dict(zip(model.metrics_names, results))
# Out:
# 65/65 [==============================] - 1s 11ms/step - loss: 0.0089 - mse: 0.0089 - centernormXYReal: 133.2561 - normXYReal: 108.6356 - mseXYReal: 8860.2969 - maeXYReal: 67.8005 - rmseXYReal: 94.1292
# {'loss': 0.008860299363732338,
#  'mse': 0.008860299363732338,
#  'centernormXYReal': 133.2560577392578,
#  'normXYReal': 108.63555908203125,
#  'mseXYReal': 8860.296875,
#  'maeXYReal': 67.80048370361328,
#  'rmseXYReal': 94.12915802001953}
