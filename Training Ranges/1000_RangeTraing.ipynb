# %% [markdown]
# # Preamble

# %% [markdown]
# This notebook shows the results of training with different data ranges. Due to past findings the prediction of the ai can be signifcantly better when trained on specific parts of the dataset. Here the ai has been trained on data within the range (distance) of 1000 to the midpoint.

# %% [markdown]
# # Preparation of data

# %% [markdown]
# ## Setting up dataframe

# %%
import pandas as pd
import numpy as np
import glob
import os
from typing import List
import os 
import sklearn.preprocessing

# %%
HEIGHT_CONSTANT = False
directory_path = '/Users/benedictkunzmann/Desktop/Bachelorarbeit/Verlauf/Modelle/20230902_version_3.1/01_measurement_data'

# %%
### function definition section:
def sort_key(file_path): # define a custom sorting key function to sort filenames alphabetically
    """ notes here """
    
    file_name = os.path.basename(file_path)
    
    return file_name

def get_csv_paths_list(directory_path: str):
    """ notes:
        this function is meant to list all A4T-, A5T-, A6T- and A7T-measurement files
         for different coil-coil-distances in form of her absolute filepathes."""

    csv_files = []

    parPath = os.getcwd()
    dataFolder = directory_path
    dataPath = os.path.join(parPath, dataFolder)

    subfolders = [f.path for f in os.scandir(dataPath) if f.is_dir()]

    for folder in subfolders:
        files_in_dir = glob.glob(os.path.join(folder, "*.csv"))
        sorted_files = sorted(files_in_dir, key=sort_key)
        csv_files.append(sorted_files)

    csv_files = csv_files[0:-1]

    return csv_files

def process_csv_files(csv_block: List[str]) -> pd.DataFrame:
    """ notes:
        parameter csv_block needs to be a list of 4 filepath strings.
        those strings refer to 4 different measurement files of sensors
         A4T, A5T, A6T and A7T.
        for a different height (coil-coil-distance) another csv_block
         has to be passed in.
        this function returns a combined/merged pd.dataframe in which
         the structure is ["A4T","A5T","A6T","A7T","x","y","z"], 
         thus all XxY-grids within each individual measurment file
         are flattened."""

    tmp_dfs = []
    columns = ["A4T","A5T","A6T","A7T","x","y","z"]
    merged_df = pd.DataFrame(columns=columns)

    curr_dz = float(csv_block[0].split("_dz")[1].split("/")[0]) # extract current z-height of dataset
    for _, sensor_file in enumerate(csv_block):
        data_list = [] # create a list to store the data

        curr_sensor = sensor_file.split("_")[-1].split(".")[0]  # extract current sensor's name in dataset

        df = pd.read_csv(sensor_file,skiprows=28,sep=",",index_col=0)
        df.index = pd.to_numeric(df.index)
        df.columns = pd.to_numeric(df.columns)

        for row_label, row in df.iterrows():
            for col_label, value in row.items():
                data_list.append((value, col_label, row_label, curr_dz, curr_sensor))

        tmp_dfs.append(pd.DataFrame(data_list, columns=["data","x","y","z","sensor"]))

        for _, tmp_df in enumerate(tmp_dfs):
            sensor_name = tmp_df["sensor"][0]
            merged_df[sensor_name] = tmp_df["data"]
        merged_df["x"] = tmp_df["x"]
        merged_df["y"] = tmp_df["y"]
        merged_df["z"] = tmp_df["z"]
        
    return merged_df

# %%
def extend_array(arr: np.ndarray, n: int):
    if arr.ndim == 1:
        result = []
        result.extend([arr[0]])
        for i in range(1, len(arr)):
            diff = (arr[i] - arr[i-1]) / (n+1)
            new_elements = [arr[i-1] + j*diff for j in range(1, (n+1))]
            result.extend(new_elements)
            result.extend([arr[i]])
        return np.array(result)

    result = []
    for row in arr:
        new_row = [row[0]]
        for i in range(1, len(row)):
            diff = (row[i] - row[i-1]) / (n+1)
            new_elements = [row[i-1] + j*diff for j in range(1, (n+1))]
            new_row.extend(new_elements)
            new_row.append(row[i])
        result.append(new_row)
    return np.array(result)

# %%
csv_files = []
merged_df_list = []

csv_files = get_csv_paths_list(directory_path) # function call to get the filepathes of all measurement files
csv_files # jupyter print

for idx, z_height_group in enumerate(csv_files): # loop through each group of files (A4T, A5T, A6T, A7T)
    merged_df_list.append(process_csv_files(z_height_group))

final_combined_df = pd.concat(merged_df_list, ignore_index=True)
final_combined_df
# Out:
#          A4T    A5T    A6T    A7T      x       y      z
# 0      0.122  0.159  0.161  0.148  620.0 -1120.0  190.0
# 1      0.160  0.194  0.192  0.173  600.0 -1120.0  190.0
# 2      0.145  0.186  0.189  0.178  580.0 -1120.0  190.0
# 3      0.132  0.167  0.168  0.154  560.0 -1120.0  190.0
# 4      0.132  0.167  0.172  0.161  540.0 -1120.0  190.0
# ...      ...    ...    ...    ...    ...     ...    ...
# 49828  0.143  0.179  0.176  0.156 -540.0  1120.0  180.0
# 49829  0.110  0.151  0.143  0.128 -560.0  1120.0  180.0
# 49830  0.114  0.159  0.156  0.143 -580.0  1120.0  180.0
# 49831  0.157  0.192  0.187  0.167 -600.0  1120.0  180.0
# 49832  0.000  0.000  0.000  0.000 -620.0  1120.0  180.0
#
# [49833 rows x 7 columns]

# %%
final_combined_df["A4T"].max()
# Out:
# 3.934

# %% [markdown]
# ### Cuttting the Frame

# %%
distance_threshold = 1000

# Calculate Euclidean distance
final_combined_df['distance'] = np.sqrt(final_combined_df['x']**2 + final_combined_df['y']**2)

# Filter the DataFrame based on the distance threshold
filtered_df = final_combined_df[final_combined_df['distance'] <= distance_threshold]

# Drop the 'distance' column if you don't need it anymore
filtered_df = filtered_df.drop(columns=['distance'])

# Display the filtered DataFrame
filtered_df
# Out:
#          A4T    A5T    A6T    A7T      x       y      z
# 409    0.132  0.167  0.170  0.203    0.0 -1000.0  190.0
# 463    0.132  0.167  0.171  0.201  180.0  -980.0  190.0
# 464    0.114  0.153  0.156  0.195  160.0  -980.0  190.0
# 465    0.134  0.175  0.184  0.219  140.0  -980.0  190.0
# 466    0.114  0.148  0.154  0.200  120.0  -980.0  190.0
# ...      ...    ...    ...    ...    ...     ...    ...
# 49366  0.120  0.292  0.165  0.145 -120.0   980.0  180.0
# 49367  0.116  0.288  0.160  0.143 -140.0   980.0  180.0
# 49368  0.131  0.289  0.170  0.151 -160.0   980.0  180.0
# 49369  0.156  0.291  0.187  0.165 -180.0   980.0  180.0
# 49423  0.160  0.294  0.197  0.168    0.0  1000.0  180.0
#
# [40957 rows x 7 columns]

# %%
# input_data = final_combined_df[["A4T", "A5T", "A6T", "A7T"]]
input_data = filtered_df[["A4T", "A5T", "A6T", "A7T"]]
input_data
# Out:
#          A4T    A5T    A6T    A7T
# 409    0.132  0.167  0.170  0.203
# 463    0.132  0.167  0.171  0.201
# 464    0.114  0.153  0.156  0.195
# 465    0.134  0.175  0.184  0.219
# 466    0.114  0.148  0.154  0.200
# ...      ...    ...    ...    ...
# 49366  0.120  0.292  0.165  0.145
# 49367  0.116  0.288  0.160  0.143
# 49368  0.131  0.289  0.170  0.151
# 49369  0.156  0.291  0.187  0.165
# 49423  0.160  0.294  0.197  0.168
#
# [40957 rows x 4 columns]

# %%
# target_data = final_combined_df[["x", "y"]]
target_data = filtered_df[["x", "y"]]
target_data
# Out:
#            x       y
# 409      0.0 -1000.0
# 463    180.0  -980.0
# 464    160.0  -980.0
# 465    140.0  -980.0
# 466    120.0  -980.0
# ...      ...     ...
# 49366 -120.0   980.0
# 49367 -140.0   980.0
# 49368 -160.0   980.0
# 49369 -180.0   980.0
# 49423    0.0  1000.0
#
# [40957 rows x 2 columns]

# %% [markdown]
# ## Scale the dataframe

# %%
scaler_input = sklearn.preprocessing.MinMaxScaler()
scaled_input_data = scaler_input.fit_transform(input_data)
scaled_input_data.max(axis=0)
# Out:
# array([1., 1., 1., 1.])

# %%
scaler_target = sklearn.preprocessing.MinMaxScaler()
scaled_target_data = scaler_target.fit_transform(target_data)
scaled_target_data.max(axis=0)
# Out:
# array([1., 1.])

# %% [markdown]
# ## Get distribution of the datapoints

# %%
import matplotlib.pyplot as plt

percentages = []
thresholds = []

for threshold in np.arange(0.05, 1, 0.05):
    thresholds.append(threshold)
    filtered_arr = scaled_input_data[scaled_input_data >= threshold]
    percentage = len(filtered_arr) / scaled_input_data.size * 100
    percentages.append(percentage)
    # print(f"Threshold: {threshold:.2f}, Percentage: {percentage:.2f}%")

plt.bar(thresholds, percentages, width= 0.025)
plt.show()

# %% [markdown]
# # Model

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dropout, Input, Activation, Dense
from keras.initializers import HeUniform
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.losses import MeanSquaredError

# %%
import metrics
import time

# %% [markdown]
# ## Generating training and testing data

# %%
input_tensor = tf.convert_to_tensor(scaled_input_data)
target_tensor = tf.convert_to_tensor(scaled_target_data)
n_features = 4

# %%
# Create a dataset with the input and target tensors
dataset = tf.data.Dataset.from_tensor_slices((input_tensor, target_tensor))

# Shuffle the dataset with a buffer size of the number of samples
buffer_size = input_tensor.shape[0]
shuffled_dataset = dataset.shuffle(buffer_size)

# Extract the shuffled input and target tensors from the shuffled dataset
input_tensor, target_tensor = next(iter(shuffled_dataset.batch(buffer_size)))

input_dataset = tf.data.Dataset.from_tensor_slices(input_data)
target_dataset = tf.data.Dataset.from_tensor_slices(target_tensor)

print(input_tensor.shape)
# Out:
# (40957, 4)

# %%
# # split the data and labels into training and testing sets
# train_size = int(0.7 * len(input_tensor)) # 80% of data for training
# train_data, test_data = tf.split(input_tensor, [train_size, len(input_tensor)-train_size], axis=0)
# train_labels, test_labels = tf.split(target_tensor, [train_size, len(target_tensor)-train_size], axis=0)
# print(train_data.shape, train_labels.shape)

buffer_size = input_tensor.shape[0]
indices = np.arange(buffer_size)
np.random.shuffle(indices)

# Define the sizes for training, validation, and test sets
train_size = int(0.7 * buffer_size)  # 70% of data for training
val_size = int(0.15 * buffer_size)   # 15% of data for validation
test_size = buffer_size - train_size - val_size  # Rest for testing

# Split the shuffled indices into training, validation, and test sets
train_indices = indices[:train_size]
val_indices = indices[train_size:train_size + val_size]
test_indices = indices[train_size + val_size:]

# Convert the indices to TensorFlow tensors
train_indices = tf.convert_to_tensor(train_indices, dtype=tf.int32)
val_indices = tf.convert_to_tensor(val_indices, dtype=tf.int32)
test_indices = tf.convert_to_tensor(test_indices, dtype=tf.int32)

# Use the indices to create tensors for training, validation, and test sets
train_data = tf.gather(input_tensor, train_indices)
train_labels = tf.gather(target_tensor, train_indices)

val_data = tf.gather(input_tensor, val_indices)
val_labels = tf.gather(target_tensor, val_indices)

test_data = tf.gather(input_tensor, test_indices)
test_labels = tf.gather(target_tensor, test_indices)

# %% [markdown]
# ## Building the model

# %%
n_hidden = 1024

model = Sequential()
model.add(Input(shape= (n_features), name='Dense_Input'))
model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_1'))
model.add(Activation('relu', name='relu_1'))
model.add(Dropout(rate=0.2, name='dropout_1'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_2'))
model.add(Activation('relu', name='relu_2'))
model.add(Dropout(rate=0.2, name='dropout_2'))
model.add(Dense(n_hidden, kernel_initializer= HeUniform(), name='Dense_3'))
model.add(Activation('relu', name='relu_3'))
model.add(Dropout(rate=0.2, name='dropout_3'))
model.add(Dense(n_hidden/2, kernel_initializer= HeUniform(), name='Dense_4'))
model.add(Activation('relu', name='relu_4'))
model.add(Dense(2, name='Dense_Out'))
model.add(Activation('sigmoid', name='sigmoid_Out'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_1 (Dense)             (None, 512)               2560
#
#  relu_1 (Activation)         (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  Dense_2 (Dense)             (None, 1024)              525312
#
#  relu_2 (Activation)         (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  Dense_3 (Dense)             (None, 1024)              1049600
#
#  relu_3 (Activation)         (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  Dense_4 (Dense)             (None, 512)               524800
#
#  relu_4 (Activation)         (None, 512)               0
#
#  Dense_Out (Dense)           (None, 2)                 1026
#
#  sigmoid_Out (Activation)    (None, 2)                 0
#
# =================================================================
# Total params: 2,103,298
# Trainable params: 2,103,298
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the model

# %%
import math
# Define configuration parameters
start_lr = 0.0001
rampup_epochs = 20
exp_decay = 0.1

# Define the scheduling function
def scheduler(epoch):
  def lr(epoch, start_lr, rampup_epochs, exp_decay):
    if epoch < rampup_epochs:
      return start_lr
    else:
      return start_lr * math.exp(-exp_decay * epoch)
  return lr(epoch, start_lr, rampup_epochs, exp_decay)

# %%
optimizer = Adam()
loss = MeanSquaredError()

mcp_save = ModelCheckpoint(f'MLP-NewData-ZInput_mse_{int(time.time())}.h5', 
                           save_best_only=True,
                           monitor='val_mse', 
                           mode='min')

learning_callback = tf.keras.callbacks.LearningRateScheduler(scheduler)
model.compile(optimizer=optimizer, 
                loss="mse",
                metrics=["mse", metrics.CenterMeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYNormRealWorld(scaler=scaler_target),
                                metrics.MeanXYSquarredErrorRealWorld(scaler=scaler_target),  
                                metrics.MeanXYAbsoluteErrorRealWorld(scaler=scaler_target),
                                metrics.MeanXYRootSquarredErrorRealWorld(scaler=scaler_target)]
)

# %%
history = model.fit(
    x = train_data,
    y = train_labels, 
    epochs = 40,
    validation_data = [val_data, val_labels],
    callbacks = [learning_callback]
)
# Out:
# Epoch 1/40
# 2023-09-24 16:27:46.121802: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 896/896 [==============================] - ETA: 0s - loss: 0.0278 - mse: 0.0278 - centernormXYReal: 597.8972 - normXYReal: 320.5988 - mseXYReal: 75222.3438 - maeXYReal: 202.6573 - rmseXYReal: 274.2669
# 2023-09-24 16:27:59.898525: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 896/896 [==============================] - 16s 17ms/step - loss: 0.0278 - mse: 0.0278 - centernormXYReal: 597.8972 - normXYReal: 320.5988 - mseXYReal: 75222.3438 - maeXYReal: 202.6573 - rmseXYReal: 274.2669 - val_loss: 0.0161 - val_mse: 0.0161 - val_centernormXYReal: 418.0991 - val_normXYReal: 228.6229 - val_mseXYReal: 39326.1445 - val_maeXYReal: 143.3384 - val_rmseXYReal: 198.3082 - lr: 1.0000e-04
# Epoch 2/40
# 896/896 [==============================] - 15s 16ms/step - loss: 0.0150 - mse: 0.0150 - centernormXYReal: 285.7403 - normXYReal: 214.7651 - mseXYReal: 37221.7812 - maeXYReal: 135.0210 - rmseXYReal: 192.9295 - val_loss: 0.0130 - val_mse: 0.0130 - val_centernormXYReal: 355.8930 - val_normXYReal: 196.2295 - val_mseXYReal: 31651.6562 - val_maeXYReal: 123.3288 - val_rmseXYReal: 177.9091 - lr: 1.0000e-04
# Epoch 3/40
# 896/896 [==============================] - 15s 16ms/step - loss: 0.0131 - mse: 0.0131 - centernormXYReal: 254.1508 - normXYReal: 195.3703 - mseXYReal: 32657.8398 - maeXYReal: 122.4855 - rmseXYReal: 180.7148 - val_loss: 0.0117 - val_mse: 0.0117 - val_centernormXYReal: 221.3344 - val_normXYReal: 183.9309 - val_mseXYReal: 28970.8379 - val_maeXYReal: 116.3543 - val_rmseXYReal: 170.2082 - lr: 1.0000e-04
# Epoch 4/40
# 896/896 [==============================] - 15s 16ms/step - loss: 0.0120 - mse: 0.0120 - centernormXYReal: 240.6037 - normXYReal: 182.9811 - mseXYReal: 29893.6953 - maeXYReal: 114.6177 - rmseXYReal: 172.8979 - val_loss: 0.0108 - val_mse: 0.0108 - val_centernormXYReal: 213.0552 - val_normXYReal: 169.9196 - val_mseXYReal: 26039.2676 - val_maeXYReal: 106.8985 - val_rmseXYReal: 161.3669 - lr: 1.0000e-04
# Epoch 5/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0111 - mse: 0.0111 - centernormXYReal: 224.0491 - normXYReal: 174.0174 - mseXYReal: 27853.5273 - maeXYReal: 108.9215 - rmseXYReal: 166.8938 - val_loss: 0.0102 - val_mse: 0.0102 - val_centernormXYReal: 185.4729 - val_normXYReal: 164.6118 - val_mseXYReal: 24946.7227 - val_maeXYReal: 102.8628 - val_rmseXYReal: 157.9453 - lr: 1.0000e-04
# Epoch 6/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0104 - mse: 0.0104 - centernormXYReal: 210.8874 - normXYReal: 166.5678 - mseXYReal: 26094.1680 - maeXYReal: 104.2724 - rmseXYReal: 161.5369 - val_loss: 0.0090 - val_mse: 0.0090 - val_centernormXYReal: 224.8201 - val_normXYReal: 148.5287 - val_mseXYReal: 22301.6133 - val_maeXYReal: 92.1847 - val_rmseXYReal: 149.3372 - lr: 1.0000e-04
# Epoch 7/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0098 - mse: 0.0098 - centernormXYReal: 181.0163 - normXYReal: 159.9751 - mseXYReal: 24656.3516 - maeXYReal: 99.9662 - rmseXYReal: 157.0234 - val_loss: 0.0088 - val_mse: 0.0088 - val_centernormXYReal: 197.6864 - val_normXYReal: 146.7651 - val_mseXYReal: 21699.4043 - val_maeXYReal: 90.8534 - val_rmseXYReal: 147.3072 - lr: 1.0000e-04
# Epoch 8/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0092 - mse: 0.0092 - centernormXYReal: 212.9308 - normXYReal: 153.9164 - mseXYReal: 23353.9102 - maeXYReal: 96.1437 - rmseXYReal: 152.8199 - val_loss: 0.0086 - val_mse: 0.0086 - val_centernormXYReal: 199.9163 - val_normXYReal: 145.9383 - val_mseXYReal: 21421.6035 - val_maeXYReal: 91.5704 - val_rmseXYReal: 146.3612 - lr: 1.0000e-04
# Epoch 9/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0087 - mse: 0.0087 - centernormXYReal: 174.6221 - normXYReal: 147.8129 - mseXYReal: 22086.1836 - maeXYReal: 92.2796 - rmseXYReal: 148.6142 - val_loss: 0.0079 - val_mse: 0.0079 - val_centernormXYReal: 207.0150 - val_normXYReal: 137.4599 - val_mseXYReal: 20086.5840 - val_maeXYReal: 85.5200 - val_rmseXYReal: 141.7271 - lr: 1.0000e-04
# Epoch 10/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0083 - mse: 0.0083 - centernormXYReal: 166.6438 - normXYReal: 143.3795 - mseXYReal: 21247.8496 - maeXYReal: 89.4542 - rmseXYReal: 145.7664 - val_loss: 0.0081 - val_mse: 0.0081 - val_centernormXYReal: 183.8731 - val_normXYReal: 144.6890 - val_mseXYReal: 20580.5957 - val_maeXYReal: 90.1523 - val_rmseXYReal: 143.4594 - lr: 1.0000e-04
# Epoch 11/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0078 - mse: 0.0078 - centernormXYReal: 185.9140 - normXYReal: 138.2128 - mseXYReal: 20142.8359 - maeXYReal: 86.3332 - rmseXYReal: 141.9255 - val_loss: 0.0076 - val_mse: 0.0076 - val_centernormXYReal: 187.8551 - val_normXYReal: 132.6790 - val_mseXYReal: 19653.3477 - val_maeXYReal: 82.7041 - val_rmseXYReal: 140.1904 - lr: 1.0000e-04
# Epoch 12/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0075 - mse: 0.0075 - centernormXYReal: 188.9698 - normXYReal: 133.8612 - mseXYReal: 19369.7969 - maeXYReal: 83.6332 - rmseXYReal: 139.1754 - val_loss: 0.0072 - val_mse: 0.0072 - val_centernormXYReal: 244.8948 - val_normXYReal: 130.2003 - val_mseXYReal: 18329.0566 - val_maeXYReal: 81.2345 - val_rmseXYReal: 135.3848 - lr: 1.0000e-04
# Epoch 13/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0073 - mse: 0.0073 - centernormXYReal: 162.0310 - normXYReal: 131.1401 - mseXYReal: 18983.4082 - maeXYReal: 81.7765 - rmseXYReal: 137.7803 - val_loss: 0.0069 - val_mse: 0.0069 - val_centernormXYReal: 180.7168 - val_normXYReal: 128.3187 - val_mseXYReal: 17939.8477 - val_maeXYReal: 79.9306 - val_rmseXYReal: 133.9397 - lr: 1.0000e-04
# Epoch 14/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0070 - mse: 0.0070 - centernormXYReal: 186.3321 - normXYReal: 127.3959 - mseXYReal: 18190.5430 - maeXYReal: 79.5051 - rmseXYReal: 134.8723 - val_loss: 0.0065 - val_mse: 0.0065 - val_centernormXYReal: 179.0017 - val_normXYReal: 123.6418 - val_mseXYReal: 16641.0527 - val_maeXYReal: 76.8831 - val_rmseXYReal: 129.0002 - lr: 1.0000e-04
# Epoch 15/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0068 - mse: 0.0068 - centernormXYReal: 159.9320 - normXYReal: 124.5839 - mseXYReal: 17713.7734 - maeXYReal: 77.7395 - rmseXYReal: 133.0931 - val_loss: 0.0065 - val_mse: 0.0065 - val_centernormXYReal: 145.1672 - val_normXYReal: 124.1709 - val_mseXYReal: 16757.8965 - val_maeXYReal: 77.1730 - val_rmseXYReal: 129.4523 - lr: 1.0000e-04
# Epoch 16/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0065 - mse: 0.0065 - centernormXYReal: 173.6046 - normXYReal: 121.8371 - mseXYReal: 17028.1641 - maeXYReal: 75.9846 - rmseXYReal: 130.4920 - val_loss: 0.0063 - val_mse: 0.0063 - val_centernormXYReal: 156.2851 - val_normXYReal: 119.3962 - val_mseXYReal: 16172.6270 - val_maeXYReal: 74.5767 - val_rmseXYReal: 127.1716 - lr: 1.0000e-04
# Epoch 17/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0065 - mse: 0.0065 - centernormXYReal: 178.9574 - normXYReal: 119.9345 - mseXYReal: 16861.8906 - maeXYReal: 74.6833 - rmseXYReal: 129.8533 - val_loss: 0.0061 - val_mse: 0.0061 - val_centernormXYReal: 304.7369 - val_normXYReal: 117.9155 - val_mseXYReal: 15842.5020 - val_maeXYReal: 73.6592 - val_rmseXYReal: 125.8670 - lr: 1.0000e-04
# Epoch 18/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0063 - mse: 0.0063 - centernormXYReal: 147.3428 - normXYReal: 117.6961 - mseXYReal: 16430.5723 - maeXYReal: 73.4509 - rmseXYReal: 128.1818 - val_loss: 0.0062 - val_mse: 0.0062 - val_centernormXYReal: 214.8880 - val_normXYReal: 118.1752 - val_mseXYReal: 16202.5977 - val_maeXYReal: 73.6848 - val_rmseXYReal: 127.2894 - lr: 1.0000e-04
# Epoch 19/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0062 - mse: 0.0062 - centernormXYReal: 181.2689 - normXYReal: 116.1860 - mseXYReal: 16077.6211 - maeXYReal: 72.4753 - rmseXYReal: 126.7976 - val_loss: 0.0058 - val_mse: 0.0058 - val_centernormXYReal: 176.9712 - val_normXYReal: 110.9604 - val_mseXYReal: 15235.0869 - val_maeXYReal: 68.9809 - val_rmseXYReal: 123.4305 - lr: 1.0000e-04
# Epoch 20/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0060 - mse: 0.0060 - centernormXYReal: 165.3941 - normXYReal: 114.1701 - mseXYReal: 15779.5146 - maeXYReal: 71.1841 - rmseXYReal: 125.6165 - val_loss: 0.0058 - val_mse: 0.0058 - val_centernormXYReal: 158.1265 - val_normXYReal: 112.7403 - val_mseXYReal: 15032.2275 - val_maeXYReal: 70.4069 - val_rmseXYReal: 122.6060 - lr: 1.0000e-04
# Epoch 21/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0054 - mse: 0.0054 - centernormXYReal: 189.5139 - normXYReal: 104.8212 - mseXYReal: 14224.2617 - maeXYReal: 65.2513 - rmseXYReal: 119.2655 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 159.6902 - val_normXYReal: 105.1383 - val_mseXYReal: 14064.4219 - val_maeXYReal: 65.5386 - val_rmseXYReal: 118.5935 - lr: 1.3534e-05
# Epoch 22/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0052 - mse: 0.0052 - centernormXYReal: 164.4576 - normXYReal: 102.1476 - mseXYReal: 13679.1699 - maeXYReal: 63.6263 - rmseXYReal: 116.9580 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 147.2762 - val_normXYReal: 106.1629 - val_mseXYReal: 14132.1104 - val_maeXYReal: 66.1420 - val_rmseXYReal: 118.8786 - lr: 1.2246e-05
# Epoch 23/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0052 - mse: 0.0052 - centernormXYReal: 165.2076 - normXYReal: 101.3118 - mseXYReal: 13575.7256 - maeXYReal: 63.0737 - rmseXYReal: 116.5149 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 133.9647 - val_normXYReal: 105.7890 - val_mseXYReal: 13992.8330 - val_maeXYReal: 66.0218 - val_rmseXYReal: 118.2913 - lr: 1.1080e-05
# Epoch 24/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0051 - mse: 0.0051 - centernormXYReal: 177.4952 - normXYReal: 100.4350 - mseXYReal: 13418.0059 - maeXYReal: 62.5694 - rmseXYReal: 115.8361 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 145.6496 - val_normXYReal: 105.0138 - val_mseXYReal: 13971.3584 - val_maeXYReal: 65.3975 - val_rmseXYReal: 118.2005 - lr: 1.0026e-05
# Epoch 25/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0051 - mse: 0.0051 - centernormXYReal: 156.0387 - normXYReal: 99.7951 - mseXYReal: 13330.3896 - maeXYReal: 62.1103 - rmseXYReal: 115.4573 - val_loss: 0.0054 - val_mse: 0.0054 - val_centernormXYReal: 137.1930 - val_normXYReal: 105.5022 - val_mseXYReal: 14002.8574 - val_maeXYReal: 65.8460 - val_rmseXYReal: 118.3337 - lr: 9.0718e-06
# Epoch 26/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0051 - mse: 0.0051 - centernormXYReal: 130.5071 - normXYReal: 99.4658 - mseXYReal: 13303.6562 - maeXYReal: 61.9339 - rmseXYReal: 115.3415 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 130.4918 - val_normXYReal: 104.9535 - val_mseXYReal: 13918.3965 - val_maeXYReal: 65.3748 - val_rmseXYReal: 117.9763 - lr: 8.2085e-06
# Epoch 27/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0050 - mse: 0.0050 - centernormXYReal: 178.4023 - normXYReal: 98.9227 - mseXYReal: 13231.1172 - maeXYReal: 61.5836 - rmseXYReal: 115.0266 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 148.2867 - val_normXYReal: 104.2116 - val_mseXYReal: 13888.7100 - val_maeXYReal: 64.9843 - val_rmseXYReal: 117.8504 - lr: 7.4274e-06
# Epoch 28/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0050 - mse: 0.0050 - centernormXYReal: 163.2649 - normXYReal: 98.4857 - mseXYReal: 13094.1689 - maeXYReal: 61.3007 - rmseXYReal: 114.4297 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 142.5708 - val_normXYReal: 104.3813 - val_mseXYReal: 13848.9971 - val_maeXYReal: 65.0343 - val_rmseXYReal: 117.6818 - lr: 6.7206e-06
# Epoch 29/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0050 - mse: 0.0050 - centernormXYReal: 164.4278 - normXYReal: 98.1550 - mseXYReal: 13069.5576 - maeXYReal: 61.1127 - rmseXYReal: 114.3222 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 145.7256 - val_normXYReal: 104.2985 - val_mseXYReal: 13768.0381 - val_maeXYReal: 65.0021 - val_rmseXYReal: 117.3373 - lr: 6.0810e-06
# Epoch 30/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 164.9919 - normXYReal: 97.8336 - mseXYReal: 12954.9658 - maeXYReal: 60.9048 - rmseXYReal: 113.8199 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 147.2432 - val_normXYReal: 104.7205 - val_mseXYReal: 13834.1553 - val_maeXYReal: 65.3594 - val_rmseXYReal: 117.6187 - lr: 5.5023e-06
# Epoch 31/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 175.0606 - normXYReal: 97.6562 - mseXYReal: 13027.2178 - maeXYReal: 60.8120 - rmseXYReal: 114.1368 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 141.8266 - val_normXYReal: 104.0108 - val_mseXYReal: 13810.2568 - val_maeXYReal: 64.7803 - val_rmseXYReal: 117.5170 - lr: 4.9787e-06
# Epoch 32/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 136.8317 - normXYReal: 97.3139 - mseXYReal: 12948.8779 - maeXYReal: 60.5916 - rmseXYReal: 113.7931 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 129.4810 - val_normXYReal: 103.9972 - val_mseXYReal: 13810.8945 - val_maeXYReal: 64.8143 - val_rmseXYReal: 117.5198 - lr: 4.5049e-06
# Epoch 33/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 173.6393 - normXYReal: 97.0622 - mseXYReal: 12866.4980 - maeXYReal: 60.4002 - rmseXYReal: 113.4306 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 150.6169 - val_normXYReal: 103.6166 - val_mseXYReal: 13768.4580 - val_maeXYReal: 64.6178 - val_rmseXYReal: 117.3391 - lr: 4.0762e-06
# Epoch 34/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 158.9578 - normXYReal: 97.0650 - mseXYReal: 12880.9512 - maeXYReal: 60.4518 - rmseXYReal: 113.4943 - val_loss: 0.0053 - val_mse: 0.0053 - val_centernormXYReal: 155.9279 - val_normXYReal: 104.2681 - val_mseXYReal: 13827.7080 - val_maeXYReal: 64.9796 - val_rmseXYReal: 117.5913 - lr: 3.6883e-06
# Epoch 35/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 160.1838 - normXYReal: 96.7022 - mseXYReal: 12773.1279 - maeXYReal: 60.1932 - rmseXYReal: 113.0183 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 135.3508 - val_normXYReal: 102.7458 - val_mseXYReal: 13632.2471 - val_maeXYReal: 64.0720 - val_rmseXYReal: 116.7572 - lr: 3.3373e-06
# Epoch 36/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 162.2433 - normXYReal: 96.6478 - mseXYReal: 12827.4795 - maeXYReal: 60.2136 - rmseXYReal: 113.2585 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 138.8588 - val_normXYReal: 103.4939 - val_mseXYReal: 13687.8086 - val_maeXYReal: 64.4984 - val_rmseXYReal: 116.9949 - lr: 3.0197e-06
# Epoch 37/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 158.7229 - normXYReal: 96.5826 - mseXYReal: 12836.2627 - maeXYReal: 60.1433 - rmseXYReal: 113.2972 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 149.6366 - val_normXYReal: 103.3671 - val_mseXYReal: 13704.5186 - val_maeXYReal: 64.4281 - val_rmseXYReal: 117.0663 - lr: 2.7324e-06
# Epoch 38/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 174.1664 - normXYReal: 96.5779 - mseXYReal: 12827.0449 - maeXYReal: 60.1510 - rmseXYReal: 113.2565 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 134.2149 - val_normXYReal: 103.9190 - val_mseXYReal: 13702.9434 - val_maeXYReal: 64.7685 - val_rmseXYReal: 117.0596 - lr: 2.4724e-06
# Epoch 39/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0049 - mse: 0.0049 - centernormXYReal: 177.9620 - normXYReal: 96.6066 - mseXYReal: 12850.8867 - maeXYReal: 60.1450 - rmseXYReal: 113.3618 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 128.4819 - val_normXYReal: 103.2461 - val_mseXYReal: 13634.5234 - val_maeXYReal: 64.3641 - val_rmseXYReal: 116.7670 - lr: 2.2371e-06
# Epoch 40/40
# 896/896 [==============================] - 15s 17ms/step - loss: 0.0048 - mse: 0.0048 - centernormXYReal: 173.7972 - normXYReal: 96.0892 - mseXYReal: 12705.7744 - maeXYReal: 59.8225 - rmseXYReal: 112.7199 - val_loss: 0.0052 - val_mse: 0.0052 - val_centernormXYReal: 138.2154 - val_normXYReal: 103.1351 - val_mseXYReal: 13624.2256 - val_maeXYReal: 64.2841 - val_rmseXYReal: 116.7229 - lr: 2.0242e-06

# %% [markdown]
# ## Analysis of the model

# %%
plt.plot(history.history["mse"], 'b', label="mse")
plt.plot(history.history["val_mse"], 'r', label="val_mse")
plt.ylabel("mse")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["loss"], 'b', label="loss")
plt.plot(history.history["val_loss"], 'r', label="val_loss")
plt.ylabel("losses")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["centernormXYReal"], 'b', label="centernormXYReal")
plt.plot(history.history["val_centernormXYReal"], 'r', label="val_centernormXYReal")
plt.ylabel("centernormXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
plt.plot(history.history["normXYReal"], 'b', label="normXYReal")
plt.plot(history.history["val_normXYReal"], 'r', label="val_normXYReal")
plt.ylabel("normXYReal [mm]")
plt.xlabel("Epoch")
plt.legend()
plt.show()

# %%
results = model.evaluate(test_data, test_labels)
dict(zip(model.metrics_names, results))
# Out:
# 193/193 [==============================] - 2s 12ms/step - loss: 0.0052 - mse: 0.0052 - centernormXYReal: 119.9379 - normXYReal: 104.0728 - mseXYReal: 13342.2725 - maeXYReal: 65.0451 - rmseXYReal: 115.5088
# {'loss': 0.005175371188670397,
#  'mse': 0.005175371188670397,
#  'centernormXYReal': 119.93794250488281,
#  'normXYReal': 104.07278442382812,
#  'mseXYReal': 13342.2724609375,
#  'maeXYReal': 65.04508209228516,
#  'rmseXYReal': 115.50875854492188}
